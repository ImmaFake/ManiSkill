# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import gym
import time
import mani_skill.env
import pandas as pd
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style


#####################  hyper parameters  ####################

MAX_EPISODES = 1500               # 最大训练代数
MAX_EP_STEPS = 200               # episode最大持续帧数

RENDER = False

LOAD_MEM = False
LOAD_MODEL = False
LOAD_FOLDER_NAME = 'carbinet_1000epi'

LOAD_PRETRAIN = False


ENV_NAME = 'OpenCabinetDrawer-v0'         # 游戏名称
SEED = 123                       # 随机数种子

var = 5
var_low_bound = 0.2

# %%
###############################  DDPG  ####################################
class DDPG(object):
    def __init__(self, a_dim, s_dim, a_bound,):
        self.a_dim = a_dim
        self.s_dim = s_dim
        self.a_bound = a_bound
        self.pointer = 0                                                                         # exp buffer指针
        self.lr_a = 0.001                                                                        # learning rate for actor
        self.lr_c = 0.001                                                                        # learning rate for critic
        self.gamma = 0.9                                                                         # reward discount
        self.tau = 0.0001                                                                          # 软更新比例
        self.memory_capacity = 20000
        self.batch_size = 32
        self.memory = np.zeros((self.memory_capacity, s_dim * 2 + a_dim + 1), dtype=np.float32)

        self.Reward_record = []
        
        class ANet(nn.Module):                               # 定义动作网络
            def __init__(self, s_dim, a_dim, a_bound):
                super(ANet,self).__init__()
                self.a_bound = a_bound
                self.fc1 = nn.Linear(s_dim,1024)
                self.fc1.weight.data.normal_(0,0.1)          # initialization
                
                self.fc2 = nn.Linear(1024,1024)
                self.fc2.weight.data.normal_(0,0.1)
                               
                self.fc3 = nn.Linear(1024,1024)
                self.fc3.weight.data.normal_(0,0.1)
                
                self.fc4 = nn.Linear(1024,1024)
                self.fc4.weight.data.normal_(0,0.1)
                
                self.out = nn.Linear(1024,a_dim)
                self.out.weight.data.normal_(0,0.1)          # initialization
            def forward(self,x):
                x = self.fc1(x)
                x = F.relu(x)
                
                x = self.fc2(x)
                x = F.relu(x)
                
                x = self.fc3(x)
                x = F.relu(x)
                
                x = self.fc4(x)
                x = F.relu(x)               
                
                x = self.out(x)
                x = F.tanh(x)
                actions_value = x * a_bound
                return actions_value

        class CNet(nn.Module):                               # 定义价值网络
            def __init__(self,s_dim,a_dim):
                super(CNet,self).__init__()
                self.fcs1 = nn.Linear(s_dim,1024)
                self.fcs1.weight.data.normal_(0,0.1)          # initialization
                #self.fcs1.weight.data.fill_(-0.01)
                
                self.fcs2 = nn.Linear(1024,1024)
                self.fcs2.weight.data.normal_(0,0.1)          # initialization
                #self.fcs1.weight.data.fill_(-0.01)
                
                self.fcs3 = nn.Linear(1024,1024)
                self.fcs3.weight.data.normal_(0,0.1)          # initialization
                #self.fcs1.weight.data.fill_(-0.01) 

                self.fcs4 = nn.Linear(1024,1024)
                self.fcs4.weight.data.normal_(0,0.1) 
                
                self.fca1 = nn.Linear(a_dim,1024)
                self.fca1.weight.data.normal_(0,0.1)          # initialization
                #self.fcs1.weight.data.fill_(-0.01)
                
                self.fca2 = nn.Linear(1024,1024)
                self.fca2.weight.data.normal_(0,0.1)          # initialization
                #self.fcs1.weight.data.fill_(-0.01)              
                
                self.fca3 = nn.Linear(1024,1024)
                self.fca3.weight.data.normal_(0,0.1)          # initialization
                #self.fcs1.weight.data.fill_(-0.01)
                
                self.fca4 = nn.Linear(1024,1024)
                self.fca4.weight.data.normal_(0,0.1)
                
                self.out = nn.Linear(1024,1)
                self.out.weight.data.normal_(0,0.1)          # initialization
                #self.fcs1.weight.data.fill_(-0.01)
            def forward(self,s,a):
                x = self.fcs1(s)                              # 输入状态
                x = F.relu(x)
                
                x = self.fcs2(x)
                x = F.relu(x)
                
                x = self.fcs3(x)
                x = F.relu(x)
                
                x = self.fcs4(x)
                x = F.relu(x)
                
                y = self.fca1(a)                              # 输入动作
                y = F.relu(y)
                
                y = self.fca2(y)                              
                y = F.relu(y)
                
                y = self.fca3(y)                              
                y = F.relu(y)
                
                y = self.fca4(y)                              
                y = F.relu(y)
                
                net = F.relu(x+y)
                actions_value = self.out(net)                # 给出V(s,a)
                return actions_value

        self.Actor_eval = ANet(s_dim, a_dim, a_bound)        # 主网络
        self.Actor_target = ANet(s_dim, a_dim, a_bound)      # 目标网络
        self.Critic_eval = CNet(s_dim, a_dim)                # 主网络
        self.Critic_target = CNet(s_dim, a_dim)              # 当前网络
        self.ctrain = torch.optim.Adam(self.Critic_eval.parameters(),lr = self.lr_c) # critic的优化器
        self.atrain = torch.optim.Adam(self.Actor_eval.parameters(),lr = self.lr_a)  # actor的优化器
        self.loss_td = nn.MSELoss()                          # 损失函数采用均方误差

    def choose_action(self, s):
        s = torch.unsqueeze(torch.FloatTensor(s), 0)
        #print('choose action: ',self.Actor_eval(s))
        #print('choose action 0 : ', self.Actor_eval(s)[0])
        #print('forward: ',self.Actor_eval.forward(s))
        return self.Actor_eval(s)[0].detach()                # detach()不需要计算梯度 #用forward等价（应该

    def learn(self):

        for x in self.Actor_target.state_dict().keys():#更新target network
            eval('self.Actor_target.' + x + '.data.mul_((1 - self.tau))')  
            eval('self.Actor_target.' + x + '.data.add_(self.tau * self.Actor_eval.' + x + '.data)')
        for x in self.Critic_target.state_dict().keys():
            eval('self.Critic_target.' + x + '.data.mul_((1- self.tau))')
            eval('self.Critic_target.' + x + '.data.add_(self.tau * self.Critic_eval.' + x + '.data)')

        # soft target replacement

        indices = np.random.choice(self.memory_capacity, size = self.batch_size)  # 随机采样的index
        bt = self.memory[indices, :]                                              # 采样batch_size个sample
        bs = torch.FloatTensor(bt[:, :self.s_dim])                                # state
        ba = torch.FloatTensor(bt[:, self.s_dim: self.s_dim + self.a_dim])        # action
        br = torch.FloatTensor(bt[:, -self.s_dim - 1: -self.s_dim])               # reward
        bs_ = torch.FloatTensor(bt[:, -self.s_dim:])                              # next state
        
        
        a = self.Actor_eval(bs)
        q = self.Critic_eval(bs,a)  # 依据critic给出的打分 来更新actor 使得actor作出的预测才critic这边能得到更高的分数
                                    # 如果 a是一个正确的行为的话，那么它的Q应该更贴近0
        loss_a = -torch.mean(q)     #一个batch输入进去，有好多个q所以要做平均
        #print('q: ',q)
        #print('loss_a: ',loss_a)
        self.atrain.zero_grad()
        loss_a.backward()
        self.atrain.step()
        
        
        a_ = self.Actor_target(bs_)      # 预测下一步会做什么动作
        q_ = self.Critic_target(bs_,a_)  # 给预测出的下一步动作进行打分-- 用于给出 Actor 更新参数时的 Gradient ascent 强度
        q_target = br + self.gamma * q_  # 
        #print('q_target: ', q_target)
        #print('Reward: ', br)
        #print('q_: ', q_)
        q_v = self.Critic_eval(bs,ba)    # 对这一步的动作进行打分 
        #print('q_v: ', q_v)
        td_error = self.loss_td(q_target,q_v)
        # td_error = R + self.gamma * ct（bs_,at(bs_)）-ce(s,ba) 更新ce ,但这个ae(s)是记忆中的ba，让ce得出的Q靠近Q_target,让评价更准确
        # print('td error: ', torch.mean(td_error))
        self.ctrain.zero_grad()
        td_error.backward()
        self.ctrain.step()
        
        
    def store_transition(self, s, a, r, s_):
        transition = np.hstack((s, a, [r], s_))
        index = self.pointer % self.memory_capacity     # replace the old memory with new memory
        self.memory[index, :] = transition
        self.pointer += 1                               # 指示sample位置的指针+1
    
    def store_reward(self,ep_reward):
        self.Reward_record.append(ep_reward)
        
    def save(self,folder_name):
    
        os.mkdir('./DPG model/' + folder_name)
    
        PATH1 = './DPG model/' + folder_name + '/Actor_eval.h5f'
        PATH2 = './DPG model/' + folder_name + '/Actor_target.h5f'
        PATH3 = './DPG model/' + folder_name + '/Critic_eval.h5f'
        PATH4 = './DPG model/' + folder_name + '/Critic_target.h5f'
    
        torch.save(self.Actor_eval.state_dict(), PATH1)
        torch.save(self.Actor_target.state_dict(), PATH2)
        torch.save(self.Critic_eval.state_dict(), PATH3)
        torch.save(self.Critic_target.state_dict(), PATH4)
    
        csv_name='./DPG model/' + folder_name + '/memory.csv'
        xml_df = pd.DataFrame(self.memory)
        xml_df.to_csv(csv_name, index = None, columns= None)
        
        csv_name='./DPG model/' + folder_name + '/Rewards.csv'
        xml_df = pd.DataFrame(self.Reward_record)
        xml_df.to_csv(csv_name, index = None, columns= None)
        
        y = self.Reward_record
        x = range(len(y))
        plt.figure(figsize=(10, 10), dpi=70)
        plt.scatter(x, y)
        plt.savefig('./DPG model/' + folder_name + '/scatter.png')
        plt.plot(x, y)
        plt.savefig('./DPG model/' + folder_name + '/plot.png')
        
    def plot_file_rewards(self, folder_name):
        data = pd.read_csv('./DPG model/' + folder_name + '/Rewards.csv')
        y = np.array(data).squeeze()
        x = range(y.shape[0])
        plt.figure(figsize=(10, 10), dpi=70)
        #plt.plot(x, y)
        plt.scatter(x, y)
        plt.show()
    
    def plot_rewards(self, scatter):
        y = self.Reward_record
        x = range(len(y))
        plt.figure(figsize=(10, 10), dpi=70)
            
        if scatter:
            plt.scatter(x, y)
        else:
            plt.plot(x, y)
        plt.show()
    
    def load_model(self):
        self.Actor_eval.load_state_dict(torch.load('./DPG model/' + LOAD_FOLDER_NAME + '/Actor_eval.h5f'))
        self.Actor_eval.eval()
        self.Actor_target.load_state_dict(torch.load('./DPG model/' + LOAD_FOLDER_NAME + '/Actor_target.h5f'))
        self.Actor_target.eval()
        self.Critic_eval.load_state_dict(torch.load('./DPG model/' + LOAD_FOLDER_NAME + '/Critic_eval.h5f'))
        self.Critic_eval.eval()
        self.Critic_target.load_state_dict(torch.load('./DPG model/' + LOAD_FOLDER_NAME + '/Critic_target.h5f'))
        self.Critic_target.eval()
        print("Load network parameters of: " + LOAD_FOLDER_NAME) 
        
    def load_memory(self):
        data = pd.read_csv('./DPG model/' + LOAD_FOLDER_NAME + '/memory.csv')
        self.memory = np.array(data)
        print("Load memory of: " + LOAD_FOLDER_NAME)
    
    def load_pretrain(self):
        self.Actor_eval.load_state_dict(torch.load('./DPG model/pretrain/Actor_eval.h5f'))
        self.Actor_eval.eval()
        self.Actor_target.load_state_dict(torch.load('./DPG model/pretrain/Actor_eval.h5f'))
        self.Actor_target.eval()        
        print("Load pretrained actor")

# %%
###############################  training  ####################################
env = gym.make(ENV_NAME)
env = env.unwrapped
env.seed(SEED)                                          # 设置Gym的随机数种子
torch.manual_seed(SEED)                                 # 设置pytorch的随机数种子

env.set_env_mode(obs_mode='state', reward_type='dense')

s_dim = env.observation_space.shape[0]                  # 状态空间
a_dim = env.action_space.shape[0]                       # 动作空间
a_bound = 1                         # 动作取值区间,对称区间，故只取上界
ddpg = DDPG(a_dim, s_dim, a_bound)

if LOAD_MODEL:
    ddpg.load_model()
    
if LOAD_MEM:
    ddpg.load_memory()

if LOAD_PRETRAIN:
    ddpg.load_pretrain()

if LOAD_MODEL or LOAD_MEM:
    var = 0.5

if LOAD_PRETRAIN:
    var = 0.1
    
t1 = time.time()                                        # 开始时间

for i in range(MAX_EPISODES):
    s = env.reset(level = 1)
    ep_reward = 0

    for j in range(MAX_EP_STEPS):
        if RENDER:
            env.render('human')

        # Add exploration noise
        a = ddpg.choose_action(s)

        a = np.clip(np.random.normal(a, var), -1, 1)    # add randomness to action selection for exploration

        s_, r, done, info = env.step(a)
        
        info_ = info.get('eval_info')
        
        if info_.get('success'):
            print('SUCCESS')
            r += 10000
        
        r += 10
        r = r * 4
        ddpg.store_transition(s, a, r , s_)         # 为什么要对reward归一化

        if ddpg.pointer > ddpg.memory_capacity or LOAD_MEM:         # 经验池已满
            if var > var_low_bound:
                var *= .9998                            # 学习阶段逐渐降低动作随机性decay the action randomness
            ddpg.learn()                                # 开始学习

        s = s_
        ep_reward += r
        if j == MAX_EP_STEPS-1 or done:
            print('Episode:', i, ' Reward: %i' % int(ep_reward), 'Explore: %.2f' % var, )
            
            ddpg.store_reward(ep_reward)
            
            if ep_reward > -100 or i == (MAX_EPISODES - 5):
                RENDER = True
            
            break
               
print('Running time: ', time.time() - t1)
# Out:
# Episode: 0  Reward: -4025 Explore: 5.00
# Episode: 1  Reward: -2809 Explore: 5.00
# Episode: 2  Reward: -2103 Explore: 5.00
# Episode: 3  Reward: -3210 Explore: 5.00
# Episode: 4  Reward: -2167 Explore: 5.00
# Episode: 5  Reward: -3016 Explore: 5.00
# Episode: 6  Reward: -2612 Explore: 5.00
# Episode: 7  Reward: -2170 Explore: 5.00
# Episode: 8  Reward: -3134 Explore: 5.00
# Episode: 9  Reward: -2848 Explore: 5.00
# Episode: 10  Reward: -3490 Explore: 5.00
# Episode: 11  Reward: -2446 Explore: 5.00
# Episode: 12  Reward: -2218 Explore: 5.00
# Episode: 13  Reward: -2218 Explore: 5.00
# Episode: 14  Reward: -3160 Explore: 5.00
# Episode: 15  Reward: -3310 Explore: 5.00
# Episode: 16  Reward: -3151 Explore: 5.00
# Episode: 17  Reward: -3305 Explore: 5.00
# Episode: 18  Reward: -2171 Explore: 5.00
# Episode: 19  Reward: -2027 Explore: 5.00
# Episode: 20  Reward: -2569 Explore: 5.00
# Episode: 21  Reward: -3600 Explore: 5.00
# Episode: 22  Reward: -2145 Explore: 5.00
# Episode: 23  Reward: -2599 Explore: 5.00
# Episode: 24  Reward: -2146 Explore: 5.00
# Episode: 25  Reward: -2040 Explore: 5.00
# Episode: 26  Reward: -3384 Explore: 5.00
# Episode: 27  Reward: -2180 Explore: 5.00
# Episode: 28  Reward: -2407 Explore: 5.00
# Episode: 29  Reward: -3047 Explore: 5.00
# Episode: 30  Reward: -2847 Explore: 5.00
# Episode: 31  Reward: -3783 Explore: 5.00
# Episode: 32  Reward: -2409 Explore: 5.00
# Episode: 33  Reward: -3282 Explore: 5.00
# Episode: 34  Reward: -2048 Explore: 5.00
# Episode: 35  Reward: -3518 Explore: 5.00
# Episode: 36  Reward: -3144 Explore: 5.00
# Episode: 37  Reward: -2624 Explore: 5.00
# Episode: 38  Reward: -3998 Explore: 5.00
# Episode: 39  Reward: -2731 Explore: 5.00
# Episode: 40  Reward: -3686 Explore: 5.00
# Episode: 41  Reward: -2771 Explore: 5.00
# Episode: 42  Reward: -2453 Explore: 5.00
# Episode: 43  Reward: -1781 Explore: 5.00
# Episode: 44  Reward: -2434 Explore: 5.00
# Episode: 45  Reward: -2136 Explore: 5.00
# Episode: 46  Reward: -3297 Explore: 5.00
# Episode: 47  Reward: -3119 Explore: 5.00
# Episode: 48  Reward: -3182 Explore: 5.00
# Episode: 49  Reward: -3034 Explore: 5.00
# Episode: 50  Reward: -2508 Explore: 5.00
# Episode: 51  Reward: -2459 Explore: 5.00
# Episode: 52  Reward: -3224 Explore: 5.00
# Episode: 53  Reward: -2523 Explore: 5.00
# Episode: 54  Reward: -1965 Explore: 5.00
# Episode: 55  Reward: -3725 Explore: 5.00
# Episode: 56  Reward: -2022 Explore: 5.00
# Episode: 57  Reward: -2346 Explore: 5.00
# Episode: 58  Reward: -2370 Explore: 5.00
# Episode: 59  Reward: -2591 Explore: 5.00
# Episode: 60  Reward: -2034 Explore: 5.00
# Episode: 61  Reward: -3795 Explore: 5.00
# Episode: 62  Reward: -2652 Explore: 5.00
# Episode: 63  Reward: -3300 Explore: 5.00
# Episode: 64  Reward: -2324 Explore: 5.00
# Episode: 65  Reward: -2845 Explore: 5.00
# Episode: 66  Reward: -2176 Explore: 5.00
# Episode: 67  Reward: -3080 Explore: 5.00
# Episode: 68  Reward: -3271 Explore: 5.00
# Episode: 69  Reward: -2350 Explore: 5.00
# Episode: 70  Reward: -2980 Explore: 5.00
# Episode: 71  Reward: -2900 Explore: 5.00
# Episode: 72  Reward: -2717 Explore: 5.00
# Episode: 73  Reward: -3237 Explore: 5.00
# Episode: 74  Reward: -2868 Explore: 5.00
# Episode: 75  Reward: -2364 Explore: 5.00
# Episode: 76  Reward: -3021 Explore: 5.00
# Episode: 77  Reward: -3407 Explore: 5.00
# Episode: 78  Reward: -2322 Explore: 5.00
# Episode: 79  Reward: -2779 Explore: 5.00
# Episode: 80  Reward: -2360 Explore: 5.00
# Episode: 81  Reward: -2928 Explore: 5.00
# Episode: 82  Reward: -2343 Explore: 5.00
# Episode: 83  Reward: -3309 Explore: 5.00
# Episode: 84  Reward: -2619 Explore: 5.00
# Episode: 85  Reward: -3443 Explore: 5.00
# Episode: 86  Reward: -2435 Explore: 5.00
# Episode: 87  Reward: -2924 Explore: 5.00
# Episode: 88  Reward: -2926 Explore: 5.00
# Episode: 89  Reward: -1939 Explore: 5.00
# Episode: 90  Reward: -2609 Explore: 5.00
# Episode: 91  Reward: -3051 Explore: 5.00
# Episode: 92  Reward: -2474 Explore: 5.00
# Episode: 93  Reward: -2187 Explore: 5.00
# Episode: 94  Reward: -2561 Explore: 5.00
# Episode: 95  Reward: -2055 Explore: 5.00
# Episode: 96  Reward: -3491 Explore: 5.00
# Episode: 97  Reward: -2423 Explore: 5.00
# Episode: 98  Reward: -2718 Explore: 5.00
# Episode: 99  Reward: -2746 Explore: 5.00
# Episode: 100  Reward: -2609 Explore: 4.80
# Episode: 101  Reward: -2706 Explore: 4.62
# Episode: 102  Reward: -3439 Explore: 4.43
# Episode: 103  Reward: -3546 Explore: 4.26
# Episode: 104  Reward: -3496 Explore: 4.09
# Episode: 105  Reward: -3106 Explore: 3.93
# Episode: 106  Reward: -3005 Explore: 3.78
# Episode: 107  Reward: -3632 Explore: 3.63
# Episode: 108  Reward: -2650 Explore: 3.49
# Episode: 109  Reward: -3598 Explore: 3.35
# Episode: 110  Reward: -3333 Explore: 3.22
# Episode: 111  Reward: -2862 Explore: 3.09
# Episode: 112  Reward: -2618 Explore: 2.97
# Episode: 113  Reward: -3177 Explore: 2.86
# Episode: 114  Reward: -3163 Explore: 2.74
# Episode: 115  Reward: -3020 Explore: 2.64
# Episode: 116  Reward: -3097 Explore: 2.53
# Episode: 117  Reward: -3671 Explore: 2.43
# Episode: 118  Reward: -3563 Explore: 2.34
# Episode: 119  Reward: -3492 Explore: 2.25
# Episode: 120  Reward: -3286 Explore: 2.16
# Episode: 121  Reward: -2934 Explore: 2.07
# Episode: 122  Reward: -3172 Explore: 1.99
# Episode: 123  Reward: -2671 Explore: 1.91
# Episode: 124  Reward: -3984 Explore: 1.84
# Episode: 125  Reward: -4137 Explore: 1.77
# Episode: 126  Reward: -3325 Explore: 1.70
# Episode: 127  Reward: -3593 Explore: 1.63
# Episode: 128  Reward: -3124 Explore: 1.57
# Episode: 129  Reward: -3197 Explore: 1.51
# Episode: 130  Reward: -3090 Explore: 1.45
# Episode: 131  Reward: -3289 Explore: 1.39
# Episode: 132  Reward: -3311 Explore: 1.34
# Episode: 133  Reward: -3339 Explore: 1.28
# Episode: 134  Reward: -3384 Explore: 1.23
# Episode: 135  Reward: -3052 Explore: 1.18
# Episode: 136  Reward: -3353 Explore: 1.14
# Episode: 137  Reward: -3569 Explore: 1.09
# Episode: 138  Reward: -2797 Explore: 1.05
# Episode: 139  Reward: -3699 Explore: 1.01
# Episode: 140  Reward: -2871 Explore: 0.97
# Episode: 141  Reward: -2980 Explore: 0.93
# Episode: 142  Reward: -2901 Explore: 0.90
# Episode: 143  Reward: -3493 Explore: 0.86
# Episode: 144  Reward: -2942 Explore: 0.83
# Episode: 145  Reward: -3709 Explore: 0.79
# Episode: 146  Reward: -3069 Explore: 0.76
# Episode: 147  Reward: -2939 Explore: 0.73
# Episode: 148  Reward: -3131 Explore: 0.70
# Episode: 149  Reward: -3167 Explore: 0.68
# Episode: 150  Reward: -3196 Explore: 0.65
# Episode: 151  Reward: -2913 Explore: 0.62
# Episode: 152  Reward: -3138 Explore: 0.60
# Episode: 153  Reward: -2989 Explore: 0.58
# Episode: 154  Reward: -3131 Explore: 0.55
# Episode: 155  Reward: -3110 Explore: 0.53
# Episode: 156  Reward: -3054 Explore: 0.51
# Episode: 157  Reward: -3175 Explore: 0.49
# Episode: 158  Reward: -2956 Explore: 0.47
# Episode: 159  Reward: -2980 Explore: 0.45
# Episode: 160  Reward: -3047 Explore: 0.44
# Episode: 161  Reward: -3197 Explore: 0.42
# Episode: 162  Reward: -3142 Explore: 0.40
# Episode: 163  Reward: -3222 Explore: 0.39
# Episode: 164  Reward: -3138 Explore: 0.37
# Episode: 165  Reward: -3071 Explore: 0.36
# Episode: 166  Reward: -3067 Explore: 0.34
# Episode: 167  Reward: -3098 Explore: 0.33
# Episode: 168  Reward: -3038 Explore: 0.32
# Episode: 169  Reward: -3029 Explore: 0.30
# Episode: 170  Reward: -2940 Explore: 0.29
# Episode: 171  Reward: -3222 Explore: 0.28
# Episode: 172  Reward: -3185 Explore: 0.27
# Episode: 173  Reward: -3127 Explore: 0.26
# Episode: 174  Reward: -3129 Explore: 0.25
# Episode: 175  Reward: -3103 Explore: 0.24
# Episode: 176  Reward: -3087 Explore: 0.23
# Episode: 177  Reward: -3058 Explore: 0.22
# Episode: 178  Reward: -3060 Explore: 0.21
# Episode: 179  Reward: -3094 Explore: 0.20
# Episode: 180  Reward: -3051 Explore: 0.20
# Episode: 181  Reward: -3074 Explore: 0.20
# Episode: 182  Reward: -3156 Explore: 0.20
# Episode: 183  Reward: -3179 Explore: 0.20
# Episode: 184  Reward: -3173 Explore: 0.20
# Episode: 185  Reward: -3166 Explore: 0.20
# Episode: 186  Reward: -3072 Explore: 0.20
# Episode: 187  Reward: -3101 Explore: 0.20
# Episode: 188  Reward: -3080 Explore: 0.20
# Episode: 189  Reward: -3101 Explore: 0.20
# Episode: 190  Reward: -3066 Explore: 0.20
# Episode: 191  Reward: -3076 Explore: 0.20
# Episode: 192  Reward: -3065 Explore: 0.20
# Episode: 193  Reward: -3106 Explore: 0.20
# Episode: 194  Reward: -3092 Explore: 0.20
# Episode: 195  Reward: -3034 Explore: 0.20
# Episode: 196  Reward: -3101 Explore: 0.20
# Episode: 197  Reward: -3103 Explore: 0.20
# Episode: 198  Reward: -3006 Explore: 0.20
# Episode: 199  Reward: -3124 Explore: 0.20
# Episode: 200  Reward: -3094 Explore: 0.20
# Episode: 201  Reward: -3053 Explore: 0.20
# Episode: 202  Reward: -3093 Explore: 0.20
# Episode: 203  Reward: -3107 Explore: 0.20
# Episode: 204  Reward: -3112 Explore: 0.20
# Episode: 205  Reward: -3112 Explore: 0.20
# Episode: 206  Reward: -3034 Explore: 0.20
# Episode: 207  Reward: -3082 Explore: 0.20
# Episode: 208  Reward: -3115 Explore: 0.20
# Episode: 209  Reward: -2991 Explore: 0.20
# Episode: 210  Reward: -3109 Explore: 0.20
# Episode: 211  Reward: -3014 Explore: 0.20
# Episode: 212  Reward: -3060 Explore: 0.20
# Episode: 213  Reward: -3099 Explore: 0.20
# Episode: 214  Reward: -3021 Explore: 0.20
# Episode: 215  Reward: -3087 Explore: 0.20
# Episode: 216  Reward: -3121 Explore: 0.20
# Episode: 217  Reward: -3047 Explore: 0.20
# Episode: 218  Reward: -3076 Explore: 0.20
# Episode: 219  Reward: -3061 Explore: 0.20
# Episode: 220  Reward: -3052 Explore: 0.20
# Episode: 221  Reward: -3085 Explore: 0.20
# Episode: 222  Reward: -3034 Explore: 0.20
# Episode: 223  Reward: -3071 Explore: 0.20
# Episode: 224  Reward: -3103 Explore: 0.20
# Episode: 225  Reward: -3052 Explore: 0.20
# Episode: 226  Reward: -3156 Explore: 0.20
# Episode: 227  Reward: -3155 Explore: 0.20
# Episode: 228  Reward: -3038 Explore: 0.20
# Episode: 229  Reward: -3152 Explore: 0.20
# Episode: 230  Reward: -3038 Explore: 0.20
# Episode: 231  Reward: -3088 Explore: 0.20
# Episode: 232  Reward: -3050 Explore: 0.20
# Episode: 233  Reward: -3072 Explore: 0.20
# Episode: 234  Reward: -3076 Explore: 0.20
# Episode: 235  Reward: -3086 Explore: 0.20
# Episode: 236  Reward: -3174 Explore: 0.20
# Episode: 237  Reward: -3158 Explore: 0.20
# Episode: 238  Reward: -3139 Explore: 0.20
# Episode: 239  Reward: -3083 Explore: 0.20
# Episode: 240  Reward: -3070 Explore: 0.20
# Episode: 241  Reward: -3036 Explore: 0.20
# Episode: 242  Reward: -3087 Explore: 0.20
# Episode: 243  Reward: -3041 Explore: 0.20
# Episode: 244  Reward: -3067 Explore: 0.20
# Episode: 245  Reward: -3069 Explore: 0.20
# Episode: 246  Reward: -3164 Explore: 0.20
# Episode: 247  Reward: -3067 Explore: 0.20
# Episode: 248  Reward: -3046 Explore: 0.20
# Episode: 249  Reward: -3112 Explore: 0.20
# Episode: 250  Reward: -3051 Explore: 0.20
# Episode: 251  Reward: -3121 Explore: 0.20
# Episode: 252  Reward: -3101 Explore: 0.20
# Episode: 253  Reward: -3119 Explore: 0.20
# Episode: 254  Reward: -3072 Explore: 0.20
# Episode: 255  Reward: -3128 Explore: 0.20
# Episode: 256  Reward: -3076 Explore: 0.20
# Episode: 257  Reward: -3050 Explore: 0.20
# Episode: 258  Reward: -3021 Explore: 0.20
# Episode: 259  Reward: -3124 Explore: 0.20
# Episode: 260  Reward: -3052 Explore: 0.20
# Episode: 261  Reward: -3103 Explore: 0.20
# Episode: 262  Reward: -3037 Explore: 0.20
# Episode: 263  Reward: -3143 Explore: 0.20
# Episode: 264  Reward: -3151 Explore: 0.20
# Episode: 265  Reward: -2965 Explore: 0.20
# Episode: 266  Reward: -3150 Explore: 0.20
# Episode: 267  Reward: -3065 Explore: 0.20
# Episode: 268  Reward: -3088 Explore: 0.20
# Episode: 269  Reward: -3027 Explore: 0.20
# Episode: 270  Reward: -3092 Explore: 0.20
# Episode: 271  Reward: -3109 Explore: 0.20
# Episode: 272  Reward: -3089 Explore: 0.20
# Episode: 273  Reward: -2999 Explore: 0.20
# Episode: 274  Reward: -3052 Explore: 0.20
# Episode: 275  Reward: -3018 Explore: 0.20
# Episode: 276  Reward: -3126 Explore: 0.20
# Episode: 277  Reward: -3030 Explore: 0.20
# Episode: 278  Reward: -3084 Explore: 0.20
# Episode: 279  Reward: -3199 Explore: 0.20
# Episode: 280  Reward: -3114 Explore: 0.20
# Episode: 281  Reward: -3060 Explore: 0.20
# Episode: 282  Reward: -3124 Explore: 0.20
# Episode: 283  Reward: -3148 Explore: 0.20
# Episode: 284  Reward: -3046 Explore: 0.20
# Episode: 285  Reward: -2982 Explore: 0.20
# Episode: 286  Reward: -3136 Explore: 0.20
# Episode: 287  Reward: -3139 Explore: 0.20
# Episode: 288  Reward: -3049 Explore: 0.20
# Episode: 289  Reward: -3089 Explore: 0.20
# Episode: 290  Reward: -3028 Explore: 0.20
# Episode: 291  Reward: -3096 Explore: 0.20
# Episode: 292  Reward: -3095 Explore: 0.20
# Episode: 293  Reward: -3151 Explore: 0.20
# Episode: 294  Reward: -3007 Explore: 0.20
# Episode: 295  Reward: -3080 Explore: 0.20
# Episode: 296  Reward: -3012 Explore: 0.20
# Episode: 297  Reward: -3048 Explore: 0.20
# Episode: 298  Reward: -3033 Explore: 0.20
# Episode: 299  Reward: -3067 Explore: 0.20
# Episode: 300  Reward: -3012 Explore: 0.20
# Episode: 301  Reward: -3118 Explore: 0.20
# Episode: 302  Reward: -3140 Explore: 0.20
# Episode: 303  Reward: -3099 Explore: 0.20
# Episode: 304  Reward: -3020 Explore: 0.20
# Episode: 305  Reward: -3026 Explore: 0.20
# Episode: 306  Reward: -3023 Explore: 0.20
# Episode: 307  Reward: -3123 Explore: 0.20
# Episode: 308  Reward: -3097 Explore: 0.20
# Episode: 309  Reward: -3046 Explore: 0.20
# Episode: 310  Reward: -3051 Explore: 0.20
# Episode: 311  Reward: -3106 Explore: 0.20
# Episode: 312  Reward: -3101 Explore: 0.20
# Episode: 313  Reward: -3092 Explore: 0.20
# Episode: 314  Reward: -3070 Explore: 0.20
# Episode: 315  Reward: -3142 Explore: 0.20
# Episode: 316  Reward: -3113 Explore: 0.20
# Episode: 317  Reward: -3121 Explore: 0.20
# Episode: 318  Reward: -3146 Explore: 0.20
# Episode: 319  Reward: -3059 Explore: 0.20
# Episode: 320  Reward: -3147 Explore: 0.20
# Episode: 321  Reward: -3110 Explore: 0.20
# Episode: 322  Reward: -3083 Explore: 0.20
# Episode: 323  Reward: -3060 Explore: 0.20
# Episode: 324  Reward: -3162 Explore: 0.20
# Episode: 325  Reward: -2999 Explore: 0.20
# Episode: 326  Reward: -3052 Explore: 0.20
# Episode: 327  Reward: -3074 Explore: 0.20
# Episode: 328  Reward: -3009 Explore: 0.20
# Episode: 329  Reward: -3125 Explore: 0.20
# Episode: 330  Reward: -3039 Explore: 0.20
# Episode: 331  Reward: -3078 Explore: 0.20
# Episode: 332  Reward: -3098 Explore: 0.20
# Episode: 333  Reward: -3077 Explore: 0.20
# Episode: 334  Reward: -3156 Explore: 0.20
# Episode: 335  Reward: -3125 Explore: 0.20
# Episode: 336  Reward: -3064 Explore: 0.20
# Episode: 337  Reward: -3081 Explore: 0.20
# Episode: 338  Reward: -3095 Explore: 0.20
# Episode: 339  Reward: -3027 Explore: 0.20
# Episode: 340  Reward: -3045 Explore: 0.20
# Episode: 341  Reward: -3079 Explore: 0.20
# Episode: 342  Reward: -3035 Explore: 0.20
# Episode: 343  Reward: -3101 Explore: 0.20
# Episode: 344  Reward: -3052 Explore: 0.20
# Episode: 345  Reward: -3002 Explore: 0.20
# Episode: 346  Reward: -3085 Explore: 0.20
# Episode: 347  Reward: -3079 Explore: 0.20
# Episode: 348  Reward: -3107 Explore: 0.20
# Episode: 349  Reward: -3089 Explore: 0.20
# Episode: 350  Reward: -3069 Explore: 0.20
# Episode: 351  Reward: -3111 Explore: 0.20
# Episode: 352  Reward: -3036 Explore: 0.20
# Episode: 353  Reward: -3095 Explore: 0.20
# Episode: 354  Reward: -3019 Explore: 0.20
# Episode: 355  Reward: -3064 Explore: 0.20
# Episode: 356  Reward: -3108 Explore: 0.20
# Episode: 357  Reward: -3101 Explore: 0.20
# Episode: 358  Reward: -3124 Explore: 0.20
# Episode: 359  Reward: -3037 Explore: 0.20
# Episode: 360  Reward: -3170 Explore: 0.20
# Episode: 361  Reward: -3104 Explore: 0.20
# Episode: 362  Reward: -3167 Explore: 0.20
# Episode: 363  Reward: -3017 Explore: 0.20
# Episode: 364  Reward: -3094 Explore: 0.20
# Episode: 365  Reward: -3092 Explore: 0.20
# Episode: 366  Reward: -3079 Explore: 0.20
# Episode: 367  Reward: -3006 Explore: 0.20
# Episode: 368  Reward: -3068 Explore: 0.20
# Episode: 369  Reward: -3033 Explore: 0.20
# Episode: 370  Reward: -3045 Explore: 0.20
# Episode: 371  Reward: -3014 Explore: 0.20
# Episode: 372  Reward: -3074 Explore: 0.20
# Episode: 373  Reward: -3059 Explore: 0.20
# Episode: 374  Reward: -3082 Explore: 0.20
# Episode: 375  Reward: -3148 Explore: 0.20
# Episode: 376  Reward: -3160 Explore: 0.20
# Episode: 377  Reward: -3049 Explore: 0.20
# Episode: 378  Reward: -2988 Explore: 0.20
# Episode: 379  Reward: -3063 Explore: 0.20
# Episode: 380  Reward: -3208 Explore: 0.20
# Episode: 381  Reward: -3093 Explore: 0.20
# Episode: 382  Reward: -3090 Explore: 0.20
# Episode: 383  Reward: -3085 Explore: 0.20
# Episode: 384  Reward: -3147 Explore: 0.20
# Episode: 385  Reward: -3016 Explore: 0.20
# Episode: 386  Reward: -3036 Explore: 0.20
# Episode: 387  Reward: -3122 Explore: 0.20
# Episode: 388  Reward: -3110 Explore: 0.20
# Episode: 389  Reward: -3047 Explore: 0.20
# Episode: 390  Reward: -3073 Explore: 0.20
# Episode: 391  Reward: -3081 Explore: 0.20
# Episode: 392  Reward: -3029 Explore: 0.20
# Episode: 393  Reward: -3155 Explore: 0.20
# Episode: 394  Reward: -3114 Explore: 0.20
# Episode: 395  Reward: -3077 Explore: 0.20
# Episode: 396  Reward: -3026 Explore: 0.20
# Episode: 397  Reward: -3004 Explore: 0.20
# Episode: 398  Reward: -3088 Explore: 0.20
# Episode: 399  Reward: -3120 Explore: 0.20
# Episode: 400  Reward: -3048 Explore: 0.20
# Episode: 401  Reward: -2982 Explore: 0.20
# Episode: 402  Reward: -3045 Explore: 0.20
# Episode: 403  Reward: -3117 Explore: 0.20
# Episode: 404  Reward: -3155 Explore: 0.20
# Episode: 405  Reward: -3008 Explore: 0.20
# Episode: 406  Reward: -3059 Explore: 0.20
# Episode: 407  Reward: -3035 Explore: 0.20
# Episode: 408  Reward: -3138 Explore: 0.20
# Episode: 409  Reward: -3114 Explore: 0.20
# Episode: 410  Reward: -3051 Explore: 0.20
# Episode: 411  Reward: -3137 Explore: 0.20
# Episode: 412  Reward: -3091 Explore: 0.20
# Episode: 413  Reward: -3168 Explore: 0.20
# Episode: 414  Reward: -3079 Explore: 0.20
# Episode: 415  Reward: -3063 Explore: 0.20
# Episode: 416  Reward: -3026 Explore: 0.20
# Episode: 417  Reward: -3118 Explore: 0.20
# Episode: 418  Reward: -3100 Explore: 0.20
# Episode: 419  Reward: -3063 Explore: 0.20
# Episode: 420  Reward: -3085 Explore: 0.20
# Episode: 421  Reward: -3088 Explore: 0.20
# Episode: 422  Reward: -3118 Explore: 0.20
# Episode: 423  Reward: -3098 Explore: 0.20
# Episode: 424  Reward: -3090 Explore: 0.20
# Episode: 425  Reward: -3029 Explore: 0.20
# Episode: 426  Reward: -3071 Explore: 0.20
# Episode: 427  Reward: -3145 Explore: 0.20
# Episode: 428  Reward: -3016 Explore: 0.20
# Episode: 429  Reward: -3099 Explore: 0.20
# Episode: 430  Reward: -3079 Explore: 0.20
# Episode: 431  Reward: -2999 Explore: 0.20
# Episode: 432  Reward: -3016 Explore: 0.20
# Episode: 433  Reward: -3102 Explore: 0.20
# Episode: 434  Reward: -3107 Explore: 0.20
# Episode: 435  Reward: -3140 Explore: 0.20
# Episode: 436  Reward: -2989 Explore: 0.20
# Episode: 437  Reward: -3032 Explore: 0.20
# Episode: 438  Reward: -3155 Explore: 0.20
# Episode: 439  Reward: -3111 Explore: 0.20
# Episode: 440  Reward: -3084 Explore: 0.20
# Episode: 441  Reward: -3025 Explore: 0.20
# Episode: 442  Reward: -3073 Explore: 0.20
# Episode: 443  Reward: -3125 Explore: 0.20
# Episode: 444  Reward: -3082 Explore: 0.20
# Episode: 445  Reward: -3004 Explore: 0.20
# Episode: 446  Reward: -3068 Explore: 0.20
# Episode: 447  Reward: -3066 Explore: 0.20
# Episode: 448  Reward: -3060 Explore: 0.20
# Episode: 449  Reward: -3127 Explore: 0.20
# Episode: 450  Reward: -2998 Explore: 0.20
# Episode: 451  Reward: -3113 Explore: 0.20
# Episode: 452  Reward: -3024 Explore: 0.20
# Episode: 453  Reward: -3049 Explore: 0.20
# Episode: 454  Reward: -3127 Explore: 0.20
# Episode: 455  Reward: -3049 Explore: 0.20
# Episode: 456  Reward: -3082 Explore: 0.20
# Episode: 457  Reward: -3113 Explore: 0.20
# Episode: 458  Reward: -3073 Explore: 0.20
# Episode: 459  Reward: -2999 Explore: 0.20
# Episode: 460  Reward: -2988 Explore: 0.20
# Episode: 461  Reward: -3034 Explore: 0.20
# Episode: 462  Reward: -3076 Explore: 0.20
# Episode: 463  Reward: -3090 Explore: 0.20
# Episode: 464  Reward: -3099 Explore: 0.20
# Episode: 465  Reward: -2962 Explore: 0.20
# Episode: 466  Reward: -3031 Explore: 0.20
# Episode: 467  Reward: -3053 Explore: 0.20
# Episode: 468  Reward: -3057 Explore: 0.20
# Episode: 469  Reward: -3074 Explore: 0.20
# Episode: 470  Reward: -3149 Explore: 0.20
# Episode: 471  Reward: -3092 Explore: 0.20
# Episode: 472  Reward: -3114 Explore: 0.20
# Episode: 473  Reward: -3136 Explore: 0.20
# Episode: 474  Reward: -3130 Explore: 0.20
# Episode: 475  Reward: -3144 Explore: 0.20
# Episode: 476  Reward: -3019 Explore: 0.20
# Episode: 477  Reward: -3080 Explore: 0.20
# Episode: 478  Reward: -3054 Explore: 0.20
# Episode: 479  Reward: -3074 Explore: 0.20
# Episode: 480  Reward: -3136 Explore: 0.20
# Episode: 481  Reward: -3135 Explore: 0.20
# Episode: 482  Reward: -3106 Explore: 0.20
# Episode: 483  Reward: -3055 Explore: 0.20
# Episode: 484  Reward: -3025 Explore: 0.20
# Episode: 485  Reward: -3097 Explore: 0.20
# Episode: 486  Reward: -3104 Explore: 0.20
# Episode: 487  Reward: -3125 Explore: 0.20
# Episode: 488  Reward: -3073 Explore: 0.20
# Episode: 489  Reward: -3139 Explore: 0.20
# Episode: 490  Reward: -3092 Explore: 0.20
# Episode: 491  Reward: -3089 Explore: 0.20
# Episode: 492  Reward: -3073 Explore: 0.20
# Episode: 493  Reward: -3167 Explore: 0.20
# Episode: 494  Reward: -3147 Explore: 0.20
# Episode: 495  Reward: -3128 Explore: 0.20
# Episode: 496  Reward: -3072 Explore: 0.20
# Episode: 497  Reward: -3006 Explore: 0.20
# Episode: 498  Reward: -3086 Explore: 0.20
# Episode: 499  Reward: -3077 Explore: 0.20
# Episode: 500  Reward: -3041 Explore: 0.20
# Episode: 501  Reward: -3022 Explore: 0.20
# Episode: 502  Reward: -3050 Explore: 0.20
# Episode: 503  Reward: -3097 Explore: 0.20
# Episode: 504  Reward: -3062 Explore: 0.20
# Episode: 505  Reward: -3148 Explore: 0.20
# Episode: 506  Reward: -3080 Explore: 0.20
# Episode: 507  Reward: -3139 Explore: 0.20
# Episode: 508  Reward: -3116 Explore: 0.20
# Episode: 509  Reward: -2991 Explore: 0.20
# Episode: 510  Reward: -3212 Explore: 0.20
# Episode: 511  Reward: -3077 Explore: 0.20
# Episode: 512  Reward: -3149 Explore: 0.20
# Episode: 513  Reward: -3103 Explore: 0.20
# Episode: 514  Reward: -3082 Explore: 0.20
# Episode: 515  Reward: -3105 Explore: 0.20
# Episode: 516  Reward: -3068 Explore: 0.20
# Episode: 517  Reward: -3071 Explore: 0.20
# Episode: 518  Reward: -3141 Explore: 0.20
# Episode: 519  Reward: -3046 Explore: 0.20
# Episode: 520  Reward: -3028 Explore: 0.20
# Episode: 521  Reward: -3042 Explore: 0.20
# Episode: 522  Reward: -3061 Explore: 0.20
# Episode: 523  Reward: -3049 Explore: 0.20
# Episode: 524  Reward: -3069 Explore: 0.20
# Episode: 525  Reward: -3126 Explore: 0.20
# Episode: 526  Reward: -3056 Explore: 0.20
# Episode: 527  Reward: -3121 Explore: 0.20
# Episode: 528  Reward: -3130 Explore: 0.20
# Episode: 529  Reward: -3113 Explore: 0.20
# Episode: 530  Reward: -3049 Explore: 0.20
# Episode: 531  Reward: -3055 Explore: 0.20
# Episode: 532  Reward: -3076 Explore: 0.20
# Episode: 533  Reward: -2998 Explore: 0.20
# Episode: 534  Reward: -3066 Explore: 0.20
# Episode: 535  Reward: -3072 Explore: 0.20
# Episode: 536  Reward: -3119 Explore: 0.20
# Episode: 537  Reward: -3111 Explore: 0.20
# Episode: 538  Reward: -3029 Explore: 0.20
# Episode: 539  Reward: -3093 Explore: 0.20
# Episode: 540  Reward: -3074 Explore: 0.20
# Episode: 541  Reward: -3095 Explore: 0.20
# Episode: 542  Reward: -2947 Explore: 0.20
# Episode: 543  Reward: -3081 Explore: 0.20
# Episode: 544  Reward: -3077 Explore: 0.20
# Episode: 545  Reward: -3048 Explore: 0.20
# Episode: 546  Reward: -3126 Explore: 0.20
# Episode: 547  Reward: -3082 Explore: 0.20
# Episode: 548  Reward: -3116 Explore: 0.20
# Episode: 549  Reward: -3031 Explore: 0.20
# Episode: 550  Reward: -3112 Explore: 0.20
# Episode: 551  Reward: -3008 Explore: 0.20
# Episode: 552  Reward: -2959 Explore: 0.20
# Episode: 553  Reward: -3092 Explore: 0.20
# Episode: 554  Reward: -3119 Explore: 0.20
# Episode: 555  Reward: -3016 Explore: 0.20
# Episode: 556  Reward: -3043 Explore: 0.20
# Episode: 557  Reward: -3074 Explore: 0.20
# Episode: 558  Reward: -3074 Explore: 0.20
# Episode: 559  Reward: -3138 Explore: 0.20
# Episode: 560  Reward: -3066 Explore: 0.20
# Episode: 561  Reward: -3088 Explore: 0.20
# Episode: 562  Reward: -3102 Explore: 0.20
# Episode: 563  Reward: -3057 Explore: 0.20
# Episode: 564  Reward: -3113 Explore: 0.20
# Episode: 565  Reward: -3028 Explore: 0.20
# Episode: 566  Reward: -3056 Explore: 0.20
# Episode: 567  Reward: -3103 Explore: 0.20
# Episode: 568  Reward: -3040 Explore: 0.20
# Episode: 569  Reward: -3068 Explore: 0.20
# Episode: 570  Reward: -3072 Explore: 0.20
# Episode: 571  Reward: -3142 Explore: 0.20
# Episode: 572  Reward: -3066 Explore: 0.20
# Episode: 573  Reward: -3121 Explore: 0.20
# Episode: 574  Reward: -3159 Explore: 0.20
# Episode: 575  Reward: -3055 Explore: 0.20
# Episode: 576  Reward: -3071 Explore: 0.20
# Episode: 577  Reward: -3109 Explore: 0.20
# Episode: 578  Reward: -3066 Explore: 0.20
# Episode: 579  Reward: -3137 Explore: 0.20
# Episode: 580  Reward: -3090 Explore: 0.20
# Episode: 581  Reward: -3065 Explore: 0.20
# Episode: 582  Reward: -3032 Explore: 0.20
# Episode: 583  Reward: -3140 Explore: 0.20
# Episode: 584  Reward: -3092 Explore: 0.20
# Episode: 585  Reward: -3128 Explore: 0.20
# Episode: 586  Reward: -3132 Explore: 0.20
# Episode: 587  Reward: -3091 Explore: 0.20
# Episode: 588  Reward: -3061 Explore: 0.20
# Episode: 589  Reward: -3030 Explore: 0.20
# Episode: 590  Reward: -3083 Explore: 0.20
# Episode: 591  Reward: -3080 Explore: 0.20
# Episode: 592  Reward: -3124 Explore: 0.20
# Episode: 593  Reward: -3168 Explore: 0.20
# Episode: 594  Reward: -3089 Explore: 0.20
# Episode: 595  Reward: -3023 Explore: 0.20
# Episode: 596  Reward: -3141 Explore: 0.20
# Episode: 597  Reward: -3058 Explore: 0.20
# Episode: 598  Reward: -3061 Explore: 0.20
# Episode: 599  Reward: -3056 Explore: 0.20
# Episode: 600  Reward: -3069 Explore: 0.20
# Episode: 601  Reward: -3034 Explore: 0.20
# Episode: 602  Reward: -3081 Explore: 0.20
# Episode: 603  Reward: -3113 Explore: 0.20
# Episode: 604  Reward: -3148 Explore: 0.20
# Episode: 605  Reward: -3082 Explore: 0.20
# Episode: 606  Reward: -3002 Explore: 0.20
# Episode: 607  Reward: -3069 Explore: 0.20
# Episode: 608  Reward: -3099 Explore: 0.20
# Episode: 609  Reward: -3028 Explore: 0.20
# Episode: 610  Reward: -3121 Explore: 0.20
# Episode: 611  Reward: -3040 Explore: 0.20
# Episode: 612  Reward: -3073 Explore: 0.20
# Episode: 613  Reward: -2976 Explore: 0.20
# Episode: 614  Reward: -3050 Explore: 0.20
# Episode: 615  Reward: -3075 Explore: 0.20
# Episode: 616  Reward: -3160 Explore: 0.20
# Episode: 617  Reward: -3124 Explore: 0.20
# Episode: 618  Reward: -2997 Explore: 0.20
# Episode: 619  Reward: -3043 Explore: 0.20
# Episode: 620  Reward: -3060 Explore: 0.20
# Episode: 621  Reward: -3110 Explore: 0.20
# Episode: 622  Reward: -3016 Explore: 0.20
# Episode: 623  Reward: -3125 Explore: 0.20
# Episode: 624  Reward: -3062 Explore: 0.20
# Episode: 625  Reward: -3123 Explore: 0.20
# Episode: 626  Reward: -3099 Explore: 0.20
# Episode: 627  Reward: -3082 Explore: 0.20
# Episode: 628  Reward: -3082 Explore: 0.20
# Episode: 629  Reward: -3079 Explore: 0.20
# Episode: 630  Reward: -3076 Explore: 0.20
# Episode: 631  Reward: -3032 Explore: 0.20
# Episode: 632  Reward: -3076 Explore: 0.20
# Episode: 633  Reward: -3011 Explore: 0.20
# Episode: 634  Reward: -3015 Explore: 0.20
# Episode: 635  Reward: -3022 Explore: 0.20
# Episode: 636  Reward: -3085 Explore: 0.20
# Episode: 637  Reward: -3086 Explore: 0.20
# Episode: 638  Reward: -3072 Explore: 0.20
# Episode: 639  Reward: -3001 Explore: 0.20
# Episode: 640  Reward: -3101 Explore: 0.20
# Episode: 641  Reward: -3022 Explore: 0.20
# Episode: 642  Reward: -3142 Explore: 0.20
# Episode: 643  Reward: -3099 Explore: 0.20
# Episode: 644  Reward: -3137 Explore: 0.20
# Episode: 645  Reward: -3037 Explore: 0.20
# Episode: 646  Reward: -3048 Explore: 0.20
# Episode: 647  Reward: -3138 Explore: 0.20
# Episode: 648  Reward: -3142 Explore: 0.20
# Episode: 649  Reward: -3048 Explore: 0.20
# Episode: 650  Reward: -3103 Explore: 0.20
# Episode: 651  Reward: -3164 Explore: 0.20
# Episode: 652  Reward: -3001 Explore: 0.20
# Episode: 653  Reward: -3086 Explore: 0.20
# Episode: 654  Reward: -3146 Explore: 0.20
# Episode: 655  Reward: -3081 Explore: 0.20
# Episode: 656  Reward: -3074 Explore: 0.20
# Episode: 657  Reward: -3072 Explore: 0.20
# Episode: 658  Reward: -3117 Explore: 0.20
# Episode: 659  Reward: -3079 Explore: 0.20
# Episode: 660  Reward: -3086 Explore: 0.20
# Episode: 661  Reward: -3138 Explore: 0.20
# Episode: 662  Reward: -3088 Explore: 0.20
# Episode: 663  Reward: -3111 Explore: 0.20
# Episode: 664  Reward: -3045 Explore: 0.20
# Episode: 665  Reward: -3085 Explore: 0.20
# Episode: 666  Reward: -3038 Explore: 0.20
# Episode: 667  Reward: -3130 Explore: 0.20
# Episode: 668  Reward: -3164 Explore: 0.20
# Episode: 669  Reward: -3103 Explore: 0.20
# Episode: 670  Reward: -3116 Explore: 0.20
# Episode: 671  Reward: -3039 Explore: 0.20
# Episode: 672  Reward: -3105 Explore: 0.20
# Episode: 673  Reward: -3134 Explore: 0.20
# Episode: 674  Reward: -3132 Explore: 0.20
# Episode: 675  Reward: -3069 Explore: 0.20
# Episode: 676  Reward: -3045 Explore: 0.20
# Episode: 677  Reward: -3093 Explore: 0.20
# Episode: 678  Reward: -3022 Explore: 0.20
# Episode: 679  Reward: -3066 Explore: 0.20
# Episode: 680  Reward: -3069 Explore: 0.20
# Episode: 681  Reward: -3129 Explore: 0.20
# Episode: 682  Reward: -3075 Explore: 0.20
# Episode: 683  Reward: -3049 Explore: 0.20
# Episode: 684  Reward: -3004 Explore: 0.20
# Episode: 685  Reward: -3161 Explore: 0.20
# Episode: 686  Reward: -3125 Explore: 0.20
# Episode: 687  Reward: -2996 Explore: 0.20
# Episode: 688  Reward: -3145 Explore: 0.20
# Episode: 689  Reward: -3080 Explore: 0.20
# Episode: 690  Reward: -3125 Explore: 0.20
# Episode: 691  Reward: -3090 Explore: 0.20
# Episode: 692  Reward: -3104 Explore: 0.20
# Episode: 693  Reward: -3138 Explore: 0.20
# Episode: 694  Reward: -3034 Explore: 0.20
# Episode: 695  Reward: -3119 Explore: 0.20
# Episode: 696  Reward: -3011 Explore: 0.20
# Episode: 697  Reward: -3010 Explore: 0.20
# Episode: 698  Reward: -3099 Explore: 0.20
# Episode: 699  Reward: -3042 Explore: 0.20
# Episode: 700  Reward: -3043 Explore: 0.20
# Episode: 701  Reward: -3062 Explore: 0.20
# Episode: 702  Reward: -3036 Explore: 0.20
# Episode: 703  Reward: -3105 Explore: 0.20
# Episode: 704  Reward: -3159 Explore: 0.20
# Episode: 705  Reward: -3104 Explore: 0.20
# Episode: 706  Reward: -2992 Explore: 0.20
# Episode: 707  Reward: -3174 Explore: 0.20
# Episode: 708  Reward: -3055 Explore: 0.20
# Episode: 709  Reward: -3093 Explore: 0.20
# Episode: 710  Reward: -3064 Explore: 0.20
# Episode: 711  Reward: -3082 Explore: 0.20
# Episode: 712  Reward: -3098 Explore: 0.20
# Episode: 713  Reward: -3125 Explore: 0.20
# Episode: 714  Reward: -3094 Explore: 0.20
# Episode: 715  Reward: -2965 Explore: 0.20
# Episode: 716  Reward: -3123 Explore: 0.20
# Episode: 717  Reward: -3067 Explore: 0.20
# Episode: 718  Reward: -3046 Explore: 0.20
# Episode: 719  Reward: -3060 Explore: 0.20
# Episode: 720  Reward: -3094 Explore: 0.20
# Episode: 721  Reward: -3084 Explore: 0.20
# Episode: 722  Reward: -3064 Explore: 0.20
# Episode: 723  Reward: -3062 Explore: 0.20
# Episode: 724  Reward: -3030 Explore: 0.20
# Episode: 725  Reward: -3083 Explore: 0.20
# Episode: 726  Reward: -3089 Explore: 0.20
# Episode: 727  Reward: -3049 Explore: 0.20
# Episode: 728  Reward: -3128 Explore: 0.20
# Episode: 729  Reward: -3168 Explore: 0.20
# Episode: 730  Reward: -3066 Explore: 0.20
# Episode: 731  Reward: -3114 Explore: 0.20
# Episode: 732  Reward: -3125 Explore: 0.20
# Episode: 733  Reward: -3138 Explore: 0.20
# Episode: 734  Reward: -2999 Explore: 0.20
# Episode: 735  Reward: -3056 Explore: 0.20
# Episode: 736  Reward: -3104 Explore: 0.20
# Episode: 737  Reward: -3084 Explore: 0.20
# Episode: 738  Reward: -3057 Explore: 0.20
# Episode: 739  Reward: -3085 Explore: 0.20
# Episode: 740  Reward: -3124 Explore: 0.20
# Episode: 741  Reward: -3058 Explore: 0.20
# Episode: 742  Reward: -3048 Explore: 0.20
# Episode: 743  Reward: -3203 Explore: 0.20
# Episode: 744  Reward: -3110 Explore: 0.20
# Episode: 745  Reward: -3138 Explore: 0.20
# Episode: 746  Reward: -3037 Explore: 0.20
# Episode: 747  Reward: -2989 Explore: 0.20
# Episode: 748  Reward: -3131 Explore: 0.20
# Episode: 749  Reward: -3041 Explore: 0.20
# Episode: 750  Reward: -3010 Explore: 0.20
# Episode: 751  Reward: -3065 Explore: 0.20
# Episode: 752  Reward: -3145 Explore: 0.20
# Episode: 753  Reward: -3010 Explore: 0.20
# Episode: 754  Reward: -3163 Explore: 0.20
# Episode: 755  Reward: -3092 Explore: 0.20
# Episode: 756  Reward: -3175 Explore: 0.20
# Episode: 757  Reward: -3099 Explore: 0.20
# Episode: 758  Reward: -3080 Explore: 0.20
# Episode: 759  Reward: -3109 Explore: 0.20
# Episode: 760  Reward: -3078 Explore: 0.20
# Episode: 761  Reward: -3152 Explore: 0.20
# Episode: 762  Reward: -3073 Explore: 0.20
# Episode: 763  Reward: -3040 Explore: 0.20
# Episode: 764  Reward: -3084 Explore: 0.20
# Episode: 765  Reward: -3052 Explore: 0.20
# Episode: 766  Reward: -3121 Explore: 0.20
# Episode: 767  Reward: -3110 Explore: 0.20
# Episode: 768  Reward: -3103 Explore: 0.20
# Episode: 769  Reward: -3068 Explore: 0.20
# Episode: 770  Reward: -3170 Explore: 0.20
# Episode: 771  Reward: -3125 Explore: 0.20
# Episode: 772  Reward: -3100 Explore: 0.20
# Episode: 773  Reward: -2984 Explore: 0.20
# Episode: 774  Reward: -3021 Explore: 0.20
# Episode: 775  Reward: -3084 Explore: 0.20
# Episode: 776  Reward: -3067 Explore: 0.20
# Episode: 777  Reward: -3120 Explore: 0.20
# Episode: 778  Reward: -3071 Explore: 0.20
# Episode: 779  Reward: -3042 Explore: 0.20
# Episode: 780  Reward: -3157 Explore: 0.20
# Episode: 781  Reward: -3147 Explore: 0.20
# Episode: 782  Reward: -3088 Explore: 0.20
# Episode: 783  Reward: -3027 Explore: 0.20
# Episode: 784  Reward: -3074 Explore: 0.20
# Episode: 785  Reward: -3067 Explore: 0.20
# Episode: 786  Reward: -3092 Explore: 0.20
# Episode: 787  Reward: -3160 Explore: 0.20
# Episode: 788  Reward: -3086 Explore: 0.20
# Episode: 789  Reward: -3039 Explore: 0.20
# Episode: 790  Reward: -3090 Explore: 0.20
# Episode: 791  Reward: -3052 Explore: 0.20
# Episode: 792  Reward: -3016 Explore: 0.20
# Episode: 793  Reward: -3185 Explore: 0.20
# Episode: 794  Reward: -3089 Explore: 0.20
# Episode: 795  Reward: -2981 Explore: 0.20
# Episode: 796  Reward: -3072 Explore: 0.20
# Episode: 797  Reward: -3064 Explore: 0.20
# Episode: 798  Reward: -3049 Explore: 0.20
# Episode: 799  Reward: -2993 Explore: 0.20
# Episode: 800  Reward: -3041 Explore: 0.20
# Episode: 801  Reward: -3097 Explore: 0.20
# Episode: 802  Reward: -3141 Explore: 0.20
# Episode: 803  Reward: -3125 Explore: 0.20
# Episode: 804  Reward: -3024 Explore: 0.20
# Episode: 805  Reward: -3049 Explore: 0.20
# Episode: 806  Reward: -3130 Explore: 0.20
# Episode: 807  Reward: -3018 Explore: 0.20
# Episode: 808  Reward: -3018 Explore: 0.20
# Episode: 809  Reward: -3137 Explore: 0.20
# Episode: 810  Reward: -2980 Explore: 0.20
# Episode: 811  Reward: -3077 Explore: 0.20
# Episode: 812  Reward: -3065 Explore: 0.20
# Episode: 813  Reward: -3095 Explore: 0.20
# Episode: 814  Reward: -3086 Explore: 0.20
# Episode: 815  Reward: -3073 Explore: 0.20
# Episode: 816  Reward: -3072 Explore: 0.20
# Episode: 817  Reward: -3053 Explore: 0.20
# Episode: 818  Reward: -3046 Explore: 0.20
# Episode: 819  Reward: -3077 Explore: 0.20
# Episode: 820  Reward: -3136 Explore: 0.20
# Episode: 821  Reward: -3033 Explore: 0.20
# Episode: 822  Reward: -3069 Explore: 0.20
# Episode: 823  Reward: -3106 Explore: 0.20
# Episode: 824  Reward: -3106 Explore: 0.20
# Episode: 825  Reward: -3071 Explore: 0.20
# Episode: 826  Reward: -3136 Explore: 0.20
# Episode: 827  Reward: -3107 Explore: 0.20
# Episode: 828  Reward: -3005 Explore: 0.20
# Episode: 829  Reward: -3106 Explore: 0.20
# Episode: 830  Reward: -3069 Explore: 0.20
# Episode: 831  Reward: -3161 Explore: 0.20
# Episode: 832  Reward: -3092 Explore: 0.20
# Episode: 833  Reward: -3043 Explore: 0.20
# Episode: 834  Reward: -3043 Explore: 0.20
# Episode: 835  Reward: -3059 Explore: 0.20
# Episode: 836  Reward: -3066 Explore: 0.20
# Episode: 837  Reward: -3117 Explore: 0.20
# Episode: 838  Reward: -3048 Explore: 0.20
# Episode: 839  Reward: -3080 Explore: 0.20
# Episode: 840  Reward: -3114 Explore: 0.20
# Episode: 841  Reward: -3030 Explore: 0.20
# Episode: 842  Reward: -3132 Explore: 0.20
# Episode: 843  Reward: -3057 Explore: 0.20
# Episode: 844  Reward: -3106 Explore: 0.20
# Episode: 845  Reward: -3109 Explore: 0.20
# Episode: 846  Reward: -3054 Explore: 0.20
# Episode: 847  Reward: -3107 Explore: 0.20
# Episode: 848  Reward: -3047 Explore: 0.20
# Episode: 849  Reward: -3040 Explore: 0.20
# Episode: 850  Reward: -3042 Explore: 0.20
# Episode: 851  Reward: -3151 Explore: 0.20
# Episode: 852  Reward: -3103 Explore: 0.20
# Episode: 853  Reward: -3110 Explore: 0.20
# Episode: 854  Reward: -3115 Explore: 0.20
# Episode: 855  Reward: -3048 Explore: 0.20
# Episode: 856  Reward: -3169 Explore: 0.20
# Episode: 857  Reward: -2995 Explore: 0.20
# Episode: 858  Reward: -3101 Explore: 0.20
# Episode: 859  Reward: -3037 Explore: 0.20
# Episode: 860  Reward: -3081 Explore: 0.20
# Episode: 861  Reward: -3120 Explore: 0.20
# Episode: 862  Reward: -3064 Explore: 0.20
# Episode: 863  Reward: -3023 Explore: 0.20
# Episode: 864  Reward: -3088 Explore: 0.20
# Episode: 865  Reward: -3113 Explore: 0.20
# Episode: 866  Reward: -3063 Explore: 0.20
# Episode: 867  Reward: -3110 Explore: 0.20
# Episode: 868  Reward: -3088 Explore: 0.20
# Episode: 869  Reward: -3077 Explore: 0.20
# Episode: 870  Reward: -3224 Explore: 0.20
# Episode: 871  Reward: -3040 Explore: 0.20
# Episode: 872  Reward: -3070 Explore: 0.20
# Episode: 873  Reward: -3102 Explore: 0.20
# Episode: 874  Reward: -3089 Explore: 0.20
# Episode: 875  Reward: -3101 Explore: 0.20
# Episode: 876  Reward: -3124 Explore: 0.20
# Episode: 877  Reward: -3058 Explore: 0.20
# Episode: 878  Reward: -2984 Explore: 0.20
# Episode: 879  Reward: -3204 Explore: 0.20
# Episode: 880  Reward: -3117 Explore: 0.20
# Episode: 881  Reward: -3118 Explore: 0.20
# Episode: 882  Reward: -3065 Explore: 0.20
# Episode: 883  Reward: -3109 Explore: 0.20
# Episode: 884  Reward: -3160 Explore: 0.20
# Episode: 885  Reward: -3043 Explore: 0.20
# Episode: 886  Reward: -3134 Explore: 0.20
# Episode: 887  Reward: -3088 Explore: 0.20
# Episode: 888  Reward: -3051 Explore: 0.20
# Episode: 889  Reward: -3007 Explore: 0.20
# Episode: 890  Reward: -3166 Explore: 0.20
# Episode: 891  Reward: -3120 Explore: 0.20
# Episode: 892  Reward: -3088 Explore: 0.20
# Episode: 893  Reward: -3073 Explore: 0.20
# Episode: 894  Reward: -3124 Explore: 0.20
# Episode: 895  Reward: -3094 Explore: 0.20
# Episode: 896  Reward: -3115 Explore: 0.20
# Episode: 897  Reward: -3129 Explore: 0.20
# Episode: 898  Reward: -3102 Explore: 0.20
# Episode: 899  Reward: -3089 Explore: 0.20
# Episode: 900  Reward: -3036 Explore: 0.20
# Episode: 901  Reward: -3164 Explore: 0.20
# Episode: 902  Reward: -3109 Explore: 0.20
# Episode: 903  Reward: -3050 Explore: 0.20
# Episode: 904  Reward: -2994 Explore: 0.20
# Episode: 905  Reward: -3042 Explore: 0.20
# Episode: 906  Reward: -3148 Explore: 0.20
# Episode: 907  Reward: -3077 Explore: 0.20
# Episode: 908  Reward: -3062 Explore: 0.20
# Episode: 909  Reward: -3080 Explore: 0.20
# Episode: 910  Reward: -3099 Explore: 0.20
# Episode: 911  Reward: -3052 Explore: 0.20
# Episode: 912  Reward: -3061 Explore: 0.20
# Episode: 913  Reward: -3058 Explore: 0.20
# Episode: 914  Reward: -3026 Explore: 0.20
# Episode: 915  Reward: -3091 Explore: 0.20
# Episode: 916  Reward: -3129 Explore: 0.20
# Episode: 917  Reward: -3011 Explore: 0.20
# Episode: 918  Reward: -3172 Explore: 0.20
# Episode: 919  Reward: -3025 Explore: 0.20
# Episode: 920  Reward: -3140 Explore: 0.20
# Episode: 921  Reward: -3118 Explore: 0.20
# Episode: 922  Reward: -3009 Explore: 0.20
# Episode: 923  Reward: -3075 Explore: 0.20
# Episode: 924  Reward: -3055 Explore: 0.20
# Episode: 925  Reward: -3074 Explore: 0.20
# Episode: 926  Reward: -3040 Explore: 0.20
# Episode: 927  Reward: -3052 Explore: 0.20
# Episode: 928  Reward: -3093 Explore: 0.20
# Episode: 929  Reward: -3093 Explore: 0.20
# Episode: 930  Reward: -3121 Explore: 0.20
# Episode: 931  Reward: -3076 Explore: 0.20
# Episode: 932  Reward: -3041 Explore: 0.20
# Episode: 933  Reward: -3033 Explore: 0.20
# Episode: 934  Reward: -3093 Explore: 0.20
# Episode: 935  Reward: -3184 Explore: 0.20
# Episode: 936  Reward: -3092 Explore: 0.20
# Episode: 937  Reward: -3031 Explore: 0.20
# Episode: 938  Reward: -3118 Explore: 0.20
# Episode: 939  Reward: -3027 Explore: 0.20
# Episode: 940  Reward: -3166 Explore: 0.20
# Episode: 941  Reward: -2996 Explore: 0.20
# Episode: 942  Reward: -3132 Explore: 0.20
# Episode: 943  Reward: -3095 Explore: 0.20
# Episode: 944  Reward: -3122 Explore: 0.20
# Episode: 945  Reward: -3058 Explore: 0.20
# Episode: 946  Reward: -3083 Explore: 0.20
# Episode: 947  Reward: -3057 Explore: 0.20
# Episode: 948  Reward: -3070 Explore: 0.20
# Episode: 949  Reward: -3059 Explore: 0.20
# Episode: 950  Reward: -3036 Explore: 0.20
# Episode: 951  Reward: -3056 Explore: 0.20
# Episode: 952  Reward: -2912 Explore: 0.20
# Episode: 953  Reward: -3177 Explore: 0.20
# Episode: 954  Reward: -3063 Explore: 0.20
# Episode: 955  Reward: -3064 Explore: 0.20
# Episode: 956  Reward: -3080 Explore: 0.20
# Episode: 957  Reward: -3024 Explore: 0.20
# Episode: 958  Reward: -3096 Explore: 0.20
# Episode: 959  Reward: -3098 Explore: 0.20
# Episode: 960  Reward: -3092 Explore: 0.20
# Episode: 961  Reward: -3049 Explore: 0.20
# Episode: 962  Reward: -3150 Explore: 0.20
# Episode: 963  Reward: -3103 Explore: 0.20
# Episode: 964  Reward: -3125 Explore: 0.20
# Episode: 965  Reward: -3059 Explore: 0.20
# Episode: 966  Reward: -3135 Explore: 0.20
# Episode: 967  Reward: -3117 Explore: 0.20
# Episode: 968  Reward: -3144 Explore: 0.20
# Episode: 969  Reward: -3056 Explore: 0.20
# Episode: 970  Reward: -3067 Explore: 0.20
# Episode: 971  Reward: -3093 Explore: 0.20
# Episode: 972  Reward: -3050 Explore: 0.20
# Episode: 973  Reward: -3115 Explore: 0.20
# Episode: 974  Reward: -3107 Explore: 0.20
# Episode: 975  Reward: -3114 Explore: 0.20
# Episode: 976  Reward: -3176 Explore: 0.20
# Episode: 977  Reward: -2985 Explore: 0.20
# Episode: 978  Reward: -2994 Explore: 0.20
# Episode: 979  Reward: -3063 Explore: 0.20
# Episode: 980  Reward: -3083 Explore: 0.20
# Episode: 981  Reward: -3157 Explore: 0.20
# Episode: 982  Reward: -3073 Explore: 0.20
# Episode: 983  Reward: -3118 Explore: 0.20
# Episode: 984  Reward: -3140 Explore: 0.20
# Episode: 985  Reward: -3070 Explore: 0.20
# Episode: 986  Reward: -3060 Explore: 0.20
# Episode: 987  Reward: -3191 Explore: 0.20
# Episode: 988  Reward: -3117 Explore: 0.20
# Episode: 989  Reward: -3073 Explore: 0.20
# Episode: 990  Reward: -3064 Explore: 0.20
# Episode: 991  Reward: -3078 Explore: 0.20
# Episode: 992  Reward: -3027 Explore: 0.20
# Episode: 993  Reward: -3034 Explore: 0.20
# Episode: 994  Reward: -3123 Explore: 0.20
# Episode: 995  Reward: -3061 Explore: 0.20
# Episode: 996  Reward: -3084 Explore: 0.20
# Episode: 997  Reward: -3152 Explore: 0.20
# Episode: 998  Reward: -3001 Explore: 0.20
# Episode: 999  Reward: -3147 Explore: 0.20
# Episode: 1000  Reward: -3136 Explore: 0.20
# Episode: 1001  Reward: -3085 Explore: 0.20
# Episode: 1002  Reward: -3106 Explore: 0.20
# Episode: 1003  Reward: -3080 Explore: 0.20
# Episode: 1004  Reward: -3026 Explore: 0.20
# Episode: 1005  Reward: -3087 Explore: 0.20
# Episode: 1006  Reward: -3081 Explore: 0.20
# Episode: 1007  Reward: -3098 Explore: 0.20
# Episode: 1008  Reward: -3062 Explore: 0.20
# Episode: 1009  Reward: -3033 Explore: 0.20
# Episode: 1010  Reward: -3016 Explore: 0.20
# Episode: 1011  Reward: -3111 Explore: 0.20
# Episode: 1012  Reward: -3149 Explore: 0.20
# Episode: 1013  Reward: -3074 Explore: 0.20
# Episode: 1014  Reward: -3068 Explore: 0.20
# Episode: 1015  Reward: -3114 Explore: 0.20
# Episode: 1016  Reward: -3062 Explore: 0.20
# Episode: 1017  Reward: -3091 Explore: 0.20
# Episode: 1018  Reward: -3040 Explore: 0.20
# Episode: 1019  Reward: -3054 Explore: 0.20
# Episode: 1020  Reward: -3072 Explore: 0.20
# Episode: 1021  Reward: -3078 Explore: 0.20
# Episode: 1022  Reward: -3030 Explore: 0.20
# Episode: 1023  Reward: -3102 Explore: 0.20
# Episode: 1024  Reward: -3016 Explore: 0.20
# Episode: 1025  Reward: -3041 Explore: 0.20
# Episode: 1026  Reward: -3166 Explore: 0.20
# Episode: 1027  Reward: -3080 Explore: 0.20
# Episode: 1028  Reward: -3131 Explore: 0.20
# Episode: 1029  Reward: -3135 Explore: 0.20
# Episode: 1030  Reward: -3140 Explore: 0.20
# Episode: 1031  Reward: -3130 Explore: 0.20
# Episode: 1032  Reward: -3060 Explore: 0.20
# Episode: 1033  Reward: -3112 Explore: 0.20
# Episode: 1034  Reward: -3091 Explore: 0.20
# Episode: 1035  Reward: -3016 Explore: 0.20
# Episode: 1036  Reward: -3117 Explore: 0.20
# Episode: 1037  Reward: -3077 Explore: 0.20
# Episode: 1038  Reward: -3033 Explore: 0.20
# Episode: 1039  Reward: -3122 Explore: 0.20
# Episode: 1040  Reward: -3110 Explore: 0.20
# Episode: 1041  Reward: -3182 Explore: 0.20
# Episode: 1042  Reward: -3118 Explore: 0.20
# Episode: 1043  Reward: -3093 Explore: 0.20
# Episode: 1044  Reward: -3044 Explore: 0.20
# Episode: 1045  Reward: -3046 Explore: 0.20
# Episode: 1046  Reward: -3069 Explore: 0.20
# Episode: 1047  Reward: -3061 Explore: 0.20
# Episode: 1048  Reward: -3064 Explore: 0.20
# Episode: 1049  Reward: -3066 Explore: 0.20
# Episode: 1050  Reward: -3144 Explore: 0.20
# Episode: 1051  Reward: -3097 Explore: 0.20
# Episode: 1052  Reward: -3055 Explore: 0.20
# Episode: 1053  Reward: -3146 Explore: 0.20
# Episode: 1054  Reward: -3038 Explore: 0.20
# Episode: 1055  Reward: -3083 Explore: 0.20
# Episode: 1056  Reward: -3188 Explore: 0.20
# Episode: 1057  Reward: -3178 Explore: 0.20
# Episode: 1058  Reward: -3055 Explore: 0.20
# Episode: 1059  Reward: -3061 Explore: 0.20
# Episode: 1060  Reward: -3158 Explore: 0.20
# Episode: 1061  Reward: -3074 Explore: 0.20
# Episode: 1062  Reward: -3086 Explore: 0.20
# Episode: 1063  Reward: -3083 Explore: 0.20
# Episode: 1064  Reward: -3112 Explore: 0.20
# Episode: 1065  Reward: -3091 Explore: 0.20
# Episode: 1066  Reward: -3080 Explore: 0.20
# Episode: 1067  Reward: -3032 Explore: 0.20
# Episode: 1068  Reward: -3093 Explore: 0.20
# Episode: 1069  Reward: -3157 Explore: 0.20
# Episode: 1070  Reward: -3137 Explore: 0.20
# Episode: 1071  Reward: -3034 Explore: 0.20
# Episode: 1072  Reward: -3151 Explore: 0.20
# Episode: 1073  Reward: -3078 Explore: 0.20
# Episode: 1074  Reward: -3058 Explore: 0.20
# Episode: 1075  Reward: -3088 Explore: 0.20
# Episode: 1076  Reward: -3061 Explore: 0.20
# Episode: 1077  Reward: -3106 Explore: 0.20
# Episode: 1078  Reward: -3044 Explore: 0.20
# Episode: 1079  Reward: -3038 Explore: 0.20
# Episode: 1080  Reward: -3072 Explore: 0.20
# Episode: 1081  Reward: -3027 Explore: 0.20
# Episode: 1082  Reward: -3105 Explore: 0.20
# Episode: 1083  Reward: -3055 Explore: 0.20
# Episode: 1084  Reward: -2990 Explore: 0.20
# Episode: 1085  Reward: -3113 Explore: 0.20
# Episode: 1086  Reward: -3003 Explore: 0.20
# Episode: 1087  Reward: -3054 Explore: 0.20
# Episode: 1088  Reward: -3119 Explore: 0.20
# Episode: 1089  Reward: -3095 Explore: 0.20
# Episode: 1090  Reward: -3083 Explore: 0.20
# Episode: 1091  Reward: -2988 Explore: 0.20
# Episode: 1092  Reward: -3173 Explore: 0.20
# Episode: 1093  Reward: -3051 Explore: 0.20
# Episode: 1094  Reward: -3135 Explore: 0.20
# Episode: 1095  Reward: -3047 Explore: 0.20
# Episode: 1096  Reward: -3038 Explore: 0.20
# Episode: 1097  Reward: -3095 Explore: 0.20
# Episode: 1098  Reward: -3106 Explore: 0.20
# Episode: 1099  Reward: -3140 Explore: 0.20
# Episode: 1100  Reward: -3048 Explore: 0.20
# Episode: 1101  Reward: -3136 Explore: 0.20
# Episode: 1102  Reward: -3107 Explore: 0.20
# Episode: 1103  Reward: -3079 Explore: 0.20
# Episode: 1104  Reward: -3110 Explore: 0.20
# Episode: 1105  Reward: -3109 Explore: 0.20
# Episode: 1106  Reward: -3017 Explore: 0.20
# Episode: 1107  Reward: -3180 Explore: 0.20
# Episode: 1108  Reward: -3051 Explore: 0.20
# Episode: 1109  Reward: -3008 Explore: 0.20
# Episode: 1110  Reward: -3150 Explore: 0.20
# Episode: 1111  Reward: -3108 Explore: 0.20
# Episode: 1112  Reward: -3166 Explore: 0.20
# Episode: 1113  Reward: -3085 Explore: 0.20
# Episode: 1114  Reward: -3147 Explore: 0.20
# Episode: 1115  Reward: -3125 Explore: 0.20
# Episode: 1116  Reward: -3029 Explore: 0.20
# Episode: 1117  Reward: -3112 Explore: 0.20
# Episode: 1118  Reward: -3158 Explore: 0.20
# Episode: 1119  Reward: -3090 Explore: 0.20
# Episode: 1120  Reward: -3098 Explore: 0.20
# Episode: 1121  Reward: -3025 Explore: 0.20
# Episode: 1122  Reward: -3127 Explore: 0.20
# Episode: 1123  Reward: -3111 Explore: 0.20
# Episode: 1124  Reward: -3131 Explore: 0.20
# Episode: 1125  Reward: -2976 Explore: 0.20
# Episode: 1126  Reward: -2960 Explore: 0.20
# Episode: 1127  Reward: -3102 Explore: 0.20
# Episode: 1128  Reward: -3123 Explore: 0.20
# Episode: 1129  Reward: -3056 Explore: 0.20
# Episode: 1130  Reward: -3134 Explore: 0.20
# Episode: 1131  Reward: -3091 Explore: 0.20
# Episode: 1132  Reward: -3134 Explore: 0.20
# Episode: 1133  Reward: -3110 Explore: 0.20
# Episode: 1134  Reward: -3096 Explore: 0.20
# Episode: 1135  Reward: -3051 Explore: 0.20
# Episode: 1136  Reward: -3051 Explore: 0.20
# Episode: 1137  Reward: -3042 Explore: 0.20
# Episode: 1138  Reward: -3015 Explore: 0.20
# Episode: 1139  Reward: -3049 Explore: 0.20
# Episode: 1140  Reward: -3113 Explore: 0.20
# Episode: 1141  Reward: -3015 Explore: 0.20
# Episode: 1142  Reward: -3010 Explore: 0.20
# Episode: 1143  Reward: -3102 Explore: 0.20
# Episode: 1144  Reward: -3067 Explore: 0.20
# Episode: 1145  Reward: -3049 Explore: 0.20
# Episode: 1146  Reward: -3005 Explore: 0.20
# Episode: 1147  Reward: -3111 Explore: 0.20
# Episode: 1148  Reward: -3070 Explore: 0.20
# Episode: 1149  Reward: -3128 Explore: 0.20
# Episode: 1150  Reward: -3012 Explore: 0.20
# Episode: 1151  Reward: -3093 Explore: 0.20
# Episode: 1152  Reward: -3052 Explore: 0.20
# Episode: 1153  Reward: -2955 Explore: 0.20
# Episode: 1154  Reward: -3024 Explore: 0.20
# Episode: 1155  Reward: -3103 Explore: 0.20
# Episode: 1156  Reward: -3024 Explore: 0.20
# Episode: 1157  Reward: -3126 Explore: 0.20
# Episode: 1158  Reward: -3117 Explore: 0.20
# Episode: 1159  Reward: -3118 Explore: 0.20
# Episode: 1160  Reward: -3056 Explore: 0.20
# Episode: 1161  Reward: -3108 Explore: 0.20
# Episode: 1162  Reward: -3041 Explore: 0.20
# Episode: 1163  Reward: -3137 Explore: 0.20
# Episode: 1164  Reward: -3079 Explore: 0.20
# Episode: 1165  Reward: -3095 Explore: 0.20
# Episode: 1166  Reward: -3000 Explore: 0.20
# Episode: 1167  Reward: -3134 Explore: 0.20
# Episode: 1168  Reward: -3179 Explore: 0.20
# Episode: 1169  Reward: -3073 Explore: 0.20
# Episode: 1170  Reward: -3078 Explore: 0.20
# Episode: 1171  Reward: -3082 Explore: 0.20
# Episode: 1172  Reward: -3044 Explore: 0.20
# Episode: 1173  Reward: -3161 Explore: 0.20
# Episode: 1174  Reward: -3042 Explore: 0.20
# Episode: 1175  Reward: -3098 Explore: 0.20
# Episode: 1176  Reward: -3060 Explore: 0.20
# Episode: 1177  Reward: -3108 Explore: 0.20
# Episode: 1178  Reward: -3048 Explore: 0.20
# Episode: 1179  Reward: -3034 Explore: 0.20
# Episode: 1180  Reward: -2951 Explore: 0.20
# Episode: 1181  Reward: -3091 Explore: 0.20
# Episode: 1182  Reward: -3092 Explore: 0.20
# Episode: 1183  Reward: -3047 Explore: 0.20
# Episode: 1184  Reward: -3038 Explore: 0.20
# Episode: 1185  Reward: -3070 Explore: 0.20
# Episode: 1186  Reward: -3069 Explore: 0.20
# Episode: 1187  Reward: -3100 Explore: 0.20
# Episode: 1188  Reward: -3095 Explore: 0.20
# Episode: 1189  Reward: -3184 Explore: 0.20
# Episode: 1190  Reward: -2979 Explore: 0.20
# Episode: 1191  Reward: -3058 Explore: 0.20
# Episode: 1192  Reward: -3113 Explore: 0.20
# Episode: 1193  Reward: -3080 Explore: 0.20
# Episode: 1194  Reward: -3111 Explore: 0.20
# Episode: 1195  Reward: -3113 Explore: 0.20
# Episode: 1196  Reward: -3123 Explore: 0.20
# Episode: 1197  Reward: -3047 Explore: 0.20
# Episode: 1198  Reward: -3001 Explore: 0.20
# Episode: 1199  Reward: -3194 Explore: 0.20
# Episode: 1200  Reward: -3012 Explore: 0.20
# Episode: 1201  Reward: -3080 Explore: 0.20
# Episode: 1202  Reward: -3099 Explore: 0.20
# Episode: 1203  Reward: -3045 Explore: 0.20
# Episode: 1204  Reward: -3115 Explore: 0.20
# Episode: 1205  Reward: -3075 Explore: 0.20
# Episode: 1206  Reward: -3002 Explore: 0.20
# Episode: 1207  Reward: -3100 Explore: 0.20
# Episode: 1208  Reward: -3092 Explore: 0.20
# Episode: 1209  Reward: -3017 Explore: 0.20
# Episode: 1210  Reward: -3045 Explore: 0.20
# Episode: 1211  Reward: -3061 Explore: 0.20
# Episode: 1212  Reward: -3026 Explore: 0.20
# Episode: 1213  Reward: -3064 Explore: 0.20
# Episode: 1214  Reward: -3212 Explore: 0.20
# Episode: 1215  Reward: -3022 Explore: 0.20
# Episode: 1216  Reward: -3059 Explore: 0.20
# Episode: 1217  Reward: -3049 Explore: 0.20
# Episode: 1218  Reward: -3085 Explore: 0.20
# Episode: 1219  Reward: -3049 Explore: 0.20
# Episode: 1220  Reward: -3093 Explore: 0.20
# Episode: 1221  Reward: -3098 Explore: 0.20
# Episode: 1222  Reward: -3028 Explore: 0.20
# Episode: 1223  Reward: -3112 Explore: 0.20
# Episode: 1224  Reward: -3135 Explore: 0.20
# Episode: 1225  Reward: -3056 Explore: 0.20
# Episode: 1226  Reward: -3102 Explore: 0.20
# Episode: 1227  Reward: -3034 Explore: 0.20
# Episode: 1228  Reward: -3074 Explore: 0.20
# Episode: 1229  Reward: -3071 Explore: 0.20
# Episode: 1230  Reward: -3094 Explore: 0.20
# Episode: 1231  Reward: -3063 Explore: 0.20
# Episode: 1232  Reward: -3105 Explore: 0.20
# Episode: 1233  Reward: -3057 Explore: 0.20
# Episode: 1234  Reward: -2977 Explore: 0.20
# Episode: 1235  Reward: -3152 Explore: 0.20
# Episode: 1236  Reward: -3047 Explore: 0.20
# Episode: 1237  Reward: -3078 Explore: 0.20
# Episode: 1238  Reward: -3099 Explore: 0.20
# Episode: 1239  Reward: -3052 Explore: 0.20
# Episode: 1240  Reward: -3063 Explore: 0.20
# Episode: 1241  Reward: -3189 Explore: 0.20
# Episode: 1242  Reward: -3013 Explore: 0.20
# Episode: 1243  Reward: -3080 Explore: 0.20
# Episode: 1244  Reward: -3070 Explore: 0.20
# Episode: 1245  Reward: -3018 Explore: 0.20
# Episode: 1246  Reward: -3080 Explore: 0.20
# Episode: 1247  Reward: -3096 Explore: 0.20
# Episode: 1248  Reward: -3024 Explore: 0.20
# Episode: 1249  Reward: -3029 Explore: 0.20
# Episode: 1250  Reward: -3171 Explore: 0.20
# Episode: 1251  Reward: -2976 Explore: 0.20
# Episode: 1252  Reward: -3029 Explore: 0.20
# Episode: 1253  Reward: -3062 Explore: 0.20
# Episode: 1254  Reward: -3131 Explore: 0.20
# Episode: 1255  Reward: -3072 Explore: 0.20
# Episode: 1256  Reward: -3076 Explore: 0.20
# Episode: 1257  Reward: -3119 Explore: 0.20
# Episode: 1258  Reward: -3082 Explore: 0.20
# Episode: 1259  Reward: -3173 Explore: 0.20
# Episode: 1260  Reward: -3104 Explore: 0.20
# Episode: 1261  Reward: -3060 Explore: 0.20
# Episode: 1262  Reward: -3040 Explore: 0.20
# Episode: 1263  Reward: -3066 Explore: 0.20
# Episode: 1264  Reward: -3108 Explore: 0.20
# Episode: 1265  Reward: -2982 Explore: 0.20
# Episode: 1266  Reward: -3129 Explore: 0.20
# Episode: 1267  Reward: -3112 Explore: 0.20
# Episode: 1268  Reward: -3037 Explore: 0.20
# Episode: 1269  Reward: -3038 Explore: 0.20
# Episode: 1270  Reward: -3038 Explore: 0.20
# Episode: 1271  Reward: -3114 Explore: 0.20
# Episode: 1272  Reward: -3047 Explore: 0.20
# Episode: 1273  Reward: -3080 Explore: 0.20
# Episode: 1274  Reward: -3107 Explore: 0.20
# Episode: 1275  Reward: -3066 Explore: 0.20
# Episode: 1276  Reward: -3065 Explore: 0.20
# Episode: 1277  Reward: -3020 Explore: 0.20
# Episode: 1278  Reward: -3084 Explore: 0.20
# Episode: 1279  Reward: -3139 Explore: 0.20
# Episode: 1280  Reward: -3050 Explore: 0.20
# Episode: 1281  Reward: -3062 Explore: 0.20
# Episode: 1282  Reward: -3201 Explore: 0.20
# Episode: 1283  Reward: -3057 Explore: 0.20
# Episode: 1284  Reward: -3037 Explore: 0.20
# Episode: 1285  Reward: -3097 Explore: 0.20
# Episode: 1286  Reward: -3010 Explore: 0.20
# Episode: 1287  Reward: -3132 Explore: 0.20
# Episode: 1288  Reward: -3006 Explore: 0.20
# Episode: 1289  Reward: -3097 Explore: 0.20
# Episode: 1290  Reward: -3013 Explore: 0.20
# Episode: 1291  Reward: -3131 Explore: 0.20
# Episode: 1292  Reward: -3040 Explore: 0.20
# Episode: 1293  Reward: -3160 Explore: 0.20
# Episode: 1294  Reward: -3201 Explore: 0.20
# Episode: 1295  Reward: -3084 Explore: 0.20
# Episode: 1296  Reward: -3033 Explore: 0.20
# Episode: 1297  Reward: -3015 Explore: 0.20
# Episode: 1298  Reward: -3082 Explore: 0.20
# Episode: 1299  Reward: -3056 Explore: 0.20
# Episode: 1300  Reward: -3036 Explore: 0.20
# Episode: 1301  Reward: -3131 Explore: 0.20
# Episode: 1302  Reward: -3117 Explore: 0.20
# Episode: 1303  Reward: -3081 Explore: 0.20
# Episode: 1304  Reward: -3063 Explore: 0.20
# Episode: 1305  Reward: -3074 Explore: 0.20
# Episode: 1306  Reward: -3074 Explore: 0.20
# Episode: 1307  Reward: -2927 Explore: 0.20
# Episode: 1308  Reward: -3074 Explore: 0.20
# Episode: 1309  Reward: -3000 Explore: 0.20
# Episode: 1310  Reward: -3133 Explore: 0.20
# Episode: 1311  Reward: -3046 Explore: 0.20
# Episode: 1312  Reward: -3083 Explore: 0.20
# Episode: 1313  Reward: -3116 Explore: 0.20
# Episode: 1314  Reward: -3166 Explore: 0.20
# Episode: 1315  Reward: -3053 Explore: 0.20
# Episode: 1316  Reward: -3058 Explore: 0.20
# Episode: 1317  Reward: -3060 Explore: 0.20
# Episode: 1318  Reward: -3053 Explore: 0.20
# Episode: 1319  Reward: -3096 Explore: 0.20
# Episode: 1320  Reward: -3080 Explore: 0.20
# Episode: 1321  Reward: -3042 Explore: 0.20
# Episode: 1322  Reward: -3076 Explore: 0.20
# Episode: 1323  Reward: -3051 Explore: 0.20
# Episode: 1324  Reward: -3050 Explore: 0.20
# Episode: 1325  Reward: -3073 Explore: 0.20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2817/1608176977.py in <module>
#      57             if var > var_low_bound:
#      58                 var *= .9998                            # 学习阶段逐渐降低动作随机性decay the action randomness
# ---> 59             ddpg.learn()                                # 开始学习
#      60
#      61         s = s_
#
# /tmp/ipykernel_2817/54171186.py in learn(self)
#     136         for x in self.Actor_target.state_dict().keys():#更新target network
#     137             eval('self.Actor_target.' + x + '.data.mul_((1 - self.tau))')
# --> 138             eval('self.Actor_target.' + x + '.data.add_(self.tau * self.Actor_eval.' + x + '.data)')
#     139         for x in self.Critic_target.state_dict().keys():
#     140             eval('self.Critic_target.' + x + '.data.mul_((1- self.tau))')
#
# <string> in <module>
#
# KeyboardInterrupt:

# %%
ddpg.save('carbinet_1000epi_four1024layers')

# %%
ddpg.plot_rewards(scatter = True)

# %%
info
# Out:
# {'eval_info': {'cabinet_static': True, 'open_enough': False, 'success': False},
#  'dist_ee_to_handle': array([1.32828861, 1.30526796]),
#  'angle1': 1.1766494349134005,
#  'angle2': 1.5317321746066244,
#  'dist_ee_mid_to_handle': -1.3160184768477239,
#  'rew_ee_handle': -2.6335565692093796,
#  'rew_ee_mid_handle': -1.0,
#  'qpos_rew': 0,
#  'qvel_rew': 0,
#  'gripper_angle_err': 67.4170465869911,
#  'gripper_angle_rew': -1.1236174431165185,
#  'gripper_vel_norm': 0.0,
#  'gripper_ang_vel_norm': 0.0,
#  'qpos': 0.0,
#  'qvel': 0.0,
#  'target_qpos': 0.23135713040828706,
#  'reward_raw': -6.757174012325898,
#  'stage_reward': -7.0,
#  'TimeLimit.truncated': True}

# %%
y = ddpg.Reward_record
x = range(len(y))
plt.figure(figsize=(10, 10), dpi=70)
        
plt.scatter(x, y)
#plt.plot(x, y)
plt.savefig('./scatter.png')
#plt.show()
