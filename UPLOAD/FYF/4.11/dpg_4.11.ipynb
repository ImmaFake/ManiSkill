# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import gym
import time
import mani_skill.env
import pandas as pd
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
from torch.distributions import Normal
import random
import time
use_cuda = torch.cuda.is_available()
device   = torch.device("cuda" if use_cuda else "cpu")

#####################  hyper parameters  ####################

MAX_EPISODES = 2001              
MAX_EP_STEPS = 60               

RENDER = False

LOAD_MEM = False
LOAD_MODEL = True
LOAD_FOLDER_NAME = 'carbinet_SELF_level_12789_4000+2000EPS'

LOAD_PRETRAIN = False

CHECK_POINT_EPI = 50


ENV_NAME = 'OpenCabinetDrawer-v0'       
SEED = 123                      

var = 5
var_low_bound = 0.05

# %%
###############################  DDPG  ####################################
class DDPG(object):
    def __init__(self, a_dim, s_dim, a_bound,hidden_dim):
        self.a_dim = a_dim
        self.s_dim = s_dim
        self.a_bound = a_bound
        self.hidden_dim = hidden_dim
        self.pointer = 0                                                                         # exp buffer指针
        self.lr_a = 0.001                                                                      # learning rate for actor
        self.lr_c = 0.001                                                                       # learning rate for critic
        self.gamma = 0.9                                                                         # reward discount
        self.tau = 0.001                                                                          # 软更新比例
        self.memory_capacity = 10000
        self.batch_size = 32
        self.memory = np.zeros((self.memory_capacity, s_dim * 2 + a_dim + 1), dtype=np.float32)

        self.Reward_record = []
        self.Success_record = np.zeros(MAX_EPISODES)
        
        class ANet(nn.Module):                               # 定义动作网络
            def __init__(self, s_dim, a_dim, a_bound,hidden_size):
                super(ANet,self).__init__()
                self.a_bound = a_bound
                
                self.linear1 = nn.Linear(s_dim, hidden_size)
                self.linear2 = nn.Linear(hidden_size, hidden_size)
                self.linear3 = nn.Linear(hidden_size, hidden_size)
                self.linear4 = nn.Linear(hidden_size, a_dim)
                
                
                self.linear4.weight.data.uniform_(-0.03, 0.03)
                self.linear4.bias.data.uniform_(-0.03, 0.03)
#                 self.fc1 = nn.Linear(s_dim,256)
#                 self.fc1.weight.data.normal_(0,0.1)          # initialization
                
#                 self.fc2 = nn.Linear(256,512)
#                 self.fc2.weight.data.normal_(0,0.1)
#                                
#                 self.fc3 = nn.Linear(512,256)
#                 self.fc3.weight.data.normal_(0,0.1)
                
#                 self.out = nn.Linear(256,a_dim)
#                 self.out.weight.data.normal_(0,0.1)          # initialization
            def forward(self,x):
                x = F.relu(self.linear1(x))
                x = F.relu(self.linear2(x))
                x = F.relu(self.linear3(x))
                x = F.tanh(self.linear4(x))
                
#                 x = self.fc1(x)
#                 x = F.relu(x)
#                  
#                 x = self.fc2(x)
#                 x = F.relu(x)
                
#                 x = self.fc3(x)
#                 x = F.relu(x)
                
#                 x = self.out(x)
#                 x = F.tanh(x)
                actions_value = x * a_bound
                return actions_value

        class CNet(nn.Module):                               # 定义价值网络
            def __init__(self,s_dim,a_dim,hidden_size):
                super(CNet,self).__init__()
                
                self.linear1 = nn.Linear(s_dim + a_dim, hidden_size)
                self.linear2 = nn.Linear(hidden_size, hidden_size)
#                 self.linear3 = nn.Linear(hidden_size, hidden_size)
                self.linear3 = nn.Linear(hidden_size, 1)
                

                self.linear3.weight.data.uniform_(-0.03,0.03)
                self.linear3.bias.data.uniform_(-0.03,0.03)

#                 self.fcs1 = nn.Linear(s_dim,256)
#                 self.fcs1.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01)
                
#                 self.fcs2 = nn.Linear(256,512)
#                 self.fcs2.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01)
                
#                 self.fcs3 = nn.Linear(512,256)
#                 self.fcs3.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01) 
                
#                 self.fca1 = nn.Linear(a_dim,256)
#                 self.fca1.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01)
                
#                 self.fca2 = nn.Linear(256,512)
#                 self.fca2.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01)              
                
#                 self.fca3 = nn.Linear(512,256)
#                 self.fca3.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01)
                
#                 self.out = nn.Linear(256,1)
#                 self.out.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01)
            def forward(self,s,a):
        
                x = torch.cat([s, a], 1)
                x = F.relu(self.linear1(x))
                x = F.relu(self.linear2(x))
#                 x = F.relu(self.linear3(x))
                x = self.linear3(x)

#                 x = self.fcs1(s)                              # 输入状态
#                 x = F.relu(x)
                
#                 x = self.fcs2(x)
#                 x = F.relu(x)
                
#                 x = self.fcs3(x)
#                 x = F.relu(x) 
                
#                 y = self.fca1(a)                              # 输入动作
#                 y = F.relu(y)
                
#                 y = self.fca2(y)                              
#                 y = F.relu(y)
                
#                 y = self.fca3(y)                              
#                 y = F.relu(y)
                
#                 net = F.relu(x+y)
#                 actions_value = self.out(net)                # 给出V(s,a)
                return x

        self.Actor_eval = ANet(s_dim, a_dim, a_bound, hidden_dim)        # 主网络
        self.Actor_target = ANet(s_dim, a_dim, a_bound, hidden_dim)      # 目标网络
        self.Critic_eval = CNet(s_dim, a_dim,hidden_dim)                # 主网络
        self.Critic_target = CNet(s_dim, a_dim,hidden_dim)              # 当前网络
        self.ctrain = torch.optim.Adam(self.Critic_eval.parameters(),lr = self.lr_c) # critic的优化器
        self.atrain = torch.optim.Adam(self.Actor_eval.parameters(),lr = self.lr_a)  # actor的优化器
        self.loss_td = nn.MSELoss()                          # 损失函数采用均方误差

    def choose_action(self, s):
        s = torch.unsqueeze(torch.FloatTensor(s), 0)

        return self.Actor_eval(s)[0].detach()                

    def learn(self):
        #self.atrain = torch.optim.Adam(self.Actor_eval.parameters(),lr = lr_a)  # actor的优化器
        #self.ctrain = torch.optim.Adam(self.Critic_eval.parameters(),lr = lr_c) # critic的优化器
        for x in self.Actor_target.state_dict().keys():#更新target network
            eval('self.Actor_target.' + x + '.data.mul_((1 - self.tau))')  
            eval('self.Actor_target.' + x + '.data.add_(self.tau * self.Actor_eval.' + x + '.data)')
        for x in self.Critic_target.state_dict().keys():
            eval('self.Critic_target.' + x + '.data.mul_((1- self.tau))')
            eval('self.Critic_target.' + x + '.data.add_(self.tau * self.Critic_eval.' + x + '.data)')

        # soft target replacement

        indices = np.random.choice(self.memory_capacity, size = self.batch_size)  # 随机采样的index
        bt = self.memory[indices, :]                                              # 采样batch_size个sample
        bs = torch.FloatTensor(bt[:, :self.s_dim])                                # state
        ba = torch.FloatTensor(bt[:, self.s_dim: self.s_dim + self.a_dim])        # action
        br = torch.FloatTensor(bt[:, -self.s_dim - 1: -self.s_dim])               # reward
        bs_ = torch.FloatTensor(bt[:, -self.s_dim:])                              # next state
        
        
        a = self.Actor_eval(bs)
        q = self.Critic_eval(bs,a)  

        loss_a = -torch.mean(q)            
        #print('q: ',q)
        #print('loss_a: ',loss_a)
        self.atrain.zero_grad()
        loss_a.backward()
        self.atrain.step()
        
        
        a_ = self.Actor_target(bs_)      
        q_ = self.Critic_target(bs_,a_)  
        q_target = br + self.gamma * q_  

        q_v = self.Critic_eval(bs,ba)

        td_error = self.loss_td(q_target,q_v)

        self.ctrain.zero_grad()
        td_error.backward()
        self.ctrain.step()
        
        
    def store_transition(self, s, a, r, s_):
        transition = np.hstack((s, a, [r], s_))
        index = self.pointer % self.memory_capacity     # replace the old memory with new memory
        self.memory[index, :] = transition
        self.pointer += 1                              
    
    def store_reward(self,ep_reward):
        self.Reward_record.append(ep_reward)
        
    def Record_success(self,epi):
        self.Success_record[epi] = 1
        
    def save(self,folder_name):
    
        if os.path.exists('./DPG model/' + folder_name):
            os.remove('./DPG model/' + folder_name)
            
        os.mkdir('./DPG model/' + folder_name)
    
        PATH1 = './DPG model/' + folder_name + '/Actor_eval.h5f'
        PATH2 = './DPG model/' + folder_name + '/Actor_target.h5f'
        PATH3 = './DPG model/' + folder_name + '/Critic_eval.h5f'
        PATH4 = './DPG model/' + folder_name + '/Critic_target.h5f'
    
        torch.save(self.Actor_eval.state_dict(), PATH1)
        torch.save(self.Actor_target.state_dict(), PATH2)
        torch.save(self.Critic_eval.state_dict(), PATH3)
        torch.save(self.Critic_target.state_dict(), PATH4)
    
        csv_name='./DPG model/' + folder_name + '/memory.csv'
        xml_df = pd.DataFrame(self.memory)
        xml_df.to_csv(csv_name, index = None, columns= None)
        
        csv_name='./DPG model/' + folder_name + '/Rewards.csv'
        xml_df = pd.DataFrame(self.Reward_record)
        xml_df.to_csv(csv_name, index = None, columns= None)
        
        csv_name='./DPG model/' + folder_name + '/Success_record.csv'
        xml_df = pd.DataFrame(self.Success_record)
        xml_df.to_csv(csv_name, index = None, columns= None)
        
        y = self.Reward_record
        x = range(len(y))
        plt.figure(figsize=(10, 10), dpi=70)
        plt.scatter(x, y)
        plt.savefig('./DPG model/' + folder_name + '/scatter.png')
        plt.plot(x, y)
        plt.savefig('./DPG model/' + folder_name + '/plot.png')
        
    def plot_file_rewards(self, folder_name):
        data = pd.read_csv('./DPG model/' + folder_name + '/Rewards.csv')
        y = np.array(data).squeeze()
        x = range(y.shape[0])
        plt.figure(figsize=(10, 10), dpi=70)
        #plt.plot(x, y)
        plt.scatter(x, y)
        plt.show()
    
    def plot_rewards(self, scatter):
        y = self.Reward_record
        x = range(len(y))
        plt.figure(figsize=(10, 10), dpi=70)
        
        if scatter:
            plt.scatter(x, y)
        else:
            plt.plot(x, y)
        plt.show()
    
    def load_model(self):
        self.Actor_eval.load_state_dict(torch.load('./DPG model/' + LOAD_FOLDER_NAME + '/Actor_eval.h5f'))
        self.Actor_eval.eval()
        self.Actor_target.load_state_dict(torch.load('./DPG model/' + LOAD_FOLDER_NAME + '/Actor_target.h5f'))
        self.Actor_target.eval()
        self.Critic_eval.load_state_dict(torch.load('./DPG model/' + LOAD_FOLDER_NAME + '/Critic_eval.h5f'))
        self.Critic_eval.eval()
        self.Critic_target.load_state_dict(torch.load('./DPG model/' + LOAD_FOLDER_NAME + '/Critic_target.h5f'))
        self.Critic_target.eval()
        print("Load network parameters of: " + LOAD_FOLDER_NAME) 
        
    def load_memory(self):
        data = pd.read_csv('./DPG model/' + LOAD_FOLDER_NAME + '/memory.csv')
        self.memory = np.array(data)
        print("Load memory of: " + LOAD_FOLDER_NAME)
        
    def load_pretrain(self):    
        ddpg.Actor_eval.load_state_dict(torch.load('./DPG model/pretrain/Actor_eval.h5f'))
        ddpg.Actor_eval.eval()
        ddpg.Actor_target.load_state_dict(torch.load('./DPG model/pretrain/Actor_eval.h5f'))
        ddpg.Actor_target.eval() 
#         ddpg.Critic_eval.load_state_dict(torch.load('./DPG model/pretrain/Critic_eval.h5f'))
#         ddpg.Critic_eval.eval()
#         ddpg.Critic_target.load_state_dict(torch.load('./DPG model/pretrain/Critic_eval.h5f'))
#         ddpg.Critic_target.eval()

# %%
##############################  training  ####################################
env = gym.make(ENV_NAME)
env = env.unwrapped
env.seed(SEED)                                          # 设置Gym的随机数种子
torch.manual_seed(SEED)                                 # 设置pytorch的随机数种子

env.set_env_mode(obs_mode='state', reward_type='dense')

s_dim = env.observation_space.shape[0]                  # 状态空间
a_dim = env.action_space.shape[0]                       # 动作空间
a_bound = 1                                             # 动作取值区间,对称区间，故只取上界
hidden_dim = 512
#lr_a = 0.001
#lr_c = 0.001
ddpg = DDPG(a_dim, s_dim, a_bound, hidden_dim)

if LOAD_MODEL:
    ddpg.load_model()

    
if LOAD_MEM:
    ddpg.load_memory()

if LOAD_PRETRAIN:
    ddpg.load_pretrain()


if LOAD_MODEL or LOAD_MEM:
    var = 0.1

if LOAD_PRETRAIN:
    var = 0.2

list = [1, 2, 7, 8, 9, 11, 14, 18, 33]
t1 = time.time()                                        # 开始时间

for i in range(MAX_EPISODES):
    LEVEL = random.choice(list)
    s = env.reset(level = LEVEL)
    #s = env.reset(level = int(random.choice([1,2,7,8,9])))
    ep_reward = 0
    
    #if i > 500:
        
     #   if lr_a >= 0.000001:
      #      lr_a = lr_a - 0.0000001
       # if lr_c >= 0.000001:
        #    lr_c = lr_c - 0.0000001
    
    for j in range(MAX_EP_STEPS):
        if RENDER:
            env.render('human')

        # Add exploration noise
        a = ddpg.choose_action(s)

        a = np.clip(np.random.normal(a, var), -1, 1)    # add randomness to action selection for exploration

        s_, r, done, info = env.step(a)
        
        info_ = info.get('eval_info')
        
        if info_.get('success'):
            print('SUCCESS')
            ddpg.Record_success(i)
            r += 100 #+200
        
        r += 10
        r = r * 200
        r+= 200
        r += info.get('qpos') * 4000
        #print(r)
        ddpg.store_transition(s, a, r, s_)         # 为什么要对reward归一化
    
        
        if ddpg.pointer > ddpg.memory_capacity or LOAD_MEM:         # 经验池已满
            if var > var_low_bound:
                var *= .9995                            # 学习阶段逐渐降低动作随机性decay the action randomness
            ddpg.learn()                                # 开始学习

        s = s_
        ep_reward += r
        if j == MAX_EP_STEPS -1 or done:
            print('Episode:', i, ' Reward: %i' % int(ep_reward/j), 'Explore: %.2f' % var, )
            
            ddpg.store_reward(ep_reward/j)
            
            #if ddpg.pointer > ddpg.memory_capacity and done:
                #RENDER = True
            if (i % CHECK_POINT_EPI) == 0 and i != 0:
                ddpg.save('level_9_4000+2000/' + str(i) + 'epi')
            
            break
               
print('Running time: ', time.time() - t1)
# Out:
# Load network parameters of: carbinet_SELF_level_12789_4000+2000EPS
# Episode: 0  Reward: 55 Explore: 0.10
# SUCCESS
# Episode: 1  Reward: 1477 Explore: 0.10
# Episode: 2  Reward: 20 Explore: 0.10
# Episode: 3  Reward: -4 Explore: 0.10
# Episode: 4  Reward: -166 Explore: 0.10
# Episode: 5  Reward: 14 Explore: 0.10
# Episode: 6  Reward: 172 Explore: 0.10
# Episode: 7  Reward: -4 Explore: 0.10
# Episode: 8  Reward: 68 Explore: 0.10
# Episode: 9  Reward: -54 Explore: 0.10
# Episode: 10  Reward: -253 Explore: 0.10
# Episode: 11  Reward: 39 Explore: 0.10
# Episode: 12  Reward: -329 Explore: 0.10
# Episode: 13  Reward: -163 Explore: 0.10
# Episode: 14  Reward: -152 Explore: 0.10
# Episode: 15  Reward: -222 Explore: 0.10
# Episode: 16  Reward: -24 Explore: 0.10
# Episode: 17  Reward: -18 Explore: 0.10
# Episode: 18  Reward: -156 Explore: 0.10
# Episode: 19  Reward: -175 Explore: 0.10
# Episode: 20  Reward: -39 Explore: 0.10
# Episode: 21  Reward: -321 Explore: 0.10
# Episode: 22  Reward: 16 Explore: 0.10
# Episode: 23  Reward: -282 Explore: 0.10
# Episode: 24  Reward: -13 Explore: 0.10
# SUCCESS
# Episode: 25  Reward: 782 Explore: 0.10
# Episode: 26  Reward: 26 Explore: 0.10
# Episode: 27  Reward: -50 Explore: 0.10
# Episode: 28  Reward: 29 Explore: 0.10
# Episode: 29  Reward: 22 Explore: 0.10
# Episode: 30  Reward: 16 Explore: 0.10
# SUCCESS
# Episode: 31  Reward: 1070 Explore: 0.10
# SUCCESS
# Episode: 32  Reward: 888 Explore: 0.10
# Episode: 33  Reward: 96 Explore: 0.10
# SUCCESS
# Episode: 34  Reward: 1393 Explore: 0.10
# Episode: 35  Reward: 288 Explore: 0.10
# Episode: 36  Reward: 67 Explore: 0.10
# Episode: 37  Reward: 15 Explore: 0.10
# SUCCESS
# Episode: 38  Reward: 1235 Explore: 0.10
# Episode: 39  Reward: -367 Explore: 0.10
# Episode: 40  Reward: -346 Explore: 0.10
# Episode: 41  Reward: -173 Explore: 0.10
# Episode: 42  Reward: 26 Explore: 0.10
# Episode: 43  Reward: -238 Explore: 0.10
# Episode: 44  Reward: 15 Explore: 0.10
# Episode: 45  Reward: 17 Explore: 0.10
# Episode: 46  Reward: 60 Explore: 0.10
# SUCCESS
# Episode: 47  Reward: 821 Explore: 0.10
# Episode: 48  Reward: -166 Explore: 0.10
# Episode: 49  Reward: -7 Explore: 0.10
# Episode: 50  Reward: 261 Explore: 0.10
# Episode: 51  Reward: 46 Explore: 0.10
# Episode: 52  Reward: -218 Explore: 0.10
# Episode: 53  Reward: -204 Explore: 0.10
# Episode: 54  Reward: -51 Explore: 0.10
# SUCCESS
# Episode: 55  Reward: 630 Explore: 0.10
# Episode: 56  Reward: 12 Explore: 0.10
# Episode: 57  Reward: -310 Explore: 0.10
# Episode: 58  Reward: -25 Explore: 0.10
# Episode: 59  Reward: 27 Explore: 0.10
# Episode: 60  Reward: -26 Explore: 0.10
# Episode: 61  Reward: -2 Explore: 0.10
# Episode: 62  Reward: -148 Explore: 0.10
# Episode: 63  Reward: -218 Explore: 0.10
# Episode: 64  Reward: 33 Explore: 0.10
# Episode: 65  Reward: -25 Explore: 0.10
# Episode: 66  Reward: -8 Explore: 0.10
# SUCCESS
# Episode: 67  Reward: 1441 Explore: 0.10
# Episode: 68  Reward: 50 Explore: 0.10
# Episode: 69  Reward: 26 Explore: 0.10
# Episode: 70  Reward: -332 Explore: 0.10
# Episode: 71  Reward: -26 Explore: 0.10
# Episode: 72  Reward: -223 Explore: 0.10
# Episode: 73  Reward: -141 Explore: 0.10
# Episode: 74  Reward: -30 Explore: 0.10
# Episode: 75  Reward: -17 Explore: 0.10
# Episode: 76  Reward: -223 Explore: 0.10
# Episode: 77  Reward: 16 Explore: 0.10
# Episode: 78  Reward: 63 Explore: 0.10
# Episode: 79  Reward: -319 Explore: 0.10
# Episode: 80  Reward: -17 Explore: 0.10
# SUCCESS
# Episode: 81  Reward: 1329 Explore: 0.10
# Episode: 82  Reward: -232 Explore: 0.10
# Episode: 83  Reward: -22 Explore: 0.10
# Episode: 84  Reward: 415 Explore: 0.10
# Episode: 85  Reward: 48 Explore: 0.10
# Episode: 86  Reward: -303 Explore: 0.10
# Episode: 87  Reward: -24 Explore: 0.10
# Episode: 88  Reward: 12 Explore: 0.10
# Episode: 89  Reward: -42 Explore: 0.10
# Episode: 90  Reward: -267 Explore: 0.10
# Episode: 91  Reward: -32 Explore: 0.10
# Episode: 92  Reward: -29 Explore: 0.10
# SUCCESS
# Episode: 93  Reward: 1403 Explore: 0.10
# Episode: 94  Reward: 8 Explore: 0.10
# Episode: 95  Reward: -18 Explore: 0.10
# Episode: 96  Reward: -67 Explore: 0.10
# SUCCESS
# Episode: 97  Reward: 1292 Explore: 0.10
# Episode: 98  Reward: 401 Explore: 0.10
# Episode: 99  Reward: 16 Explore: 0.10
# SUCCESS
# Episode: 100  Reward: 1299 Explore: 0.10
# Episode: 101  Reward: -16 Explore: 0.10
# Episode: 102  Reward: 0 Explore: 0.10
# Episode: 103  Reward: 71 Explore: 0.10
# Episode: 104  Reward: 734 Explore: 0.10
# SUCCESS
# Episode: 105  Reward: 777 Explore: 0.10
# Episode: 106  Reward: 422 Explore: 0.10
# Episode: 107  Reward: 8 Explore: 0.10
# Episode: 108  Reward: 441 Explore: 0.10
# Episode: 109  Reward: 392 Explore: 0.10
# Episode: 110  Reward: 411 Explore: 0.10
# Episode: 111  Reward: -249 Explore: 0.10
# Episode: 112  Reward: -50 Explore: 0.10
# Episode: 113  Reward: -32 Explore: 0.10
# Episode: 114  Reward: -145 Explore: 0.10
# SUCCESS
# Episode: 115  Reward: 701 Explore: 0.10
# Episode: 116  Reward: -26 Explore: 0.10
# Episode: 117  Reward: -228 Explore: 0.10
# Episode: 118  Reward: -7 Explore: 0.10
# SUCCESS
# Episode: 119  Reward: 1205 Explore: 0.10
# Episode: 120  Reward: 13 Explore: 0.10
# Episode: 121  Reward: -188 Explore: 0.10
# Episode: 122  Reward: -14 Explore: 0.10
# Episode: 123  Reward: 32 Explore: 0.10
# Episode: 124  Reward: 51 Explore: 0.10
# Episode: 125  Reward: 940 Explore: 0.10
# Episode: 126  Reward: -66 Explore: 0.10
# SUCCESS
# Episode: 127  Reward: 665 Explore: 0.10
# Episode: 128  Reward: -192 Explore: 0.10
# Episode: 129  Reward: 15 Explore: 0.10
# Episode: 130  Reward: 650 Explore: 0.10
# Episode: 131  Reward: -245 Explore: 0.10
# Episode: 132  Reward: 578 Explore: 0.10
# Episode: 133  Reward: 686 Explore: 0.10
# Episode: 134  Reward: 795 Explore: 0.10
# Episode: 135  Reward: 47 Explore: 0.10
# Episode: 136  Reward: -100 Explore: 0.10
# Episode: 137  Reward: 361 Explore: 0.10
# Episode: 138  Reward: -27 Explore: 0.10
# Episode: 139  Reward: -113 Explore: 0.10
# Episode: 140  Reward: 35 Explore: 0.10
# Episode: 141  Reward: 66 Explore: 0.10
# Episode: 142  Reward: -5 Explore: 0.10
# Episode: 143  Reward: -259 Explore: 0.10
# SUCCESS
# Episode: 144  Reward: 1350 Explore: 0.10
# Episode: 145  Reward: -78 Explore: 0.10
# SUCCESS
# Episode: 146  Reward: 635 Explore: 0.10
# Episode: 147  Reward: -156 Explore: 0.10
# Episode: 148  Reward: -191 Explore: 0.10
# Episode: 149  Reward: 55 Explore: 0.10
# Episode: 150  Reward: -274 Explore: 0.10
# Episode: 151  Reward: -59 Explore: 0.10
# Episode: 152  Reward: -138 Explore: 0.10
# Episode: 153  Reward: -263 Explore: 0.10
# Episode: 154  Reward: -46 Explore: 0.10
# Episode: 155  Reward: 8 Explore: 0.10
# Episode: 156  Reward: 134 Explore: 0.10
# Episode: 157  Reward: -2 Explore: 0.10
# Episode: 158  Reward: 0 Explore: 0.10
# Episode: 159  Reward: -3 Explore: 0.10
# Episode: 160  Reward: 607 Explore: 0.10
# Episode: 161  Reward: -4 Explore: 0.10
# SUCCESS
# Episode: 162  Reward: 765 Explore: 0.10
# Episode: 163  Reward: 584 Explore: 0.10
# Episode: 164  Reward: -28 Explore: 0.10
# Episode: 165  Reward: -163 Explore: 0.10
# Episode: 166  Reward: -4 Explore: 0.10
# Episode: 167  Reward: -276 Explore: 0.10
# Episode: 168  Reward: -88 Explore: 0.10
# Episode: 169  Reward: -37 Explore: 0.10
# Episode: 170  Reward: 23 Explore: 0.10
# Episode: 171  Reward: 488 Explore: 0.10
# SUCCESS
# Episode: 172  Reward: 1092 Explore: 0.10
# Episode: 173  Reward: 908 Explore: 0.10
# Episode: 174  Reward: -12 Explore: 0.10
# Episode: 175  Reward: -216 Explore: 0.09
# Episode: 176  Reward: 59 Explore: 0.09
# Episode: 177  Reward: -346 Explore: 0.09
# Episode: 178  Reward: -266 Explore: 0.09
# Episode: 179  Reward: -91 Explore: 0.08
# Episode: 180  Reward: -48 Explore: 0.08
# Episode: 181  Reward: 12 Explore: 0.08
# Episode: 182  Reward: -116 Explore: 0.08
# Episode: 183  Reward: -231 Explore: 0.07
# Episode: 184  Reward: -111 Explore: 0.07
# Episode: 185  Reward: -108 Explore: 0.07
# Episode: 186  Reward: -187 Explore: 0.07
# Episode: 187  Reward: -108 Explore: 0.07
# Episode: 188  Reward: -245 Explore: 0.06
# SUCCESS
# Episode: 189  Reward: 1183 Explore: 0.06
# Episode: 190  Reward: -391 Explore: 0.06
# Episode: 191  Reward: -128 Explore: 0.06
# Episode: 192  Reward: -281 Explore: 0.06
# Episode: 193  Reward: 299 Explore: 0.06
# Episode: 194  Reward: -275 Explore: 0.05
# Episode: 195  Reward: -163 Explore: 0.05
# Episode: 196  Reward: -135 Explore: 0.05
# SUCCESS
# Episode: 197  Reward: 1369 Explore: 0.05
# Episode: 198  Reward: -342 Explore: 0.05
# Episode: 199  Reward: -369 Explore: 0.05
# Episode: 200  Reward: -185 Explore: 0.05
# Episode: 201  Reward: 47 Explore: 0.05
# Episode: 202  Reward: 18 Explore: 0.05
# Episode: 203  Reward: -26 Explore: 0.05
# SUCCESS
# Episode: 204  Reward: 1534 Explore: 0.05
# Episode: 205  Reward: -207 Explore: 0.05
# Episode: 206  Reward: -231 Explore: 0.05
# Episode: 207  Reward: -307 Explore: 0.05
# Episode: 208  Reward: -170 Explore: 0.05
# Episode: 209  Reward: -4 Explore: 0.05
# Episode: 210  Reward: -128 Explore: 0.05
# Episode: 211  Reward: -25 Explore: 0.05
# Episode: 212  Reward: -219 Explore: 0.05
# Episode: 213  Reward: 60 Explore: 0.05
# Episode: 214  Reward: 25 Explore: 0.05
# Episode: 215  Reward: -265 Explore: 0.05
# Episode: 216  Reward: -139 Explore: 0.05
# Episode: 217  Reward: -163 Explore: 0.05
# Episode: 218  Reward: -91 Explore: 0.05
# Episode: 219  Reward: -247 Explore: 0.05
# SUCCESS
# Episode: 220  Reward: 1082 Explore: 0.05
# Episode: 221  Reward: -71 Explore: 0.05
# Episode: 222  Reward: -154 Explore: 0.05
# Episode: 223  Reward: -32 Explore: 0.05
# Episode: 224  Reward: 59 Explore: 0.05
# Episode: 225  Reward: -73 Explore: 0.05
# Episode: 226  Reward: 33 Explore: 0.05
# Episode: 227  Reward: -75 Explore: 0.05
# Episode: 228  Reward: -350 Explore: 0.05
# Episode: 229  Reward: -146 Explore: 0.05
# Episode: 230  Reward: -48 Explore: 0.05
# SUCCESS
# Episode: 231  Reward: 1116 Explore: 0.05
# Episode: 232  Reward: -402 Explore: 0.05
# Episode: 233  Reward: -293 Explore: 0.05
# SUCCESS
# Episode: 234  Reward: 1229 Explore: 0.05
# Episode: 235  Reward: -206 Explore: 0.05
# Episode: 236  Reward: -11 Explore: 0.05
# SUCCESS
# Episode: 237  Reward: 1509 Explore: 0.05
# Episode: 238  Reward: -28 Explore: 0.05
# SUCCESS
# Episode: 239  Reward: 1054 Explore: 0.05
# SUCCESS
# Episode: 240  Reward: 1296 Explore: 0.05
# Episode: 241  Reward: -137 Explore: 0.05
# Episode: 242  Reward: -11 Explore: 0.05
# SUCCESS
# Episode: 243  Reward: 1485 Explore: 0.05
# Episode: 244  Reward: -55 Explore: 0.05
# SUCCESS
# Episode: 245  Reward: 1404 Explore: 0.05
# Episode: 246  Reward: -178 Explore: 0.05
# Episode: 247  Reward: -43 Explore: 0.05
# Episode: 248  Reward: -72 Explore: 0.05
# Episode: 249  Reward: -24 Explore: 0.05
# Episode: 250  Reward: -20 Explore: 0.05
# Episode: 251  Reward: -163 Explore: 0.05
# Episode: 252  Reward: -158 Explore: 0.05
# Episode: 253  Reward: 9 Explore: 0.05
# Episode: 254  Reward: -54 Explore: 0.05
# Episode: 255  Reward: -49 Explore: 0.05
# Episode: 256  Reward: -155 Explore: 0.05
# Episode: 257  Reward: -117 Explore: 0.05
# Episode: 258  Reward: -329 Explore: 0.05
# Episode: 259  Reward: -149 Explore: 0.05
# Episode: 260  Reward: -228 Explore: 0.05
# Episode: 261  Reward: -137 Explore: 0.05
# Episode: 262  Reward: -269 Explore: 0.05
# Episode: 263  Reward: -178 Explore: 0.05
# SUCCESS
# Episode: 264  Reward: 803 Explore: 0.05
# Episode: 265  Reward: -54 Explore: 0.05
# Episode: 266  Reward: -121 Explore: 0.05
# Episode: 267  Reward: -79 Explore: 0.05
# Episode: 268  Reward: -118 Explore: 0.05
# Episode: 269  Reward: 38 Explore: 0.05
# Episode: 270  Reward: 10 Explore: 0.05
# Episode: 271  Reward: 26 Explore: 0.05
# Episode: 272  Reward: 460 Explore: 0.05
# Episode: 273  Reward: -76 Explore: 0.05
# SUCCESS
# Episode: 274  Reward: 1119 Explore: 0.05
# Episode: 275  Reward: -3 Explore: 0.05
# Episode: 276  Reward: 68 Explore: 0.05
# Episode: 277  Reward: -23 Explore: 0.05
# SUCCESS
# Episode: 278  Reward: 531 Explore: 0.05
# Episode: 279  Reward: -89 Explore: 0.05
# Episode: 280  Reward: -233 Explore: 0.05
# Episode: 281  Reward: -323 Explore: 0.05
# Episode: 282  Reward: -310 Explore: 0.05
# Episode: 283  Reward: 28 Explore: 0.05
# Episode: 284  Reward: -46 Explore: 0.05
# Episode: 285  Reward: 2 Explore: 0.05
# SUCCESS
# Episode: 286  Reward: 1083 Explore: 0.05
# Episode: 287  Reward: -168 Explore: 0.05
# Episode: 288  Reward: -183 Explore: 0.05
# Episode: 289  Reward: -172 Explore: 0.05
# Episode: 290  Reward: -50 Explore: 0.05
# Episode: 291  Reward: -203 Explore: 0.05
# Episode: 292  Reward: 45 Explore: 0.05
# Episode: 293  Reward: 86 Explore: 0.05
# Episode: 294  Reward: 9 Explore: 0.05
# Episode: 295  Reward: -131 Explore: 0.05
# Episode: 296  Reward: 368 Explore: 0.05
# Episode: 297  Reward: -79 Explore: 0.05
# Episode: 298  Reward: -232 Explore: 0.05
# Episode: 299  Reward: 566 Explore: 0.05
# Episode: 300  Reward: -219 Explore: 0.05
# Episode: 301  Reward: 63 Explore: 0.05
# Episode: 302  Reward: -70 Explore: 0.05
# Episode: 303  Reward: 34 Explore: 0.05
# Episode: 304  Reward: -18 Explore: 0.05
# SUCCESS
# Episode: 305  Reward: 1423 Explore: 0.05
# Episode: 306  Reward: 58 Explore: 0.05
# Episode: 307  Reward: 56 Explore: 0.05
# Episode: 308  Reward: 21 Explore: 0.05
# Episode: 309  Reward: 116 Explore: 0.05
# Episode: 310  Reward: 2 Explore: 0.05
# Episode: 311  Reward: 40 Explore: 0.05
# Episode: 312  Reward: 55 Explore: 0.05
# Episode: 313  Reward: 3 Explore: 0.05
# Episode: 314  Reward: 0 Explore: 0.05
# Episode: 315  Reward: 56 Explore: 0.05
# Episode: 316  Reward: -26 Explore: 0.05
# Episode: 317  Reward: -110 Explore: 0.05
# Episode: 318  Reward: -46 Explore: 0.05
# SUCCESS
# Episode: 319  Reward: 1463 Explore: 0.05
# SUCCESS
# Episode: 320  Reward: 1488 Explore: 0.05
# Episode: 321  Reward: -61 Explore: 0.05
# Episode: 322  Reward: -22 Explore: 0.05
# Episode: 323  Reward: 19 Explore: 0.05
# SUCCESS
# Episode: 324  Reward: 622 Explore: 0.05
# Episode: 325  Reward: -240 Explore: 0.05
# Episode: 326  Reward: -34 Explore: 0.05
# Episode: 327  Reward: -199 Explore: 0.05
# Episode: 328  Reward: -128 Explore: 0.05
# Episode: 329  Reward: -303 Explore: 0.05
# SUCCESS
# Episode: 330  Reward: 830 Explore: 0.05
# Episode: 331  Reward: -75 Explore: 0.05
# Episode: 332  Reward: -2 Explore: 0.05
# Episode: 333  Reward: -118 Explore: 0.05
# Episode: 334  Reward: -107 Explore: 0.05
# SUCCESS
# Episode: 335  Reward: 948 Explore: 0.05
# Episode: 336  Reward: -164 Explore: 0.05
# Episode: 337  Reward: -30 Explore: 0.05
# Episode: 338  Reward: -65 Explore: 0.05
# Episode: 339  Reward: -38 Explore: 0.05
# SUCCESS
# Episode: 340  Reward: 1452 Explore: 0.05
# Episode: 341  Reward: -67 Explore: 0.05
# Episode: 342  Reward: -35 Explore: 0.05
# Episode: 343  Reward: -176 Explore: 0.05
# Episode: 344  Reward: -63 Explore: 0.05
# Episode: 345  Reward: -313 Explore: 0.05
# SUCCESS
# Episode: 346  Reward: 1337 Explore: 0.05
# Episode: 347  Reward: -56 Explore: 0.05
# Episode: 348  Reward: -66 Explore: 0.05
# Episode: 349  Reward: -150 Explore: 0.05
# Episode: 350  Reward: 66 Explore: 0.05
# Episode: 351  Reward: 24 Explore: 0.05
# Episode: 352  Reward: -403 Explore: 0.05
# Episode: 353  Reward: -16 Explore: 0.05
# Episode: 354  Reward: 87 Explore: 0.05
# Episode: 355  Reward: 81 Explore: 0.05
# Episode: 356  Reward: 6 Explore: 0.05
# Episode: 357  Reward: -56 Explore: 0.05
# Episode: 358  Reward: 263 Explore: 0.05
# Episode: 359  Reward: 27 Explore: 0.05
# Episode: 360  Reward: 20 Explore: 0.05
# SUCCESS
# Episode: 361  Reward: 847 Explore: 0.05
# Episode: 362  Reward: 18 Explore: 0.05
# Episode: 363  Reward: -99 Explore: 0.05
# Episode: 364  Reward: -46 Explore: 0.05
# Episode: 365  Reward: -203 Explore: 0.05
# Episode: 366  Reward: 18 Explore: 0.05
# Episode: 367  Reward: -318 Explore: 0.05
# Episode: 368  Reward: 50 Explore: 0.05
# Episode: 369  Reward: -80 Explore: 0.05
# Episode: 370  Reward: 16 Explore: 0.05
# Episode: 371  Reward: 35 Explore: 0.05
# Episode: 372  Reward: -265 Explore: 0.05
# Episode: 373  Reward: 3 Explore: 0.05
# SUCCESS
# Episode: 374  Reward: 1334 Explore: 0.05
# Episode: 375  Reward: -70 Explore: 0.05
# Episode: 376  Reward: 46 Explore: 0.05
# SUCCESS
# Episode: 377  Reward: 1326 Explore: 0.05
# Episode: 378  Reward: 34 Explore: 0.05
# Episode: 379  Reward: 33 Explore: 0.05
# Episode: 380  Reward: 4 Explore: 0.05
# Episode: 381  Reward: -67 Explore: 0.05
# Episode: 382  Reward: -180 Explore: 0.05
# SUCCESS
# Episode: 383  Reward: 880 Explore: 0.05
# Episode: 384  Reward: 826 Explore: 0.05
# Episode: 385  Reward: 5 Explore: 0.05
# Episode: 386  Reward: 18 Explore: 0.05
# Episode: 387  Reward: 42 Explore: 0.05
# Episode: 388  Reward: 60 Explore: 0.05
# Episode: 389  Reward: 26 Explore: 0.05
# Episode: 390  Reward: 300 Explore: 0.05
# Episode: 391  Reward: 649 Explore: 0.05
# Episode: 392  Reward: 6 Explore: 0.05
# Episode: 393  Reward: -30 Explore: 0.05
# Episode: 394  Reward: -54 Explore: 0.05
# Episode: 395  Reward: -6 Explore: 0.05
# Episode: 396  Reward: 57 Explore: 0.05
# Episode: 397  Reward: -47 Explore: 0.05
# Episode: 398  Reward: 35 Explore: 0.05
# Episode: 399  Reward: 189 Explore: 0.05
# Episode: 400  Reward: 36 Explore: 0.05
# Episode: 401  Reward: 13 Explore: 0.05
# SUCCESS
# Episode: 402  Reward: 1458 Explore: 0.05
# SUCCESS
# Episode: 403  Reward: 829 Explore: 0.05
# Episode: 404  Reward: -295 Explore: 0.05
# Episode: 405  Reward: 12 Explore: 0.05
# Episode: 406  Reward: 29 Explore: 0.05
# SUCCESS
# Episode: 407  Reward: 1181 Explore: 0.05
# Episode: 408  Reward: -315 Explore: 0.05
# Episode: 409  Reward: 3 Explore: 0.05
# Episode: 410  Reward: 47 Explore: 0.05
# Episode: 411  Reward: 8 Explore: 0.05
# Episode: 412  Reward: 77 Explore: 0.05
# Episode: 413  Reward: 24 Explore: 0.05
# Episode: 414  Reward: 29 Explore: 0.05
# Episode: 415  Reward: -143 Explore: 0.05
# Episode: 416  Reward: -445 Explore: 0.05
# Episode: 417  Reward: 41 Explore: 0.05
# Episode: 418  Reward: 32 Explore: 0.05
# Episode: 419  Reward: -60 Explore: 0.05
# Episode: 420  Reward: -31 Explore: 0.05
# SUCCESS
# Episode: 421  Reward: 1231 Explore: 0.05
# Episode: 422  Reward: -41 Explore: 0.05
# SUCCESS
# Episode: 423  Reward: 999 Explore: 0.05
# Episode: 424  Reward: -36 Explore: 0.05
# Episode: 425  Reward: -43 Explore: 0.05
# Episode: 426  Reward: -78 Explore: 0.05
# Episode: 427  Reward: -108 Explore: 0.05
# Episode: 428  Reward: -25 Explore: 0.05
# Episode: 429  Reward: -60 Explore: 0.05
# Episode: 430  Reward: -73 Explore: 0.05
# Episode: 431  Reward: 42 Explore: 0.05
# Episode: 432  Reward: -168 Explore: 0.05
# Episode: 433  Reward: -50 Explore: 0.05
# Episode: 434  Reward: -50 Explore: 0.05
# Episode: 435  Reward: -38 Explore: 0.05
# Episode: 436  Reward: -266 Explore: 0.05
# Episode: 437  Reward: 69 Explore: 0.05
# Episode: 438  Reward: 4 Explore: 0.05
# Episode: 439  Reward: -31 Explore: 0.05
# Episode: 440  Reward: -304 Explore: 0.05
# Episode: 441  Reward: -43 Explore: 0.05
# Episode: 442  Reward: -13 Explore: 0.05
# Episode: 443  Reward: -46 Explore: 0.05
# Episode: 444  Reward: 79 Explore: 0.05
# Episode: 445  Reward: -84 Explore: 0.05
# Episode: 446  Reward: 27 Explore: 0.05
# Episode: 447  Reward: -45 Explore: 0.05
# Episode: 448  Reward: -211 Explore: 0.05
# Episode: 449  Reward: 74 Explore: 0.05
# Episode: 450  Reward: 155 Explore: 0.05
# Episode: 451  Reward: -28 Explore: 0.05
# Episode: 452  Reward: 19 Explore: 0.05
# Episode: 453  Reward: -3 Explore: 0.05
# Episode: 454  Reward: 61 Explore: 0.05
# Episode: 455  Reward: -323 Explore: 0.05
# Episode: 456  Reward: 13 Explore: 0.05
# Episode: 457  Reward: -94 Explore: 0.05
# SUCCESS
# Episode: 458  Reward: 1203 Explore: 0.05
# Episode: 459  Reward: -126 Explore: 0.05
# SUCCESS
# Episode: 460  Reward: 1011 Explore: 0.05
# Episode: 461  Reward: 5 Explore: 0.05
# Episode: 462  Reward: 197 Explore: 0.05
# Episode: 463  Reward: 48 Explore: 0.05
# SUCCESS
# Episode: 464  Reward: 1098 Explore: 0.05
# Episode: 465  Reward: -42 Explore: 0.05
# Episode: 466  Reward: 73 Explore: 0.05
# Episode: 467  Reward: 58 Explore: 0.05
# SUCCESS
# Episode: 468  Reward: 953 Explore: 0.05
# Episode: 469  Reward: -42 Explore: 0.05
# Episode: 470  Reward: 20 Explore: 0.05
# Episode: 471  Reward: -107 Explore: 0.05
# Episode: 472  Reward: -57 Explore: 0.05
# SUCCESS
# Episode: 473  Reward: 1406 Explore: 0.05
# Episode: 474  Reward: 38 Explore: 0.05
# SUCCESS
# Episode: 475  Reward: 1274 Explore: 0.05
# Episode: 476  Reward: -209 Explore: 0.05
# SUCCESS
# Episode: 477  Reward: 1166 Explore: 0.05
# Episode: 478  Reward: -226 Explore: 0.05
# Episode: 479  Reward: 9 Explore: 0.05
# Episode: 480  Reward: 22 Explore: 0.05
# Episode: 481  Reward: -106 Explore: 0.05
# Episode: 482  Reward: 19 Explore: 0.05
# Episode: 483  Reward: -65 Explore: 0.05
# Episode: 484  Reward: -63 Explore: 0.05
# Episode: 485  Reward: -148 Explore: 0.05
# Episode: 486  Reward: -34 Explore: 0.05
# Episode: 487  Reward: -49 Explore: 0.05
# Episode: 488  Reward: -106 Explore: 0.05
# Episode: 489  Reward: -83 Explore: 0.05
# Episode: 490  Reward: -50 Explore: 0.05
# Episode: 491  Reward: -74 Explore: 0.05
# Episode: 492  Reward: 23 Explore: 0.05
# Episode: 493  Reward: 18 Explore: 0.05
# Episode: 494  Reward: -22 Explore: 0.05
# SUCCESS
# Episode: 495  Reward: 984 Explore: 0.05
# Episode: 496  Reward: -260 Explore: 0.05
# Episode: 497  Reward: -17 Explore: 0.05
# SUCCESS
# Episode: 498  Reward: 869 Explore: 0.05
# Episode: 499  Reward: 37 Explore: 0.05
# Episode: 500  Reward: 6 Explore: 0.05
# Episode: 501  Reward: 4 Explore: 0.05
# Episode: 502  Reward: 19 Explore: 0.05
# Episode: 503  Reward: 47 Explore: 0.05
# Episode: 504  Reward: 63 Explore: 0.05
# Episode: 505  Reward: 0 Explore: 0.05
# Episode: 506  Reward: 29 Explore: 0.05
# SUCCESS
# Episode: 507  Reward: 1517 Explore: 0.05
# Episode: 508  Reward: 25 Explore: 0.05
# Episode: 509  Reward: -12 Explore: 0.05
# Episode: 510  Reward: 41 Explore: 0.05
# Episode: 511  Reward: -22 Explore: 0.05
# Episode: 512  Reward: 11 Explore: 0.05
# Episode: 513  Reward: -58 Explore: 0.05
# Episode: 514  Reward: -12 Explore: 0.05
# Episode: 515  Reward: -70 Explore: 0.05
# Episode: 516  Reward: 29 Explore: 0.05
# Episode: 517  Reward: 49 Explore: 0.05
# Episode: 518  Reward: 24 Explore: 0.05
# Episode: 519  Reward: 36 Explore: 0.05
# Episode: 520  Reward: 34 Explore: 0.05
# Episode: 521  Reward: -77 Explore: 0.05
# Episode: 522  Reward: 37 Explore: 0.05
# Episode: 523  Reward: 378 Explore: 0.05
# Episode: 524  Reward: 50 Explore: 0.05
# Episode: 525  Reward: 86 Explore: 0.05
# Episode: 526  Reward: 12 Explore: 0.05
# Episode: 527  Reward: -241 Explore: 0.05
# Episode: 528  Reward: -25 Explore: 0.05
# Episode: 529  Reward: -12 Explore: 0.05
# Episode: 530  Reward: -49 Explore: 0.05
# SUCCESS
# Episode: 531  Reward: 926 Explore: 0.05
# Episode: 532  Reward: -8 Explore: 0.05
# Episode: 533  Reward: 44 Explore: 0.05
# Episode: 534  Reward: 31 Explore: 0.05
# Episode: 535  Reward: 21 Explore: 0.05
# Episode: 536  Reward: 18 Explore: 0.05
# Episode: 537  Reward: 51 Explore: 0.05
# Episode: 538  Reward: -92 Explore: 0.05
# Episode: 539  Reward: -129 Explore: 0.05
# Episode: 540  Reward: -53 Explore: 0.05
# Episode: 541  Reward: 22 Explore: 0.05
# Episode: 542  Reward: -61 Explore: 0.05
# Episode: 543  Reward: 61 Explore: 0.05
# Episode: 544  Reward: -51 Explore: 0.05
# Episode: 545  Reward: 28 Explore: 0.05
# Episode: 546  Reward: -493 Explore: 0.05
# Episode: 547  Reward: -47 Explore: 0.05
# Episode: 548  Reward: -107 Explore: 0.05
# Episode: 549  Reward: -88 Explore: 0.05
# Episode: 550  Reward: 57 Explore: 0.05
# Episode: 551  Reward: -174 Explore: 0.05
# Episode: 552  Reward: 206 Explore: 0.05
# SUCCESS
# Episode: 553  Reward: 691 Explore: 0.05
# Episode: 554  Reward: 36 Explore: 0.05
# Episode: 555  Reward: 35 Explore: 0.05
# Episode: 556  Reward: 195 Explore: 0.05
# Episode: 557  Reward: -100 Explore: 0.05
# Episode: 558  Reward: -47 Explore: 0.05
# Episode: 559  Reward: 68 Explore: 0.05
# Episode: 560  Reward: -135 Explore: 0.05
# Episode: 561  Reward: 33 Explore: 0.05
# SUCCESS
# Episode: 562  Reward: 878 Explore: 0.05
# SUCCESS
# Episode: 563  Reward: 1021 Explore: 0.05
# Episode: 564  Reward: -329 Explore: 0.05
# Episode: 565  Reward: -209 Explore: 0.05
# Episode: 566  Reward: 39 Explore: 0.05
# Episode: 567  Reward: 3 Explore: 0.05
# Episode: 568  Reward: -71 Explore: 0.05
# Episode: 569  Reward: -57 Explore: 0.05
# Episode: 570  Reward: -77 Explore: 0.05
# Episode: 571  Reward: -26 Explore: 0.05
# Episode: 572  Reward: -140 Explore: 0.05
# Episode: 573  Reward: -168 Explore: 0.05
# Episode: 574  Reward: -213 Explore: 0.05
# Episode: 575  Reward: 394 Explore: 0.05
# SUCCESS
# Episode: 576  Reward: 1060 Explore: 0.05
# Episode: 577  Reward: -190 Explore: 0.05
# Episode: 578  Reward: -89 Explore: 0.05
# Episode: 579  Reward: 0 Explore: 0.05
# Episode: 580  Reward: 28 Explore: 0.05
# Episode: 581  Reward: -91 Explore: 0.05
# Episode: 582  Reward: 313 Explore: 0.05
# Episode: 583  Reward: -71 Explore: 0.05
# Episode: 584  Reward: -169 Explore: 0.05
# SUCCESS
# Episode: 585  Reward: 809 Explore: 0.05
# Episode: 586  Reward: -113 Explore: 0.05
# SUCCESS
# Episode: 587  Reward: 647 Explore: 0.05
# SUCCESS
# Episode: 588  Reward: 948 Explore: 0.05
# Episode: 589  Reward: -14 Explore: 0.05
# Episode: 590  Reward: -249 Explore: 0.05
# Episode: 591  Reward: -207 Explore: 0.05
# Episode: 592  Reward: -38 Explore: 0.05
# Episode: 593  Reward: -27 Explore: 0.05
# Episode: 594  Reward: -79 Explore: 0.05
# Episode: 595  Reward: 25 Explore: 0.05
# Episode: 596  Reward: -51 Explore: 0.05
# Episode: 597  Reward: -17 Explore: 0.05
# Episode: 598  Reward: -63 Explore: 0.05
# Episode: 599  Reward: -60 Explore: 0.05
# SUCCESS
# Episode: 600  Reward: 624 Explore: 0.05
# Episode: 601  Reward: -16 Explore: 0.05
# Episode: 602  Reward: -136 Explore: 0.05
# Episode: 603  Reward: -142 Explore: 0.05
# Episode: 604  Reward: -73 Explore: 0.05
# Episode: 605  Reward: -218 Explore: 0.05
# Episode: 606  Reward: -80 Explore: 0.05
# Episode: 607  Reward: -76 Explore: 0.05
# Episode: 608  Reward: -127 Explore: 0.05
# Episode: 609  Reward: 4 Explore: 0.05
# Episode: 610  Reward: 2 Explore: 0.05
# Episode: 611  Reward: -17 Explore: 0.05
# Episode: 612  Reward: -16 Explore: 0.05
# Episode: 613  Reward: 5 Explore: 0.05
# Episode: 614  Reward: 16 Explore: 0.05
# Episode: 615  Reward: 34 Explore: 0.05
# Episode: 616  Reward: -132 Explore: 0.05
# Episode: 617  Reward: -121 Explore: 0.05
# SUCCESS
# Episode: 618  Reward: 1457 Explore: 0.05
# Episode: 619  Reward: -105 Explore: 0.05
# SUCCESS
# Episode: 620  Reward: 1194 Explore: 0.05
# Episode: 621  Reward: -122 Explore: 0.05
# Episode: 622  Reward: 81 Explore: 0.05
# Episode: 623  Reward: -163 Explore: 0.05
# Episode: 624  Reward: -191 Explore: 0.05
# Episode: 625  Reward: 6 Explore: 0.05
# Episode: 626  Reward: -206 Explore: 0.05
# Episode: 627  Reward: -35 Explore: 0.05
# Episode: 628  Reward: -4 Explore: 0.05
# Episode: 629  Reward: -41 Explore: 0.05
# Episode: 630  Reward: -91 Explore: 0.05
# Episode: 631  Reward: -72 Explore: 0.05
# Episode: 632  Reward: -64 Explore: 0.05
# Episode: 633  Reward: -97 Explore: 0.05
# SUCCESS
# Episode: 634  Reward: 1070 Explore: 0.05
# Episode: 635  Reward: -61 Explore: 0.05
# Episode: 636  Reward: -75 Explore: 0.05
# Episode: 637  Reward: -12 Explore: 0.05
# Episode: 638  Reward: -232 Explore: 0.05
# Episode: 639  Reward: -99 Explore: 0.05
# Episode: 640  Reward: -36 Explore: 0.05
# Episode: 641  Reward: 36 Explore: 0.05
# Episode: 642  Reward: 143 Explore: 0.05
# Episode: 643  Reward: -161 Explore: 0.05
# Episode: 644  Reward: -108 Explore: 0.05
# Episode: 645  Reward: -58 Explore: 0.05
# Episode: 646  Reward: -103 Explore: 0.05
# Episode: 647  Reward: 5 Explore: 0.05
# Episode: 648  Reward: 36 Explore: 0.05
# Episode: 649  Reward: -66 Explore: 0.05
# Episode: 650  Reward: 7 Explore: 0.05
# Episode: 651  Reward: 7 Explore: 0.05
# Episode: 652  Reward: -30 Explore: 0.05
# Episode: 653  Reward: -5 Explore: 0.05
# Episode: 654  Reward: 4 Explore: 0.05
# Episode: 655  Reward: -17 Explore: 0.05
# Episode: 656  Reward: -44 Explore: 0.05
# Episode: 657  Reward: -24 Explore: 0.05
# Episode: 658  Reward: 44 Explore: 0.05
# Episode: 659  Reward: -9 Explore: 0.05
# Episode: 660  Reward: 1 Explore: 0.05
# SUCCESS
# Episode: 661  Reward: 1446 Explore: 0.05
# Episode: 662  Reward: -91 Explore: 0.05
# Episode: 663  Reward: -79 Explore: 0.05
# Episode: 664  Reward: -169 Explore: 0.05
# Episode: 665  Reward: -24 Explore: 0.05
# Episode: 666  Reward: -80 Explore: 0.05
# Episode: 667  Reward: 16 Explore: 0.05
# Episode: 668  Reward: -4 Explore: 0.05
# Episode: 669  Reward: 44 Explore: 0.05
# Episode: 670  Reward: 49 Explore: 0.05
# Episode: 671  Reward: -2 Explore: 0.05
# Episode: 672  Reward: -12 Explore: 0.05
# Episode: 673  Reward: 30 Explore: 0.05
# Episode: 674  Reward: -76 Explore: 0.05
# Episode: 675  Reward: -23 Explore: 0.05
# Episode: 676  Reward: -18 Explore: 0.05
# SUCCESS
# Episode: 677  Reward: 744 Explore: 0.05
# Episode: 678  Reward: 52 Explore: 0.05
# Episode: 679  Reward: 50 Explore: 0.05
# Episode: 680  Reward: -30 Explore: 0.05
# Episode: 681  Reward: 50 Explore: 0.05
# Episode: 682  Reward: -2 Explore: 0.05
# Episode: 683  Reward: 24 Explore: 0.05
# Episode: 684  Reward: -58 Explore: 0.05
# Episode: 685  Reward: -133 Explore: 0.05
# Episode: 686  Reward: -13 Explore: 0.05
# Episode: 687  Reward: 97 Explore: 0.05
# Episode: 688  Reward: -70 Explore: 0.05
# Episode: 689  Reward: -5 Explore: 0.05
# SUCCESS
# Episode: 690  Reward: 1279 Explore: 0.05
# Episode: 691  Reward: -31 Explore: 0.05
# Episode: 692  Reward: 283 Explore: 0.05
# Episode: 693  Reward: 15 Explore: 0.05
# SUCCESS
# Episode: 694  Reward: 1409 Explore: 0.05
# SUCCESS
# Episode: 695  Reward: 1324 Explore: 0.05
# Episode: 696  Reward: 199 Explore: 0.05
# Episode: 697  Reward: -27 Explore: 0.05
# Episode: 698  Reward: -27 Explore: 0.05
# Episode: 699  Reward: 81 Explore: 0.05
# Episode: 700  Reward: 33 Explore: 0.05
# Episode: 701  Reward: 23 Explore: 0.05
# SUCCESS
# Episode: 702  Reward: 1327 Explore: 0.05
# Episode: 703  Reward: -21 Explore: 0.05
# Episode: 704  Reward: 18 Explore: 0.05
# Episode: 705  Reward: -153 Explore: 0.05
# Episode: 706  Reward: 33 Explore: 0.05
# SUCCESS
# Episode: 707  Reward: 912 Explore: 0.05
# Episode: 708  Reward: 315 Explore: 0.05
# Episode: 709  Reward: 12 Explore: 0.05
# Episode: 710  Reward: 31 Explore: 0.05
# Episode: 711  Reward: 40 Explore: 0.05
# SUCCESS
# Episode: 712  Reward: 804 Explore: 0.05
# Episode: 713  Reward: -10 Explore: 0.05
# Episode: 714  Reward: 8 Explore: 0.05
# Episode: 715  Reward: 82 Explore: 0.05
# Episode: 716  Reward: 101 Explore: 0.05
# Episode: 717  Reward: -67 Explore: 0.05
# Episode: 718  Reward: 24 Explore: 0.05
# Episode: 719  Reward: 182 Explore: 0.05
# Episode: 720  Reward: -9 Explore: 0.05
# Episode: 721  Reward: -45 Explore: 0.05
# Episode: 722  Reward: 15 Explore: 0.05
# SUCCESS
# Episode: 723  Reward: 556 Explore: 0.05
# Episode: 724  Reward: 32 Explore: 0.05
# Episode: 725  Reward: -45 Explore: 0.05
# SUCCESS
# Episode: 726  Reward: 1047 Explore: 0.05
# Episode: 727  Reward: 8 Explore: 0.05
# Episode: 728  Reward: -40 Explore: 0.05
# Episode: 729  Reward: -18 Explore: 0.05
# SUCCESS
# Episode: 730  Reward: 554 Explore: 0.05
# Episode: 731  Reward: -580 Explore: 0.05
# SUCCESS
# Episode: 732  Reward: 1100 Explore: 0.05
# Episode: 733  Reward: -106 Explore: 0.05
# Episode: 734  Reward: -471 Explore: 0.05
# Episode: 735  Reward: -463 Explore: 0.05
# Episode: 736  Reward: 9 Explore: 0.05
# Episode: 737  Reward: 68 Explore: 0.05
# Episode: 738  Reward: -106 Explore: 0.05
# Episode: 739  Reward: -551 Explore: 0.05
# Episode: 740  Reward: -87 Explore: 0.05
# Episode: 741  Reward: -265 Explore: 0.05
# SUCCESS
# Episode: 742  Reward: 1111 Explore: 0.05
# Episode: 743  Reward: -53 Explore: 0.05
# Episode: 744  Reward: -163 Explore: 0.05
# SUCCESS
# Episode: 745  Reward: 985 Explore: 0.05
# Episode: 746  Reward: -323 Explore: 0.05
# Episode: 747  Reward: -6 Explore: 0.05
# Episode: 748  Reward: 113 Explore: 0.05
# Episode: 749  Reward: -33 Explore: 0.05
# SUCCESS
# Episode: 750  Reward: 834 Explore: 0.05
# Episode: 751  Reward: -166 Explore: 0.05
# Episode: 752  Reward: 209 Explore: 0.05
# Episode: 753  Reward: -37 Explore: 0.05
# Episode: 754  Reward: -149 Explore: 0.05
# Episode: 755  Reward: -32 Explore: 0.05
# Episode: 756  Reward: -122 Explore: 0.05
# Episode: 757  Reward: -47 Explore: 0.05
# Episode: 758  Reward: -94 Explore: 0.05
# Episode: 759  Reward: 445 Explore: 0.05
# SUCCESS
# Episode: 760  Reward: 1490 Explore: 0.05
# Episode: 761  Reward: -33 Explore: 0.05
# Episode: 762  Reward: -131 Explore: 0.05
# Episode: 763  Reward: -128 Explore: 0.05
# SUCCESS
# Episode: 764  Reward: 700 Explore: 0.05
# Episode: 765  Reward: -20 Explore: 0.05
# Episode: 766  Reward: -61 Explore: 0.05
# Episode: 767  Reward: 339 Explore: 0.05
# Episode: 768  Reward: -565 Explore: 0.05
# Episode: 769  Reward: -33 Explore: 0.05
# Episode: 770  Reward: -118 Explore: 0.05
# Episode: 771  Reward: -131 Explore: 0.05
# Episode: 772  Reward: -152 Explore: 0.05
# Episode: 773  Reward: -51 Explore: 0.05
# Episode: 774  Reward: -81 Explore: 0.05
# Episode: 775  Reward: -111 Explore: 0.05
# Episode: 776  Reward: -58 Explore: 0.05
# Episode: 777  Reward: -15 Explore: 0.05
# Episode: 778  Reward: -8 Explore: 0.05
# Episode: 779  Reward: -79 Explore: 0.05
# Episode: 780  Reward: -30 Explore: 0.05
# Episode: 781  Reward: -48 Explore: 0.05
# Episode: 782  Reward: 108 Explore: 0.05
# SUCCESS
# Episode: 783  Reward: 701 Explore: 0.05
# Episode: 784  Reward: -98 Explore: 0.05
# Episode: 785  Reward: -68 Explore: 0.05
# Episode: 786  Reward: -48 Explore: 0.05
# Episode: 787  Reward: -55 Explore: 0.05
# Episode: 788  Reward: -28 Explore: 0.05
# Episode: 789  Reward: -81 Explore: 0.05
# Episode: 790  Reward: -50 Explore: 0.05
# Episode: 791  Reward: -19 Explore: 0.05
# Episode: 792  Reward: -52 Explore: 0.05
# Episode: 793  Reward: -63 Explore: 0.05
# Episode: 794  Reward: -35 Explore: 0.05
# Episode: 795  Reward: 19 Explore: 0.05
# Episode: 796  Reward: -15 Explore: 0.05
# Episode: 797  Reward: -92 Explore: 0.05
# Episode: 798  Reward: 9 Explore: 0.05
# Episode: 799  Reward: -32 Explore: 0.05
# Episode: 800  Reward: -32 Explore: 0.05
# Episode: 801  Reward: 0 Explore: 0.05
# Episode: 802  Reward: 48 Explore: 0.05
# Episode: 803  Reward: 391 Explore: 0.05
# Episode: 804  Reward: -162 Explore: 0.05
# Episode: 805  Reward: -1 Explore: 0.05
# Episode: 806  Reward: -1 Explore: 0.05
# Episode: 807  Reward: 12 Explore: 0.05
# Episode: 808  Reward: -68 Explore: 0.05
# Episode: 809  Reward: -27 Explore: 0.05
# Episode: 810  Reward: -119 Explore: 0.05
# Episode: 811  Reward: -7 Explore: 0.05
# Episode: 812  Reward: -7 Explore: 0.05
# SUCCESS
# Episode: 813  Reward: 940 Explore: 0.05
# Episode: 814  Reward: -53 Explore: 0.05
# Episode: 815  Reward: -80 Explore: 0.05
# Episode: 816  Reward: 200 Explore: 0.05
# Episode: 817  Reward: -22 Explore: 0.05
# Episode: 818  Reward: -107 Explore: 0.05
# Episode: 819  Reward: -6 Explore: 0.05
# Episode: 820  Reward: 28 Explore: 0.05
# Episode: 821  Reward: 43 Explore: 0.05
# Episode: 822  Reward: -426 Explore: 0.05
# Episode: 823  Reward: -44 Explore: 0.05
# Episode: 824  Reward: -44 Explore: 0.05
# Episode: 825  Reward: -79 Explore: 0.05
# Episode: 826  Reward: -10 Explore: 0.05
# Episode: 827  Reward: -48 Explore: 0.05
# SUCCESS
# Episode: 828  Reward: 1326 Explore: 0.05
# Episode: 829  Reward: -7 Explore: 0.05
# Episode: 830  Reward: 48 Explore: 0.05
# Episode: 831  Reward: 30 Explore: 0.05
# Episode: 832  Reward: 140 Explore: 0.05
# Episode: 833  Reward: 58 Explore: 0.05
# Episode: 834  Reward: -8 Explore: 0.05
# Episode: 835  Reward: 157 Explore: 0.05
# SUCCESS
# Episode: 836  Reward: 962 Explore: 0.05
# Episode: 837  Reward: 190 Explore: 0.05
# Episode: 838  Reward: -163 Explore: 0.05
# Episode: 839  Reward: 37 Explore: 0.05
# Episode: 840  Reward: 1 Explore: 0.05
# Episode: 841  Reward: -3 Explore: 0.05
# Episode: 842  Reward: -5 Explore: 0.05
# Episode: 843  Reward: 48 Explore: 0.05
# Episode: 844  Reward: 170 Explore: 0.05
# Episode: 845  Reward: -550 Explore: 0.05
# Episode: 846  Reward: 26 Explore: 0.05
# Episode: 847  Reward: -164 Explore: 0.05
# Episode: 848  Reward: 185 Explore: 0.05
# Episode: 849  Reward: -48 Explore: 0.05
# Episode: 850  Reward: -22 Explore: 0.05
# Episode: 851  Reward: -91 Explore: 0.05
# Episode: 852  Reward: 47 Explore: 0.05
# Episode: 853  Reward: 31 Explore: 0.05
# SUCCESS
# Episode: 854  Reward: 748 Explore: 0.05
# Episode: 855  Reward: 21 Explore: 0.05
# Episode: 856  Reward: 13 Explore: 0.05
# Episode: 857  Reward: 11 Explore: 0.05
# Episode: 858  Reward: 30 Explore: 0.05
# Episode: 859  Reward: 224 Explore: 0.05
# Episode: 860  Reward: 18 Explore: 0.05
# Episode: 861  Reward: 71 Explore: 0.05
# Episode: 862  Reward: 4 Explore: 0.05
# SUCCESS
# Episode: 863  Reward: 643 Explore: 0.05
# Episode: 864  Reward: -27 Explore: 0.05
# Episode: 865  Reward: -46 Explore: 0.05
# Episode: 866  Reward: -136 Explore: 0.05
# Episode: 867  Reward: -91 Explore: 0.05
# Episode: 868  Reward: -157 Explore: 0.05
# SUCCESS
# Episode: 869  Reward: 635 Explore: 0.05
# Episode: 870  Reward: -48 Explore: 0.05
# Episode: 871  Reward: 67 Explore: 0.05
# SUCCESS
# Episode: 872  Reward: 1335 Explore: 0.05
# Episode: 873  Reward: 10 Explore: 0.05
# Episode: 874  Reward: 17 Explore: 0.05
# SUCCESS
# Episode: 875  Reward: 1299 Explore: 0.05
# Episode: 876  Reward: 21 Explore: 0.05
# SUCCESS
# Episode: 877  Reward: 569 Explore: 0.05
# Episode: 878  Reward: 66 Explore: 0.05
# SUCCESS
# Episode: 879  Reward: 621 Explore: 0.05
# Episode: 880  Reward: 271 Explore: 0.05
# Episode: 881  Reward: -76 Explore: 0.05
# Episode: 882  Reward: 59 Explore: 0.05
# Episode: 883  Reward: 6 Explore: 0.05
# Episode: 884  Reward: -98 Explore: 0.05
# Episode: 885  Reward: -152 Explore: 0.05
# SUCCESS
# Episode: 886  Reward: 1319 Explore: 0.05
# SUCCESS
# Episode: 887  Reward: 1374 Explore: 0.05
# Episode: 888  Reward: 11 Explore: 0.05
# Episode: 889  Reward: 167 Explore: 0.05
# Episode: 890  Reward: -108 Explore: 0.05
# Episode: 891  Reward: -112 Explore: 0.05
# SUCCESS
# Episode: 892  Reward: 1526 Explore: 0.05
# Episode: 893  Reward: 24 Explore: 0.05
# Episode: 894  Reward: 55 Explore: 0.05
# SUCCESS
# Episode: 895  Reward: 604 Explore: 0.05
# Episode: 896  Reward: 47 Explore: 0.05
# Episode: 897  Reward: 28 Explore: 0.05
# Episode: 898  Reward: 15 Explore: 0.05
# Episode: 899  Reward: -135 Explore: 0.05
# Episode: 900  Reward: -8 Explore: 0.05
# Episode: 901  Reward: 30 Explore: 0.05
# Episode: 902  Reward: 26 Explore: 0.05
# Episode: 903  Reward: 363 Explore: 0.05
# Episode: 904  Reward: -127 Explore: 0.05
# Episode: 905  Reward: -19 Explore: 0.05
# Episode: 906  Reward: -190 Explore: 0.05
# SUCCESS
# Episode: 907  Reward: 576 Explore: 0.05
# Episode: 908  Reward: 381 Explore: 0.05
# Episode: 909  Reward: 7 Explore: 0.05
# Episode: 910  Reward: 64 Explore: 0.05
# Episode: 911  Reward: -1 Explore: 0.05
# Episode: 912  Reward: 43 Explore: 0.05
# Episode: 913  Reward: -246 Explore: 0.05
# Episode: 914  Reward: 36 Explore: 0.05
# Episode: 915  Reward: 94 Explore: 0.05
# Episode: 916  Reward: -31 Explore: 0.05
# Episode: 917  Reward: 75 Explore: 0.05
# Episode: 918  Reward: 26 Explore: 0.05
# Episode: 919  Reward: -49 Explore: 0.05
# Episode: 920  Reward: -163 Explore: 0.05
# Episode: 921  Reward: -5 Explore: 0.05
# Episode: 922  Reward: 13 Explore: 0.05
# Episode: 923  Reward: -265 Explore: 0.05
# Episode: 924  Reward: -17 Explore: 0.05
# Episode: 925  Reward: -55 Explore: 0.05
# Episode: 926  Reward: -22 Explore: 0.05
# Episode: 927  Reward: -238 Explore: 0.05
# Episode: 928  Reward: 101 Explore: 0.05
# Episode: 929  Reward: -97 Explore: 0.05
# Episode: 930  Reward: -72 Explore: 0.05
# Episode: 931  Reward: -36 Explore: 0.05
# Episode: 932  Reward: 19 Explore: 0.05
# Episode: 933  Reward: -279 Explore: 0.05
# Episode: 934  Reward: 159 Explore: 0.05
# SUCCESS
# Episode: 935  Reward: 1263 Explore: 0.05
# Episode: 936  Reward: -70 Explore: 0.05
# Episode: 937  Reward: 23 Explore: 0.05
# Episode: 938  Reward: 31 Explore: 0.05
# Episode: 939  Reward: -56 Explore: 0.05
# SUCCESS
# Episode: 940  Reward: 1496 Explore: 0.05
# Episode: 941  Reward: 20 Explore: 0.05
# Episode: 942  Reward: -35 Explore: 0.05
# Episode: 943  Reward: -100 Explore: 0.05
# Episode: 944  Reward: -53 Explore: 0.05
# Episode: 945  Reward: -46 Explore: 0.05
# Episode: 946  Reward: 13 Explore: 0.05
# Episode: 947  Reward: -56 Explore: 0.05
# Episode: 948  Reward: -113 Explore: 0.05
# Episode: 949  Reward: -143 Explore: 0.05
# Episode: 950  Reward: 6 Explore: 0.05
# Episode: 951  Reward: -29 Explore: 0.05
# Episode: 952  Reward: -1 Explore: 0.05
# Episode: 953  Reward: 85 Explore: 0.05
# Episode: 954  Reward: -125 Explore: 0.05
# Episode: 955  Reward: -342 Explore: 0.05
# Episode: 956  Reward: -367 Explore: 0.05
# Episode: 957  Reward: -344 Explore: 0.05
# Episode: 958  Reward: 51 Explore: 0.05
# Episode: 959  Reward: -206 Explore: 0.05
# Episode: 960  Reward: -157 Explore: 0.05
# Episode: 961  Reward: -67 Explore: 0.05
# Episode: 962  Reward: -60 Explore: 0.05
# Episode: 963  Reward: 33 Explore: 0.05
# Episode: 964  Reward: -72 Explore: 0.05
# Episode: 965  Reward: -179 Explore: 0.05
# Episode: 966  Reward: -123 Explore: 0.05
# Episode: 967  Reward: -128 Explore: 0.05
# Episode: 968  Reward: -179 Explore: 0.05
# Episode: 969  Reward: -181 Explore: 0.05
# Episode: 970  Reward: -170 Explore: 0.05
# Episode: 971  Reward: -236 Explore: 0.05
# Episode: 972  Reward: -217 Explore: 0.05
# Episode: 973  Reward: -188 Explore: 0.05
# Episode: 974  Reward: -67 Explore: 0.05
# Episode: 975  Reward: -40 Explore: 0.05
# Episode: 976  Reward: -99 Explore: 0.05
# Episode: 977  Reward: -107 Explore: 0.05
# Episode: 978  Reward: -136 Explore: 0.05
# Episode: 979  Reward: -110 Explore: 0.05
# Episode: 980  Reward: 19 Explore: 0.05
# Episode: 981  Reward: -76 Explore: 0.05
# Episode: 982  Reward: 166 Explore: 0.05
# Episode: 983  Reward: -128 Explore: 0.05
# Episode: 984  Reward: -72 Explore: 0.05
# Episode: 985  Reward: -67 Explore: 0.05
# Episode: 986  Reward: -15 Explore: 0.05
# Episode: 987  Reward: -71 Explore: 0.05
# Episode: 988  Reward: -11 Explore: 0.05
# Episode: 989  Reward: 37 Explore: 0.05
# Episode: 990  Reward: 35 Explore: 0.05
# Episode: 991  Reward: 32 Explore: 0.05
# Episode: 992  Reward: -9 Explore: 0.05
# Episode: 993  Reward: 2 Explore: 0.05
# Episode: 994  Reward: -26 Explore: 0.05
# Episode: 995  Reward: 66 Explore: 0.05
# Episode: 996  Reward: -18 Explore: 0.05
# Episode: 997  Reward: 916 Explore: 0.05
# Episode: 998  Reward: 24 Explore: 0.05
# Episode: 999  Reward: -5 Explore: 0.05
# SUCCESS
# Episode: 1000  Reward: 678 Explore: 0.05
# Episode: 1001  Reward: -68 Explore: 0.05
# Episode: 1002  Reward: 89 Explore: 0.05
# SUCCESS
# Episode: 1003  Reward: 1521 Explore: 0.05
# Episode: 1004  Reward: 3 Explore: 0.05
# Episode: 1005  Reward: 15 Explore: 0.05
# Episode: 1006  Reward: -2 Explore: 0.05
# Episode: 1007  Reward: -35 Explore: 0.05
# Episode: 1008  Reward: -86 Explore: 0.05
# Episode: 1009  Reward: -42 Explore: 0.05
# Episode: 1010  Reward: -87 Explore: 0.05
# Episode: 1011  Reward: -6 Explore: 0.05
# Episode: 1012  Reward: 20 Explore: 0.05
# SUCCESS
# Episode: 1013  Reward: 689 Explore: 0.05
# Episode: 1014  Reward: 14 Explore: 0.05
# Episode: 1015  Reward: -48 Explore: 0.05
# Episode: 1016  Reward: -37 Explore: 0.05
# Episode: 1017  Reward: 62 Explore: 0.05
# Episode: 1018  Reward: 70 Explore: 0.05
# Episode: 1019  Reward: 95 Explore: 0.05
# Episode: 1020  Reward: -38 Explore: 0.05
# Episode: 1021  Reward: 36 Explore: 0.05
# Episode: 1022  Reward: 50 Explore: 0.05
# SUCCESS
# Episode: 1023  Reward: 658 Explore: 0.05
# Episode: 1024  Reward: -134 Explore: 0.05
# Episode: 1025  Reward: 4 Explore: 0.05
# Episode: 1026  Reward: -83 Explore: 0.05
# Episode: 1027  Reward: -2 Explore: 0.05
# Episode: 1028  Reward: 37 Explore: 0.05
# Episode: 1029  Reward: 239 Explore: 0.05
# Episode: 1030  Reward: 25 Explore: 0.05
# Episode: 1031  Reward: 28 Explore: 0.05
# Episode: 1032  Reward: -5 Explore: 0.05
# SUCCESS
# Episode: 1033  Reward: 655 Explore: 0.05
# Episode: 1034  Reward: -20 Explore: 0.05
# Episode: 1035  Reward: 145 Explore: 0.05
# Episode: 1036  Reward: -5 Explore: 0.05
# Episode: 1037  Reward: -54 Explore: 0.05
# Episode: 1038  Reward: 19 Explore: 0.05
# Episode: 1039  Reward: -45 Explore: 0.05
# Episode: 1040  Reward: -145 Explore: 0.05
# Episode: 1041  Reward: 33 Explore: 0.05
# Episode: 1042  Reward: 48 Explore: 0.05
# Episode: 1043  Reward: 24 Explore: 0.05
# Episode: 1044  Reward: -8 Explore: 0.05
# Episode: 1045  Reward: -13 Explore: 0.05
# Episode: 1046  Reward: 10 Explore: 0.05
# Episode: 1047  Reward: 19 Explore: 0.05
# Episode: 1048  Reward: 47 Explore: 0.05
# Episode: 1049  Reward: -107 Explore: 0.05
# Episode: 1050  Reward: -247 Explore: 0.05
# /tmp/ipykernel_3777/1934568889.py:234: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10, 10), dpi=70)
# SUCCESS
# Episode: 1051  Reward: 647 Explore: 0.05
# Episode: 1052  Reward: 51 Explore: 0.05
# Episode: 1053  Reward: -115 Explore: 0.05
# Episode: 1054  Reward: -39 Explore: 0.05
# Episode: 1055  Reward: 11 Explore: 0.05
# Episode: 1056  Reward: 525 Explore: 0.05
# Episode: 1057  Reward: -8 Explore: 0.05
# Episode: 1058  Reward: -32 Explore: 0.05
# Episode: 1059  Reward: -48 Explore: 0.05
# Episode: 1060  Reward: -83 Explore: 0.05
# Episode: 1061  Reward: -36 Explore: 0.05
# Episode: 1062  Reward: -129 Explore: 0.05
# Episode: 1063  Reward: -8 Explore: 0.05
# Episode: 1064  Reward: -6 Explore: 0.05
# Episode: 1065  Reward: -132 Explore: 0.05
# Episode: 1066  Reward: -37 Explore: 0.05
# Episode: 1067  Reward: -33 Explore: 0.05
# Episode: 1068  Reward: -43 Explore: 0.05
# Episode: 1069  Reward: -158 Explore: 0.05
# Episode: 1070  Reward: -13 Explore: 0.05
# Episode: 1071  Reward: 25 Explore: 0.05
# Episode: 1072  Reward: -16 Explore: 0.05
# Episode: 1073  Reward: -191 Explore: 0.05
# Episode: 1074  Reward: 46 Explore: 0.05
# Episode: 1075  Reward: -70 Explore: 0.05
# Episode: 1076  Reward: -77 Explore: 0.05
# Episode: 1077  Reward: -34 Explore: 0.05
# Episode: 1078  Reward: -212 Explore: 0.05
# Episode: 1079  Reward: 46 Explore: 0.05
# Episode: 1080  Reward: -36 Explore: 0.05
# Episode: 1081  Reward: -50 Explore: 0.05
# Episode: 1082  Reward: -61 Explore: 0.05
# Episode: 1083  Reward: 46 Explore: 0.05
# Episode: 1084  Reward: -10 Explore: 0.05
# Episode: 1085  Reward: -87 Explore: 0.05
# Episode: 1086  Reward: -104 Explore: 0.05
# Episode: 1087  Reward: -79 Explore: 0.05
# Episode: 1088  Reward: -39 Explore: 0.05
# Episode: 1089  Reward: 4 Explore: 0.05
# Episode: 1090  Reward: 13 Explore: 0.05
# Episode: 1091  Reward: -8 Explore: 0.05
# Episode: 1092  Reward: -89 Explore: 0.05
# Episode: 1093  Reward: -83 Explore: 0.05
# Episode: 1094  Reward: 45 Explore: 0.05
# Episode: 1095  Reward: 3 Explore: 0.05
# Episode: 1096  Reward: -38 Explore: 0.05
# Episode: 1097  Reward: 11 Explore: 0.05
# Episode: 1098  Reward: 33 Explore: 0.05
# Episode: 1099  Reward: -91 Explore: 0.05
# Episode: 1100  Reward: 23 Explore: 0.05
# Episode: 1101  Reward: -38 Explore: 0.05
# Episode: 1102  Reward: -17 Explore: 0.05
# Episode: 1103  Reward: -119 Explore: 0.05
# Episode: 1104  Reward: 69 Explore: 0.05
# Episode: 1105  Reward: 28 Explore: 0.05
# Episode: 1106  Reward: -41 Explore: 0.05
# Episode: 1107  Reward: -104 Explore: 0.05
# Episode: 1108  Reward: -140 Explore: 0.05
# Episode: 1109  Reward: -11 Explore: 0.05
# Episode: 1110  Reward: -103 Explore: 0.05
# Episode: 1111  Reward: -152 Explore: 0.05
# Episode: 1112  Reward: -20 Explore: 0.05
# Episode: 1113  Reward: -23 Explore: 0.05
# Episode: 1114  Reward: 16 Explore: 0.05
# Episode: 1115  Reward: -14 Explore: 0.05
# Episode: 1116  Reward: 14 Explore: 0.05
# Episode: 1117  Reward: -37 Explore: 0.05
# Episode: 1118  Reward: 36 Explore: 0.05
# SUCCESS
# Episode: 1119  Reward: 1475 Explore: 0.05
# Episode: 1120  Reward: -68 Explore: 0.05
# Episode: 1121  Reward: -117 Explore: 0.05
# Episode: 1122  Reward: -226 Explore: 0.05
# Episode: 1123  Reward: 6 Explore: 0.05
# Episode: 1124  Reward: -13 Explore: 0.05
# Episode: 1125  Reward: 28 Explore: 0.05
# Episode: 1126  Reward: 5 Explore: 0.05
# Episode: 1127  Reward: -200 Explore: 0.05
# Episode: 1128  Reward: -60 Explore: 0.05
# Episode: 1129  Reward: -17 Explore: 0.05
# Episode: 1130  Reward: -63 Explore: 0.05
# Episode: 1131  Reward: -170 Explore: 0.05
# Episode: 1132  Reward: -91 Explore: 0.05
# Episode: 1133  Reward: -116 Explore: 0.05
# Episode: 1134  Reward: -28 Explore: 0.05
# Episode: 1135  Reward: 45 Explore: 0.05
# Episode: 1136  Reward: -151 Explore: 0.05
# Episode: 1137  Reward: 55 Explore: 0.05
# Episode: 1138  Reward: 295 Explore: 0.05
# Episode: 1139  Reward: 16 Explore: 0.05
# Episode: 1140  Reward: 53 Explore: 0.05
# Episode: 1141  Reward: 36 Explore: 0.05
# Episode: 1142  Reward: 7 Explore: 0.05
# Episode: 1143  Reward: -84 Explore: 0.05
# SUCCESS
# Episode: 1144  Reward: 1499 Explore: 0.05
# Episode: 1145  Reward: 30 Explore: 0.05
# Episode: 1146  Reward: 29 Explore: 0.05
# Episode: 1147  Reward: -89 Explore: 0.05
# SUCCESS
# Episode: 1148  Reward: 1463 Explore: 0.05
# Episode: 1149  Reward: 0 Explore: 0.05
# Episode: 1150  Reward: -86 Explore: 0.05
# Episode: 1151  Reward: -83 Explore: 0.05
# Episode: 1152  Reward: -67 Explore: 0.05
# Episode: 1153  Reward: -51 Explore: 0.05
# Episode: 1154  Reward: -173 Explore: 0.05
# Episode: 1155  Reward: -140 Explore: 0.05
# SUCCESS
# Episode: 1156  Reward: 1495 Explore: 0.05
# Episode: 1157  Reward: -52 Explore: 0.05
# Episode: 1158  Reward: 52 Explore: 0.05
# Episode: 1159  Reward: 153 Explore: 0.05
# Episode: 1160  Reward: -61 Explore: 0.05
# Episode: 1161  Reward: -5 Explore: 0.05
# Episode: 1162  Reward: 36 Explore: 0.05
# Episode: 1163  Reward: -127 Explore: 0.05
# Episode: 1164  Reward: 118 Explore: 0.05
# Episode: 1165  Reward: 48 Explore: 0.05
# ...
# Episode: 1623  Reward: -74 Explore: 0.05
# Episode: 1624  Reward: -6 Explore: 0.05
# Episode: 1625  Reward: -130 Explore: 0.05
# Episode: 1626  Reward: 50 Explore: 0.05
# Episode: 1627  Reward: 202 Explore: 0.05
# Episode: 1628  Reward: 64 Explore: 0.05
# Episode: 1629  Reward: 729 Explore: 0.05
# Episode: 1630  Reward: 17 Explore: 0.05
# Episode: 1631  Reward: 42 Explore: 0.05
# Episode: 1632  Reward: -9 Explore: 0.05
# SUCCESS
# Episode: 1633  Reward: 1581 Explore: 0.05
# Episode: 1634  Reward: 87 Explore: 0.05
# Episode: 1635  Reward: -269 Explore: 0.05
# SUCCESS
# Episode: 1636  Reward: 1340 Explore: 0.05
# Episode: 1637  Reward: -23 Explore: 0.05
# Episode: 1638  Reward: 3 Explore: 0.05
# Episode: 1639  Reward: 40 Explore: 0.05
# Episode: 1640  Reward: 152 Explore: 0.05
# Episode: 1641  Reward: 37 Explore: 0.05
# Episode: 1642  Reward: 21 Explore: 0.05
# Episode: 1643  Reward: 31 Explore: 0.05
# SUCCESS
# Episode: 1644  Reward: 757 Explore: 0.05
# SUCCESS
# Episode: 1645  Reward: 693 Explore: 0.05
# Episode: 1646  Reward: -3 Explore: 0.05
# Episode: 1647  Reward: 25 Explore: 0.05
# Episode: 1648  Reward: 87 Explore: 0.05
# Episode: 1649  Reward: 65 Explore: 0.05
# Episode: 1650  Reward: 52 Explore: 0.05
# Episode: 1651  Reward: 2 Explore: 0.05
# Episode: 1652  Reward: -26 Explore: 0.05
# Episode: 1653  Reward: 24 Explore: 0.05
# Episode: 1654  Reward: -42 Explore: 0.05
# Episode: 1655  Reward: 31 Explore: 0.05
# Episode: 1656  Reward: -15 Explore: 0.05
# Episode: 1657  Reward: 138 Explore: 0.05
# Episode: 1658  Reward: -60 Explore: 0.05
# Episode: 1659  Reward: -46 Explore: 0.05
# Episode: 1660  Reward: -71 Explore: 0.05
# Episode: 1661  Reward: -72 Explore: 0.05
# Episode: 1662  Reward: 9 Explore: 0.05
# Episode: 1663  Reward: -122 Explore: 0.05
# Episode: 1664  Reward: -24 Explore: 0.05
# Episode: 1665  Reward: 28 Explore: 0.05
# Episode: 1666  Reward: -32 Explore: 0.05
# Episode: 1667  Reward: 18 Explore: 0.05
# Episode: 1668  Reward: 50 Explore: 0.05
# Episode: 1669  Reward: 8 Explore: 0.05
# Episode: 1670  Reward: 9 Explore: 0.05
# Episode: 1671  Reward: -9 Explore: 0.05
# Episode: 1672  Reward: 94 Explore: 0.05
# Episode: 1673  Reward: 40 Explore: 0.05
# Episode: 1674  Reward: 47 Explore: 0.05
# SUCCESS
# Episode: 1675  Reward: 1454 Explore: 0.05
# Episode: 1676  Reward: 39 Explore: 0.05
# Episode: 1677  Reward: 25 Explore: 0.05
# Episode: 1678  Reward: 65 Explore: 0.05
# SUCCESS
# Episode: 1679  Reward: 1614 Explore: 0.05
# Episode: 1680  Reward: 68 Explore: 0.05
# Episode: 1681  Reward: 54 Explore: 0.05
# Episode: 1682  Reward: -175 Explore: 0.05
# Episode: 1683  Reward: 1 Explore: 0.05
# Episode: 1684  Reward: 29 Explore: 0.05
# Episode: 1685  Reward: 0 Explore: 0.05
# Episode: 1686  Reward: -16 Explore: 0.05
# Episode: 1687  Reward: -209 Explore: 0.05
# Episode: 1688  Reward: -133 Explore: 0.05
# Episode: 1689  Reward: 15 Explore: 0.05
# Episode: 1690  Reward: 80 Explore: 0.05
# Episode: 1691  Reward: 47 Explore: 0.05
# Episode: 1692  Reward: 770 Explore: 0.05
# Episode: 1693  Reward: 1 Explore: 0.05
# Episode: 1694  Reward: 114 Explore: 0.05
# Episode: 1695  Reward: 81 Explore: 0.05
# Episode: 1696  Reward: 262 Explore: 0.05
# Episode: 1697  Reward: 35 Explore: 0.05
# Episode: 1698  Reward: -120 Explore: 0.05
# Episode: 1699  Reward: 72 Explore: 0.05
# Episode: 1700  Reward: 11 Explore: 0.05
# Episode: 1701  Reward: -21 Explore: 0.05
# Episode: 1702  Reward: 57 Explore: 0.05
# Episode: 1703  Reward: -18 Explore: 0.05
# Episode: 1704  Reward: 80 Explore: 0.05
# Episode: 1705  Reward: 62 Explore: 0.05
# Episode: 1706  Reward: 12 Explore: 0.05
# Episode: 1707  Reward: 34 Explore: 0.05
# Episode: 1708  Reward: -32 Explore: 0.05
# Episode: 1709  Reward: -45 Explore: 0.05
# Episode: 1710  Reward: 53 Explore: 0.05
# Episode: 1711  Reward: 46 Explore: 0.05
# Episode: 1712  Reward: 33 Explore: 0.05
# Episode: 1713  Reward: 27 Explore: 0.05
# Episode: 1714  Reward: -29 Explore: 0.05
# Episode: 1715  Reward: 42 Explore: 0.05
# SUCCESS
# Episode: 1716  Reward: 934 Explore: 0.05
# SUCCESS
# Episode: 1717  Reward: 1539 Explore: 0.05
# SUCCESS
# Episode: 1718  Reward: 1028 Explore: 0.05
# Episode: 1719  Reward: 307 Explore: 0.05
# Episode: 1720  Reward: 120 Explore: 0.05
# Episode: 1721  Reward: 11 Explore: 0.05
# Episode: 1722  Reward: -29 Explore: 0.05
# SUCCESS
# Episode: 1723  Reward: 899 Explore: 0.05
# Episode: 1724  Reward: 8 Explore: 0.05
# Episode: 1725  Reward: 49 Explore: 0.05
# Episode: 1726  Reward: 48 Explore: 0.05
# Episode: 1727  Reward: 30 Explore: 0.05
# Episode: 1728  Reward: 6 Explore: 0.05
# Episode: 1729  Reward: 150 Explore: 0.05
# Episode: 1730  Reward: 33 Explore: 0.05
# Episode: 1731  Reward: 92 Explore: 0.05
# Episode: 1732  Reward: 12 Explore: 0.05
# SUCCESS
# Episode: 1733  Reward: 936 Explore: 0.05
# Episode: 1734  Reward: 371 Explore: 0.05
# Episode: 1735  Reward: 41 Explore: 0.05
# Episode: 1736  Reward: 128 Explore: 0.05
# Episode: 1737  Reward: 89 Explore: 0.05
# Episode: 1738  Reward: 29 Explore: 0.05
# Episode: 1739  Reward: 40 Explore: 0.05
# SUCCESS
# Episode: 1740  Reward: 867 Explore: 0.05
# Episode: 1741  Reward: -37 Explore: 0.05
# Episode: 1742  Reward: 30 Explore: 0.05
# Episode: 1743  Reward: 120 Explore: 0.05
# Episode: 1744  Reward: -129 Explore: 0.05
# Episode: 1745  Reward: 58 Explore: 0.05
# Episode: 1746  Reward: 77 Explore: 0.05
# Episode: 1747  Reward: 149 Explore: 0.05
# Episode: 1748  Reward: 43 Explore: 0.05
# SUCCESS
# Episode: 1749  Reward: 1059 Explore: 0.05
# Episode: 1750  Reward: 10 Explore: 0.05
# Episode: 1751  Reward: -13 Explore: 0.05
# Episode: 1752  Reward: -43 Explore: 0.05
# Episode: 1753  Reward: 41 Explore: 0.05
# Episode: 1754  Reward: -16 Explore: 0.05
# Episode: 1755  Reward: 13 Explore: 0.05
# Episode: 1756  Reward: 70 Explore: 0.05
# Episode: 1757  Reward: -11 Explore: 0.05
# Episode: 1758  Reward: 47 Explore: 0.05
# Episode: 1759  Reward: -93 Explore: 0.05
# Episode: 1760  Reward: 40 Explore: 0.05
# Episode: 1761  Reward: -2 Explore: 0.05
# Episode: 1762  Reward: 38 Explore: 0.05
# Episode: 1763  Reward: 65 Explore: 0.05
# Episode: 1764  Reward: -2 Explore: 0.05
# Episode: 1765  Reward: 20 Explore: 0.05
# Episode: 1766  Reward: 38 Explore: 0.05
# Episode: 1767  Reward: 47 Explore: 0.05
# Episode: 1768  Reward: -13 Explore: 0.05
# Episode: 1769  Reward: 600 Explore: 0.05
# Episode: 1770  Reward: 45 Explore: 0.05
# Episode: 1771  Reward: -94 Explore: 0.05
# Episode: 1772  Reward: 184 Explore: 0.05
# Episode: 1773  Reward: 13 Explore: 0.05
# Episode: 1774  Reward: -3 Explore: 0.05
# Episode: 1775  Reward: 159 Explore: 0.05
# Episode: 1776  Reward: 4 Explore: 0.05
# Episode: 1777  Reward: -24 Explore: 0.05
# Episode: 1778  Reward: -72 Explore: 0.05
# Episode: 1779  Reward: 25 Explore: 0.05
# SUCCESS
# Episode: 1780  Reward: 747 Explore: 0.05
# Episode: 1781  Reward: 60 Explore: 0.05
# Episode: 1782  Reward: -12 Explore: 0.05
# Episode: 1783  Reward: -79 Explore: 0.05
# Episode: 1784  Reward: -49 Explore: 0.05
# Episode: 1785  Reward: 20 Explore: 0.05
# Episode: 1786  Reward: -21 Explore: 0.05
# Episode: 1787  Reward: 71 Explore: 0.05
# Episode: 1788  Reward: 400 Explore: 0.05
# Episode: 1789  Reward: 1035 Explore: 0.05
# Episode: 1790  Reward: -3 Explore: 0.05
# Episode: 1791  Reward: 0 Explore: 0.05
# SUCCESS
# Episode: 1792  Reward: 1227 Explore: 0.05
# SUCCESS
# Episode: 1793  Reward: 1241 Explore: 0.05
# Episode: 1794  Reward: -99 Explore: 0.05
# Episode: 1795  Reward: 10 Explore: 0.05
# Episode: 1796  Reward: -33 Explore: 0.05
# Episode: 1797  Reward: -84 Explore: 0.05
# SUCCESS
# Episode: 1798  Reward: 931 Explore: 0.05
# Episode: 1799  Reward: -94 Explore: 0.05
# Episode: 1800  Reward: 40 Explore: 0.05
# Episode: 1801  Reward: -28 Explore: 0.05
# SUCCESS
# Episode: 1802  Reward: 769 Explore: 0.05
# Episode: 1803  Reward: 3 Explore: 0.05
# Episode: 1804  Reward: -158 Explore: 0.05
# Episode: 1805  Reward: -124 Explore: 0.05
# SUCCESS
# Episode: 1806  Reward: 635 Explore: 0.05
# Episode: 1807  Reward: 44 Explore: 0.05
# SUCCESS
# Episode: 1808  Reward: 1203 Explore: 0.05
# Episode: 1809  Reward: -31 Explore: 0.05
# Episode: 1810  Reward: -144 Explore: 0.05
# Episode: 1811  Reward: -229 Explore: 0.05
# SUCCESS
# Episode: 1812  Reward: 597 Explore: 0.05
# SUCCESS
# Episode: 1813  Reward: 752 Explore: 0.05
# SUCCESS
# Episode: 1814  Reward: 1021 Explore: 0.05
# SUCCESS
# Episode: 1815  Reward: 1157 Explore: 0.05
# Episode: 1816  Reward: 146 Explore: 0.05
# Episode: 1817  Reward: -118 Explore: 0.05
# SUCCESS
# Episode: 1818  Reward: 1580 Explore: 0.05
# Episode: 1819  Reward: -162 Explore: 0.05
# SUCCESS
# Episode: 1820  Reward: 1622 Explore: 0.05
# Episode: 1821  Reward: -267 Explore: 0.05
# Episode: 1822  Reward: 12 Explore: 0.05
# SUCCESS
# Episode: 1823  Reward: 1265 Explore: 0.05
# SUCCESS
# Episode: 1824  Reward: 1497 Explore: 0.05
# Episode: 1825  Reward: -242 Explore: 0.05
# SUCCESS
# Episode: 1826  Reward: 1583 Explore: 0.05
# Episode: 1827  Reward: -221 Explore: 0.05
# Episode: 1828  Reward: -189 Explore: 0.05
# Episode: 1829  Reward: -162 Explore: 0.05
# Episode: 1830  Reward: -177 Explore: 0.05
# Episode: 1831  Reward: -1 Explore: 0.05
# Episode: 1832  Reward: -63 Explore: 0.05
# SUCCESS
# Episode: 1833  Reward: 1222 Explore: 0.05
# Episode: 1834  Reward: -100 Explore: 0.05
# Episode: 1835  Reward: -344 Explore: 0.05
# SUCCESS
# Episode: 1836  Reward: 1194 Explore: 0.05
# Episode: 1837  Reward: -182 Explore: 0.05
# Episode: 1838  Reward: -54 Explore: 0.05
# Episode: 1839  Reward: -146 Explore: 0.05
# Episode: 1840  Reward: -177 Explore: 0.05
# Episode: 1841  Reward: -149 Explore: 0.05
# Episode: 1842  Reward: -12 Explore: 0.05
# Episode: 1843  Reward: -14 Explore: 0.05
# Episode: 1844  Reward: -283 Explore: 0.05
# Episode: 1845  Reward: -194 Explore: 0.05
# Episode: 1846  Reward: -36 Explore: 0.05
# Episode: 1847  Reward: -155 Explore: 0.05
# SUCCESS
# Episode: 1848  Reward: 1599 Explore: 0.05
# Episode: 1849  Reward: 1 Explore: 0.05
# Episode: 1850  Reward: -63 Explore: 0.05
# Episode: 1851  Reward: -32 Explore: 0.05
# Episode: 1852  Reward: -90 Explore: 0.05
# Episode: 1853  Reward: -37 Explore: 0.05
# Episode: 1854  Reward: 72 Explore: 0.05
# Episode: 1855  Reward: 51 Explore: 0.05
# Episode: 1856  Reward: 38 Explore: 0.05
# Episode: 1857  Reward: 6 Explore: 0.05
# SUCCESS
# Episode: 1858  Reward: 1022 Explore: 0.05
# Episode: 1859  Reward: -43 Explore: 0.05
# Episode: 1860  Reward: 14 Explore: 0.05
# Episode: 1861  Reward: 42 Explore: 0.05
# SUCCESS
# Episode: 1862  Reward: 1670 Explore: 0.05
# Episode: 1863  Reward: 13 Explore: 0.05
# Episode: 1864  Reward: 75 Explore: 0.05
# Episode: 1865  Reward: -257 Explore: 0.05
# Episode: 1866  Reward: 59 Explore: 0.05
# Episode: 1867  Reward: -211 Explore: 0.05
# Episode: 1868  Reward: 24 Explore: 0.05
# Episode: 1869  Reward: 19 Explore: 0.05
# Episode: 1870  Reward: 43 Explore: 0.05
# Episode: 1871  Reward: 83 Explore: 0.05
# Episode: 1872  Reward: -193 Explore: 0.05
# SUCCESS
# Episode: 1873  Reward: 1507 Explore: 0.05
# SUCCESS
# Episode: 1874  Reward: 891 Explore: 0.05
# Episode: 1875  Reward: 33 Explore: 0.05
# Episode: 1876  Reward: 63 Explore: 0.05
# Episode: 1877  Reward: 121 Explore: 0.05
# Episode: 1878  Reward: 63 Explore: 0.05
# Episode: 1879  Reward: 156 Explore: 0.05
# SUCCESS
# Episode: 1880  Reward: 1014 Explore: 0.05
# Episode: 1881  Reward: 54 Explore: 0.05
# Episode: 1882  Reward: -158 Explore: 0.05
# Episode: 1883  Reward: 64 Explore: 0.05
# Episode: 1884  Reward: 45 Explore: 0.05
# Episode: 1885  Reward: 39 Explore: 0.05
# Episode: 1886  Reward: 123 Explore: 0.05
# SUCCESS
# Episode: 1887  Reward: 764 Explore: 0.05
# SUCCESS
# Episode: 1888  Reward: 633 Explore: 0.05
# SUCCESS
# Episode: 1889  Reward: 805 Explore: 0.05
# Episode: 1890  Reward: 202 Explore: 0.05
# Episode: 1891  Reward: -58 Explore: 0.05
# Episode: 1892  Reward: 72 Explore: 0.05
# SUCCESS
# Episode: 1893  Reward: 900 Explore: 0.05
# Episode: 1894  Reward: -219 Explore: 0.05
# SUCCESS
# Episode: 1895  Reward: 921 Explore: 0.05
# Episode: 1896  Reward: 113 Explore: 0.05
# Episode: 1897  Reward: -234 Explore: 0.05
# Episode: 1898  Reward: 53 Explore: 0.05
# Episode: 1899  Reward: -238 Explore: 0.05
# Episode: 1900  Reward: 4 Explore: 0.05
# Episode: 1901  Reward: 59 Explore: 0.05
# Episode: 1902  Reward: 13 Explore: 0.05
# Episode: 1903  Reward: -210 Explore: 0.05
# SUCCESS
# Episode: 1904  Reward: 1674 Explore: 0.05
# Episode: 1905  Reward: 10 Explore: 0.05
# Episode: 1906  Reward: -5 Explore: 0.05
# SUCCESS
# Episode: 1907  Reward: 1640 Explore: 0.05
# Episode: 1908  Reward: 53 Explore: 0.05
# SUCCESS
# Episode: 1909  Reward: 1329 Explore: 0.05
# Episode: 1910  Reward: -12 Explore: 0.05
# SUCCESS
# Episode: 1911  Reward: 710 Explore: 0.05
# Episode: 1912  Reward: 1 Explore: 0.05
# Episode: 1913  Reward: 63 Explore: 0.05
# Episode: 1914  Reward: -175 Explore: 0.05
# Episode: 1915  Reward: 66 Explore: 0.05
# SUCCESS
# Episode: 1916  Reward: 1256 Explore: 0.05
# Episode: 1917  Reward: 157 Explore: 0.05
# Episode: 1918  Reward: 73 Explore: 0.05
# Episode: 1919  Reward: -175 Explore: 0.05
# Episode: 1920  Reward: 25 Explore: 0.05
# Episode: 1921  Reward: 53 Explore: 0.05
# Episode: 1922  Reward: 25 Explore: 0.05
# Episode: 1923  Reward: -205 Explore: 0.05
# Episode: 1924  Reward: -41 Explore: 0.05
# Episode: 1925  Reward: 19 Explore: 0.05
# Episode: 1926  Reward: -40 Explore: 0.05
# Episode: 1927  Reward: -89 Explore: 0.05
# Episode: 1928  Reward: -21 Explore: 0.05
# Episode: 1929  Reward: 45 Explore: 0.05
# Episode: 1930  Reward: 129 Explore: 0.05
# Episode: 1931  Reward: -197 Explore: 0.05
# Episode: 1932  Reward: 97 Explore: 0.05
# Episode: 1933  Reward: 54 Explore: 0.05
# Episode: 1934  Reward: 24 Explore: 0.05
# SUCCESS
# Episode: 1935  Reward: 1594 Explore: 0.05
# SUCCESS
# Episode: 1936  Reward: 1229 Explore: 0.05
# SUCCESS
# Episode: 1937  Reward: 1611 Explore: 0.05
# SUCCESS
# Episode: 1938  Reward: 1640 Explore: 0.05
# Episode: 1939  Reward: 23 Explore: 0.05
# Episode: 1940  Reward: 21 Explore: 0.05
# Episode: 1941  Reward: 8 Explore: 0.05
# SUCCESS
# Episode: 1942  Reward: 1260 Explore: 0.05
# SUCCESS
# Episode: 1943  Reward: 1218 Explore: 0.05
# Episode: 1944  Reward: 55 Explore: 0.05
# SUCCESS
# Episode: 1945  Reward: 1340 Explore: 0.05
# Episode: 1946  Reward: 42 Explore: 0.05
# Episode: 1947  Reward: -29 Explore: 0.05
# SUCCESS
# Episode: 1948  Reward: 1245 Explore: 0.05
# SUCCESS
# Episode: 1949  Reward: 1016 Explore: 0.05
# Episode: 1950  Reward: 116 Explore: 0.05
# Episode: 1951  Reward: 31 Explore: 0.05
# Episode: 1952  Reward: -217 Explore: 0.05
# Episode: 1953  Reward: -230 Explore: 0.05
# Episode: 1954  Reward: 81 Explore: 0.05
# Episode: 1955  Reward: 12 Explore: 0.05
# SUCCESS
# Episode: 1956  Reward: 1162 Explore: 0.05
# Episode: 1957  Reward: 808 Explore: 0.05
# Episode: 1958  Reward: -122 Explore: 0.05
# SUCCESS
# Episode: 1959  Reward: 1569 Explore: 0.05
# Episode: 1960  Reward: -89 Explore: 0.05
# Episode: 1961  Reward: -132 Explore: 0.05
# SUCCESS
# Episode: 1962  Reward: 1216 Explore: 0.05
# SUCCESS
# Episode: 1963  Reward: 1344 Explore: 0.05
# Episode: 1964  Reward: 38 Explore: 0.05
# SUCCESS
# Episode: 1965  Reward: 1564 Explore: 0.05
# Episode: 1966  Reward: -205 Explore: 0.05
# Episode: 1967  Reward: -13 Explore: 0.05
# Episode: 1968  Reward: -103 Explore: 0.05
# Episode: 1969  Reward: 14 Explore: 0.05
# Episode: 1970  Reward: 13 Explore: 0.05
# Episode: 1971  Reward: 17 Explore: 0.05
# Episode: 1972  Reward: -155 Explore: 0.05
# Episode: 1973  Reward: 15 Explore: 0.05
# Episode: 1974  Reward: -150 Explore: 0.05
# Episode: 1975  Reward: -170 Explore: 0.05
# Episode: 1976  Reward: -65 Explore: 0.05
# Episode: 1977  Reward: 34 Explore: 0.05
# Episode: 1978  Reward: -7 Explore: 0.05
# Episode: 1979  Reward: 39 Explore: 0.05
# SUCCESS
# Episode: 1980  Reward: 1294 Explore: 0.05
# SUCCESS
# Episode: 1981  Reward: 1356 Explore: 0.05
# Episode: 1982  Reward: -12 Explore: 0.05
# Episode: 1983  Reward: 95 Explore: 0.05
# Episode: 1984  Reward: 14 Explore: 0.05
# Episode: 1985  Reward: 27 Explore: 0.05
# Episode: 1986  Reward: 113 Explore: 0.05
# Episode: 1987  Reward: -166 Explore: 0.05
# Episode: 1988  Reward: 41 Explore: 0.05
# Episode: 1989  Reward: -210 Explore: 0.05
# Episode: 1990  Reward: 19 Explore: 0.05
# SUCCESS
# Episode: 1991  Reward: 1199 Explore: 0.05
# Episode: 1992  Reward: -137 Explore: 0.05
# Episode: 1993  Reward: -89 Explore: 0.05
# Episode: 1994  Reward: 7 Explore: 0.05
# Episode: 1995  Reward: 61 Explore: 0.05
# Episode: 1996  Reward: -52 Explore: 0.05
# Episode: 1997  Reward: -71 Explore: 0.05
# Episode: 1998  Reward: -22 Explore: 0.05
# Episode: 1999  Reward: -168 Explore: 0.05
# SUCCESS
# Episode: 2000  Reward: 1629 Explore: 0.05
# Running time:  3230.706520318985

# %%
ddpg.save('carbinet_SELF_level_9_4000+2000EPS')

# %%
data = pd.read_csv('./DPG model/level12789_check_point_final/3050epi/Rewards.csv')
y = np.array(data).squeeze()
x = range(y.shape[0])

size = 50

z = np.zeros(len(y))
m = np.zeros(len(y))

#for i in range(len(y)):
#    if y[i] >= 10:
#        y[i] = 0
        
for i in range(len(y)):
    
    if i > (size/2 -1) and i < (len(y) - size/2):  
        for j in range(size):
            z[i] += y[i + j - int(size/2)]  #平均reward
            
            if(y[i + j - int(size/2)] == 0):
                m[i] += 1                  #success rate
            
                                   
            
        z[i] = z[i] / size
        m[i] = m[i]
        

    
    
plt.figure(figsize=(10, 10), dpi=70)

plt.plot(x, y)
plt.plot(x, z)
plt.plot(x, m)

plt.legend(['y','z','m'])
plt.show()

print('maximum success rate: ', max(m)/50)
print('maximum mean rewards: ', max(z))
# Out:
# maximum success rate:  0.0
# maximum mean rewards:  800.5924504191495

# %%
data = pd.read_csv('./DPG model/level_9_4000+2000/2000epi/Rewards.csv')
y = np.array(data).squeeze()
x = range(y.shape[0])
size = 50
z = np.zeros(len(y))
for i in range(len(y)):
    if y[i] >= 300:
        y[i] = 0  
for i in range(len(y)):
    if i > (size/2 -1) and i < (len(y) - size/2):  
        for j in range(size):
            z[i] += y[i + j - int(size/2)]  #平均reward        
    z[i] = z[i]/size
plt.figure(figsize=(10, 10), dpi=70)
plt.plot(x, y)
plt.plot(x, z)
plt.legend(['y','z'])
plt.show()
print('maximum mean rewards: ', np.argmax(z))
# Out:
# maximum mean rewards:  1328

# %%
data = pd.read_csv('./DPG model/level_9_4000+2000/2000epi/Success_record.csv')
y = np.array(data).squeeze()
x = range(y.shape[0])
m = np.zeros(y.shape[0])

for i in range(50,2000):
    for j in range(50):
        if y[i-50+j] == 1:
            m[i] += 1
    m[i] = m[i] / 50   
    
plt.figure(figsize=(10, 10), dpi=70)
plt.plot(x, m)
plt.show()
print(max(m))#最大值
print(np.argmax(m))#最大值所在位置
# Out:
# 0.34
# 1837
