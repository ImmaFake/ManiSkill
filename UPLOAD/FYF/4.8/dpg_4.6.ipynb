# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import gym
import time
import mani_skill.env
import pandas as pd
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
from torch.distributions import Normal
import random
import time
use_cuda = torch.cuda.is_available()
device   = torch.device("cuda" if use_cuda else "cpu")

#####################  hyper parameters  ####################

MAX_EPISODES = 3001              
MAX_EP_STEPS = 75               

RENDER = False

LOAD_MEM = False
LOAD_MODEL = False
LOAD_FOLDER_NAME = '2450epi'

LOAD_PRETRAIN = False

CHECK_POINT_EPI = 50


ENV_NAME = 'OpenCabinetDrawer-v0'       
SEED = 123                      

var = 5
var_low_bound = 0.05

# %%
###############################  DDPG  ####################################
class DDPG(object):
    def __init__(self, a_dim, s_dim, a_bound,hidden_dim):
        self.a_dim = a_dim
        self.s_dim = s_dim
        self.a_bound = a_bound
        self.hidden_dim = hidden_dim
        self.pointer = 0                                                                         # exp buffer指针
        #self.lr_a = 0.001                                                                      # learning rate for actor
        #self.lr_c = 0.001                                                                       # learning rate for critic
        self.gamma = 0.9                                                                         # reward discount
        self.tau = 0.001                                                                          # 软更新比例
        self.memory_capacity = 10000
        self.batch_size = 32
        self.memory = np.zeros((self.memory_capacity, s_dim * 2 + a_dim + 1), dtype=np.float32)

        self.Reward_record = []
        self.Success_record = np.zeros(MAX_EPISODES)
        
        class ANet(nn.Module):                               # 定义动作网络
            def __init__(self, s_dim, a_dim, a_bound,hidden_size):
                super(ANet,self).__init__()
                self.a_bound = a_bound
                
                self.linear1 = nn.Linear(s_dim, hidden_size)
                self.linear2 = nn.Linear(hidden_size, hidden_size)
                self.linear3 = nn.Linear(hidden_size, hidden_size)
                self.linear4 = nn.Linear(hidden_size, a_dim)
                
                
                self.linear4.weight.data.uniform_(-0.03, 0.03)
                self.linear4.bias.data.uniform_(-0.03, 0.03)
#                 self.fc1 = nn.Linear(s_dim,256)
#                 self.fc1.weight.data.normal_(0,0.1)          # initialization
                
#                 self.fc2 = nn.Linear(256,512)
#                 self.fc2.weight.data.normal_(0,0.1)
#                                
#                 self.fc3 = nn.Linear(512,256)
#                 self.fc3.weight.data.normal_(0,0.1)
                
#                 self.out = nn.Linear(256,a_dim)
#                 self.out.weight.data.normal_(0,0.1)          # initialization
            def forward(self,x):
                x = F.relu(self.linear1(x))
                x = F.relu(self.linear2(x))
                x = F.relu(self.linear3(x))
                x = F.tanh(self.linear4(x))
                
#                 x = self.fc1(x)
#                 x = F.relu(x)
#                  
#                 x = self.fc2(x)
#                 x = F.relu(x)
                
#                 x = self.fc3(x)
#                 x = F.relu(x)
                
#                 x = self.out(x)
#                 x = F.tanh(x)
                actions_value = x * a_bound
                return actions_value

        class CNet(nn.Module):                               # 定义价值网络
            def __init__(self,s_dim,a_dim,hidden_size):
                super(CNet,self).__init__()
                
                self.linear1 = nn.Linear(s_dim + a_dim, hidden_size)
                self.linear2 = nn.Linear(hidden_size, hidden_size)
#                 self.linear3 = nn.Linear(hidden_size, hidden_size)
                self.linear3 = nn.Linear(hidden_size, 1)
                

                self.linear3.weight.data.uniform_(-0.03,0.03)
                self.linear3.bias.data.uniform_(-0.03,0.03)

#                 self.fcs1 = nn.Linear(s_dim,256)
#                 self.fcs1.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01)
                
#                 self.fcs2 = nn.Linear(256,512)
#                 self.fcs2.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01)
                
#                 self.fcs3 = nn.Linear(512,256)
#                 self.fcs3.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01) 
                
#                 self.fca1 = nn.Linear(a_dim,256)
#                 self.fca1.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01)
                
#                 self.fca2 = nn.Linear(256,512)
#                 self.fca2.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01)              
                
#                 self.fca3 = nn.Linear(512,256)
#                 self.fca3.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01)
                
#                 self.out = nn.Linear(256,1)
#                 self.out.weight.data.normal_(0,0.1)          # initialization
#                 #self.fcs1.weight.data.fill_(-0.01)
            def forward(self,s,a):
        
                x = torch.cat([s, a], 1)
                x = F.relu(self.linear1(x))
                x = F.relu(self.linear2(x))
#                 x = F.relu(self.linear3(x))
                x = self.linear3(x)

#                 x = self.fcs1(s)                              # 输入状态
#                 x = F.relu(x)
                
#                 x = self.fcs2(x)
#                 x = F.relu(x)
                
#                 x = self.fcs3(x)
#                 x = F.relu(x) 
                
#                 y = self.fca1(a)                              # 输入动作
#                 y = F.relu(y)
                
#                 y = self.fca2(y)                              
#                 y = F.relu(y)
                
#                 y = self.fca3(y)                              
#                 y = F.relu(y)
                
#                 net = F.relu(x+y)
#                 actions_value = self.out(net)                # 给出V(s,a)
                return x

        self.Actor_eval = ANet(s_dim, a_dim, a_bound, hidden_dim)        # 主网络
        self.Actor_target = ANet(s_dim, a_dim, a_bound, hidden_dim)      # 目标网络
        self.Critic_eval = CNet(s_dim, a_dim,hidden_dim)                # 主网络
        self.Critic_target = CNet(s_dim, a_dim,hidden_dim)              # 当前网络
        #self.ctrain = torch.optim.Adam(self.Critic_eval.parameters(),lr = self.lr_c) # critic的优化器
        #self.atrain = torch.optim.Adam(self.Actor_eval.parameters(),lr = self.lr_a)  # actor的优化器
        self.loss_td = nn.MSELoss()                          # 损失函数采用均方误差

    def choose_action(self, s):
        s = torch.unsqueeze(torch.FloatTensor(s), 0)

        return self.Actor_eval(s)[0].detach()                

    def learn(self,lr_a,lr_c):
        self.atrain = torch.optim.Adam(self.Actor_eval.parameters(),lr = lr_a)  # actor的优化器
        self.ctrain = torch.optim.Adam(self.Critic_eval.parameters(),lr = lr_c) # critic的优化器
        for x in self.Actor_target.state_dict().keys():#更新target network
            eval('self.Actor_target.' + x + '.data.mul_((1 - self.tau))')  
            eval('self.Actor_target.' + x + '.data.add_(self.tau * self.Actor_eval.' + x + '.data)')
        for x in self.Critic_target.state_dict().keys():
            eval('self.Critic_target.' + x + '.data.mul_((1- self.tau))')
            eval('self.Critic_target.' + x + '.data.add_(self.tau * self.Critic_eval.' + x + '.data)')

        # soft target replacement

        indices = np.random.choice(self.memory_capacity, size = self.batch_size)  # 随机采样的index
        bt = self.memory[indices, :]                                              # 采样batch_size个sample
        bs = torch.FloatTensor(bt[:, :self.s_dim])                                # state
        ba = torch.FloatTensor(bt[:, self.s_dim: self.s_dim + self.a_dim])        # action
        br = torch.FloatTensor(bt[:, -self.s_dim - 1: -self.s_dim])               # reward
        bs_ = torch.FloatTensor(bt[:, -self.s_dim:])                              # next state
        
        
        a = self.Actor_eval(bs)
        q = self.Critic_eval(bs,a)  

        loss_a = -torch.mean(q)            
        #print('q: ',q)
        #print('loss_a: ',loss_a)
        self.atrain.zero_grad()
        loss_a.backward()
        self.atrain.step()
        
        
        a_ = self.Actor_target(bs_)      
        q_ = self.Critic_target(bs_,a_)  
        q_target = br + self.gamma * q_  

        q_v = self.Critic_eval(bs,ba)

        td_error = self.loss_td(q_target,q_v)

        self.ctrain.zero_grad()
        td_error.backward()
        self.ctrain.step()
        
        
    def store_transition(self, s, a, r, s_):
        transition = np.hstack((s, a, [r], s_))
        index = self.pointer % self.memory_capacity     # replace the old memory with new memory
        self.memory[index, :] = transition
        self.pointer += 1                              
    
    def store_reward(self,ep_reward):
        self.Reward_record.append(ep_reward)
        
    def Record_success(self,epi):
        self.Success_record[epi] = 1
        
    def save(self,folder_name):
    
        if os.path.exists('./DPG model/' + folder_name):
            os.remove('./DPG model/' + folder_name)
            
        os.mkdir('./DPG model/' + folder_name)
    
        PATH1 = './DPG model/' + folder_name + '/Actor_eval.h5f'
        PATH2 = './DPG model/' + folder_name + '/Actor_target.h5f'
        PATH3 = './DPG model/' + folder_name + '/Critic_eval.h5f'
        PATH4 = './DPG model/' + folder_name + '/Critic_target.h5f'
    
        torch.save(self.Actor_eval.state_dict(), PATH1)
        torch.save(self.Actor_target.state_dict(), PATH2)
        torch.save(self.Critic_eval.state_dict(), PATH3)
        torch.save(self.Critic_target.state_dict(), PATH4)
    
        csv_name='./DPG model/' + folder_name + '/memory.csv'
        xml_df = pd.DataFrame(self.memory)
        xml_df.to_csv(csv_name, index = None, columns= None)
        
        csv_name='./DPG model/' + folder_name + '/Rewards.csv'
        xml_df = pd.DataFrame(self.Reward_record)
        xml_df.to_csv(csv_name, index = None, columns= None)
        
        csv_name='./DPG model/' + folder_name + '/Success_record.csv'
        xml_df = pd.DataFrame(self.Success_record)
        xml_df.to_csv(csv_name, index = None, columns= None)
        
        y = self.Reward_record
        x = range(len(y))
        plt.figure(figsize=(10, 10), dpi=70)
        plt.scatter(x, y)
        plt.savefig('./DPG model/' + folder_name + '/scatter.png')
        plt.plot(x, y)
        plt.savefig('./DPG model/' + folder_name + '/plot.png')
        
    def plot_file_rewards(self, folder_name):
        data = pd.read_csv('./DPG model/' + folder_name + '/Rewards.csv')
        y = np.array(data).squeeze()
        x = range(y.shape[0])
        plt.figure(figsize=(10, 10), dpi=70)
        #plt.plot(x, y)
        plt.scatter(x, y)
        plt.show()
    
    def plot_rewards(self, scatter):
        y = self.Reward_record
        x = range(len(y))
        plt.figure(figsize=(10, 10), dpi=70)
        
        if scatter:
            plt.scatter(x, y)
        else:
            plt.plot(x, y)
        plt.show()
    
    def load_model(self):
        self.Actor_eval.load_state_dict(torch.load('./DPG model/' + LOAD_FOLDER_NAME + '/Actor_eval.h5f'))
        self.Actor_eval.eval()
        self.Actor_target.load_state_dict(torch.load('./DPG model/' + LOAD_FOLDER_NAME + '/Actor_target.h5f'))
        self.Actor_target.eval()
        self.Critic_eval.load_state_dict(torch.load('./DPG model/' + LOAD_FOLDER_NAME + '/Critic_eval.h5f'))
        self.Critic_eval.eval()
        self.Critic_target.load_state_dict(torch.load('./DPG model/' + LOAD_FOLDER_NAME + '/Critic_target.h5f'))
        self.Critic_target.eval()
        print("Load network parameters of: " + LOAD_FOLDER_NAME) 
        
    def load_memory(self):
        data = pd.read_csv('./DPG model/' + LOAD_FOLDER_NAME + '/memory.csv')
        self.memory = np.array(data)
        print("Load memory of: " + LOAD_FOLDER_NAME)
        
    def load_pretrain(self):    
        ddpg.Actor_eval.load_state_dict(torch.load('./DPG model/pretrain/Actor_eval.h5f'))
        ddpg.Actor_eval.eval()
        ddpg.Actor_target.load_state_dict(torch.load('./DPG model/pretrain/Actor_eval.h5f'))
        ddpg.Actor_target.eval() 
#         ddpg.Critic_eval.load_state_dict(torch.load('./DPG model/pretrain/Critic_eval.h5f'))
#         ddpg.Critic_eval.eval()
#         ddpg.Critic_target.load_state_dict(torch.load('./DPG model/pretrain/Critic_eval.h5f'))
#         ddpg.Critic_target.eval()

# %%
##############################  training  ####################################
env = gym.make(ENV_NAME)
env = env.unwrapped
env.seed(SEED)                                          # 设置Gym的随机数种子
torch.manual_seed(SEED)                                 # 设置pytorch的随机数种子

env.set_env_mode(obs_mode='state', reward_type='dense')

s_dim = env.observation_space.shape[0]                  # 状态空间
a_dim = env.action_space.shape[0]                       # 动作空间
a_bound = 1                                             # 动作取值区间,对称区间，故只取上界
hidden_dim = 512
lr_a = 0.001
lr_c = 0.001
ddpg = DDPG(a_dim, s_dim, a_bound, hidden_dim)

if LOAD_MODEL:
    ddpg.load_model()

    
if LOAD_MEM:
    ddpg.load_memory()

if LOAD_PRETRAIN:
    ddpg.load_pretrain()


if LOAD_MODEL or LOAD_MEM:
    var = 0.1

if LOAD_PRETRAIN:
    var = 0.2

list = [1, 2, 7, 8, 9, 11, 14, 18, 33]
t1 = time.time()                                        # 开始时间

for i in range(MAX_EPISODES):
    LEVEL = random.choice(list)
    s = env.reset(level = LEVEL)
    #s = env.reset(level = int(random.choice([1,2,7,8,9])))
    ep_reward = 0
    
    #if i > 500:
        
     #   if lr_a >= 0.000001:
      #      lr_a = lr_a - 0.0000001
       # if lr_c >= 0.000001:
        #    lr_c = lr_c - 0.0000001
    
    for j in range(MAX_EP_STEPS):
        if RENDER:
            env.render('human')

        # Add exploration noise
        a = ddpg.choose_action(s)

        a = np.clip(np.random.normal(a, var), -1, 1)    # add randomness to action selection for exploration

        s_, r, done, info = env.step(a)
        
        info_ = info.get('eval_info')
        
        if info_.get('success'):
            print('SUCCESS')
            ddpg.Record_success(i)
            r += 100 #+200
        
        r += 10
        r = r * 200
        r+= 200
        r += info.get('qpos') * 4000
        #print(r)
        ddpg.store_transition(s, a, r, s_)         # 为什么要对reward归一化
    
        
        if ddpg.pointer > ddpg.memory_capacity or LOAD_MEM:         # 经验池已满
            if var > var_low_bound:
                var *= .9995                            # 学习阶段逐渐降低动作随机性decay the action randomness
            ddpg.learn(lr_a,lr_c)                                # 开始学习

        s = s_
        ep_reward += r
        if j == MAX_EP_STEPS -1 or done:
            print('Episode:', i, ' Reward: %i' % int(ep_reward/j), 'Explore: %.2f' % var, )
            
            ddpg.store_reward(ep_reward/j)
            
            #if ddpg.pointer > ddpg.memory_capacity and done:
                #RENDER = True
            if (i % CHECK_POINT_EPI) == 0 and i != 0:
                ddpg.save('level_selected_checkpoint/' + str(i) + 'epi')
            
            break
               
print('Running time: ', time.time() - t1)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# /home/fyf0702/miniconda3/envs/mani_skill/lib/python3.8/site-packages/torch/nn/functional.py:1628: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Episode: 0  Reward: -426 Explore: 5.00
# Episode: 1  Reward: -371 Explore: 5.00
# Episode: 2  Reward: -413 Explore: 5.00
# Episode: 3  Reward: -628 Explore: 5.00
# Episode: 4  Reward: -381 Explore: 5.00
# Episode: 5  Reward: -333 Explore: 5.00
# Episode: 6  Reward: -309 Explore: 5.00
# Episode: 7  Reward: -470 Explore: 5.00
# Episode: 8  Reward: -505 Explore: 5.00
# Episode: 9  Reward: -323 Explore: 5.00
# Episode: 10  Reward: -563 Explore: 5.00
# Episode: 11  Reward: -450 Explore: 5.00
# Episode: 12  Reward: -544 Explore: 5.00
# Episode: 13  Reward: -567 Explore: 5.00
# Episode: 14  Reward: -477 Explore: 5.00
# Episode: 15  Reward: -468 Explore: 5.00
# Episode: 16  Reward: -554 Explore: 5.00
# Episode: 17  Reward: -707 Explore: 5.00
# Episode: 18  Reward: -659 Explore: 5.00
# Episode: 19  Reward: -638 Explore: 5.00
# Episode: 20  Reward: -390 Explore: 5.00
# Episode: 21  Reward: -609 Explore: 5.00
# Episode: 22  Reward: -357 Explore: 5.00
# Episode: 23  Reward: -561 Explore: 5.00
# Episode: 24  Reward: -302 Explore: 5.00
# Episode: 25  Reward: -259 Explore: 5.00
# Episode: 26  Reward: -558 Explore: 5.00
# Episode: 27  Reward: -443 Explore: 5.00
# Episode: 28  Reward: -484 Explore: 5.00
# Episode: 29  Reward: -493 Explore: 5.00
# Episode: 30  Reward: -542 Explore: 5.00
# Episode: 31  Reward: -567 Explore: 5.00
# Episode: 32  Reward: -512 Explore: 5.00
# Episode: 33  Reward: -504 Explore: 5.00
# Episode: 34  Reward: -339 Explore: 5.00
# Episode: 35  Reward: -674 Explore: 5.00
# Episode: 36  Reward: -625 Explore: 5.00
# Episode: 37  Reward: -624 Explore: 5.00
# Episode: 38  Reward: -378 Explore: 5.00
# Episode: 39  Reward: -368 Explore: 5.00
# Episode: 40  Reward: -727 Explore: 5.00
# Episode: 41  Reward: -759 Explore: 5.00
# Episode: 42  Reward: -717 Explore: 5.00
# Episode: 43  Reward: -457 Explore: 5.00
# Episode: 44  Reward: -745 Explore: 5.00
# Episode: 45  Reward: -309 Explore: 5.00
# Episode: 46  Reward: -432 Explore: 5.00
# Episode: 47  Reward: -529 Explore: 5.00
# Episode: 48  Reward: -556 Explore: 5.00
# Episode: 49  Reward: -816 Explore: 5.00
# Episode: 50  Reward: -469 Explore: 5.00
# Episode: 51  Reward: -881 Explore: 5.00
# Episode: 52  Reward: -551 Explore: 5.00
# Episode: 53  Reward: -535 Explore: 5.00
# Episode: 54  Reward: -462 Explore: 5.00
# Episode: 55  Reward: -319 Explore: 5.00
# Episode: 56  Reward: -491 Explore: 5.00
# Episode: 57  Reward: -573 Explore: 5.00
# Episode: 58  Reward: -597 Explore: 5.00
# Episode: 59  Reward: -461 Explore: 5.00
# Episode: 60  Reward: -681 Explore: 5.00
# Episode: 61  Reward: -578 Explore: 5.00
# Episode: 62  Reward: -383 Explore: 5.00
# Episode: 63  Reward: -578 Explore: 5.00
# Episode: 64  Reward: -395 Explore: 5.00
# Episode: 65  Reward: -637 Explore: 5.00
# Episode: 66  Reward: -647 Explore: 5.00
# Episode: 67  Reward: -351 Explore: 5.00
# Episode: 68  Reward: -282 Explore: 5.00
# Episode: 69  Reward: -588 Explore: 5.00
# Episode: 70  Reward: -649 Explore: 5.00
# Episode: 71  Reward: -685 Explore: 5.00
# Episode: 72  Reward: -260 Explore: 5.00
# Episode: 73  Reward: -514 Explore: 5.00
# Episode: 74  Reward: -460 Explore: 5.00
# Episode: 75  Reward: -463 Explore: 5.00
# Episode: 76  Reward: -456 Explore: 5.00
# Episode: 77  Reward: -602 Explore: 5.00
# Episode: 78  Reward: -419 Explore: 5.00
# Episode: 79  Reward: -518 Explore: 5.00
# Episode: 80  Reward: -885 Explore: 5.00
# Episode: 81  Reward: -590 Explore: 5.00
# Episode: 82  Reward: -582 Explore: 5.00
# Episode: 83  Reward: -504 Explore: 5.00
# Episode: 84  Reward: -345 Explore: 5.00
# Episode: 85  Reward: -726 Explore: 5.00
# Episode: 86  Reward: -241 Explore: 5.00
# Episode: 87  Reward: -585 Explore: 5.00
# Episode: 88  Reward: -677 Explore: 5.00
# Episode: 89  Reward: -447 Explore: 5.00
# Episode: 90  Reward: -558 Explore: 5.00
# Episode: 91  Reward: -387 Explore: 5.00
# Episode: 92  Reward: -623 Explore: 5.00
# Episode: 93  Reward: -568 Explore: 5.00
# Episode: 94  Reward: -405 Explore: 5.00
# Episode: 95  Reward: -648 Explore: 5.00
# Episode: 96  Reward: -771 Explore: 5.00
# Episode: 97  Reward: -387 Explore: 5.00
# Episode: 98  Reward: -422 Explore: 5.00
# Episode: 99  Reward: -414 Explore: 5.00
# Episode: 100  Reward: -733 Explore: 5.00
# Episode: 101  Reward: -692 Explore: 5.00
# Episode: 102  Reward: -607 Explore: 5.00
# Episode: 103  Reward: -466 Explore: 5.00
# Episode: 104  Reward: -698 Explore: 5.00
# Episode: 105  Reward: -533 Explore: 5.00
# Episode: 106  Reward: -539 Explore: 5.00
# Episode: 107  Reward: -233 Explore: 5.00
# Episode: 108  Reward: -427 Explore: 5.00
# Episode: 109  Reward: -695 Explore: 5.00
# Episode: 110  Reward: -749 Explore: 5.00
# Episode: 111  Reward: -605 Explore: 5.00
# Episode: 112  Reward: -311 Explore: 5.00
# Episode: 113  Reward: -558 Explore: 5.00
# Episode: 114  Reward: -456 Explore: 5.00
# Episode: 115  Reward: -861 Explore: 5.00
# Episode: 116  Reward: -670 Explore: 5.00
# Episode: 117  Reward: -597 Explore: 5.00
# Episode: 118  Reward: -448 Explore: 5.00
# Episode: 119  Reward: -330 Explore: 5.00
# Episode: 120  Reward: -756 Explore: 5.00
# Episode: 121  Reward: -496 Explore: 5.00
# Episode: 122  Reward: -515 Explore: 5.00
# Episode: 123  Reward: -672 Explore: 5.00
# Episode: 124  Reward: -177 Explore: 5.00
# Episode: 125  Reward: -516 Explore: 5.00
# Episode: 126  Reward: -368 Explore: 5.00
# Episode: 127  Reward: -250 Explore: 5.00
# Episode: 128  Reward: -502 Explore: 5.00
# Episode: 129  Reward: -358 Explore: 5.00
# Episode: 130  Reward: -500 Explore: 5.00
# Episode: 131  Reward: -636 Explore: 5.00
# Episode: 132  Reward: -559 Explore: 5.00
# Episode: 133  Reward: -480 Explore: 4.88
# Episode: 134  Reward: -450 Explore: 4.70
# Episode: 135  Reward: -385 Explore: 4.52
# Episode: 136  Reward: -517 Explore: 4.36
# Episode: 137  Reward: -449 Explore: 4.20
# Episode: 138  Reward: -495 Explore: 4.04
# Episode: 139  Reward: -432 Explore: 3.89
# Episode: 140  Reward: -623 Explore: 3.75
# Episode: 141  Reward: -524 Explore: 3.61
# Episode: 142  Reward: -578 Explore: 3.48
# Episode: 143  Reward: -587 Explore: 3.35
# Episode: 144  Reward: -428 Explore: 3.23
# Episode: 145  Reward: -360 Explore: 3.11
# Episode: 146  Reward: -527 Explore: 2.99
# Episode: 147  Reward: -579 Explore: 2.88
# Episode: 148  Reward: -650 Explore: 2.78
# Episode: 149  Reward: -533 Explore: 2.68
# Episode: 150  Reward: -475 Explore: 2.58
# Episode: 151  Reward: -377 Explore: 2.48
# Episode: 152  Reward: -412 Explore: 2.39
# Episode: 153  Reward: -212 Explore: 2.30
# Episode: 154  Reward: -509 Explore: 2.22
# Episode: 155  Reward: -362 Explore: 2.14
# Episode: 156  Reward: -352 Explore: 2.06
# Episode: 157  Reward: -400 Explore: 1.98
# Episode: 158  Reward: -648 Explore: 1.91
# Episode: 159  Reward: -474 Explore: 1.84
# Episode: 160  Reward: -370 Explore: 1.77
# Episode: 161  Reward: -268 Explore: 1.71
# Episode: 162  Reward: -434 Explore: 1.64
# Episode: 163  Reward: -562 Explore: 1.58
# Episode: 164  Reward: -427 Explore: 1.52
# Episode: 165  Reward: -456 Explore: 1.47
# Episode: 166  Reward: -208 Explore: 1.41
# Episode: 167  Reward: -572 Explore: 1.36
# Episode: 168  Reward: -425 Explore: 1.31
# Episode: 169  Reward: -524 Explore: 1.26
# Episode: 170  Reward: -496 Explore: 1.22
# Episode: 171  Reward: -424 Explore: 1.17
# Episode: 172  Reward: -488 Explore: 1.13
# Episode: 173  Reward: -428 Explore: 1.09
# Episode: 174  Reward: -400 Explore: 1.05
# Episode: 175  Reward: -438 Explore: 1.01
# Episode: 176  Reward: -453 Explore: 0.97
# Episode: 177  Reward: -410 Explore: 0.94
# Episode: 178  Reward: -324 Explore: 0.90
# Episode: 179  Reward: -384 Explore: 0.87
# Episode: 180  Reward: -348 Explore: 0.84
# Episode: 181  Reward: -437 Explore: 0.81
# Episode: 182  Reward: -459 Explore: 0.78
# Episode: 183  Reward: -434 Explore: 0.75
# Episode: 184  Reward: -484 Explore: 0.72
# Episode: 185  Reward: -355 Explore: 0.69
# Episode: 186  Reward: -373 Explore: 0.67
# Episode: 187  Reward: -294 Explore: 0.64
# Episode: 188  Reward: -71 Explore: 0.62
# Episode: 189  Reward: -93 Explore: 0.60
# Episode: 190  Reward: -229 Explore: 0.57
# Episode: 191  Reward: -44 Explore: 0.55
# Episode: 192  Reward: -180 Explore: 0.53
# Episode: 193  Reward: -167 Explore: 0.51
# Episode: 194  Reward: -183 Explore: 0.49
# Episode: 195  Reward: -98 Explore: 0.48
# Episode: 196  Reward: -225 Explore: 0.46
# Episode: 197  Reward: -56 Explore: 0.44
# Episode: 198  Reward: -28 Explore: 0.43
# Episode: 199  Reward: -7 Explore: 0.41
# Episode: 200  Reward: 33 Explore: 0.40
# Episode: 201  Reward: -37 Explore: 0.38
# Episode: 202  Reward: -55 Explore: 0.37
# Episode: 203  Reward: 67 Explore: 0.35
# Episode: 204  Reward: 16 Explore: 0.34
# Episode: 205  Reward: -15 Explore: 0.33
# Episode: 206  Reward: 28 Explore: 0.32
# Episode: 207  Reward: -51 Explore: 0.30
# Episode: 208  Reward: 1 Explore: 0.29
# Episode: 209  Reward: -57 Explore: 0.28
# Episode: 210  Reward: 26 Explore: 0.27
# Episode: 211  Reward: -12 Explore: 0.26
# Episode: 212  Reward: 34 Explore: 0.25
# Episode: 213  Reward: -49 Explore: 0.24
# Episode: 214  Reward: -82 Explore: 0.23
# Episode: 215  Reward: -27 Explore: 0.23
# Episode: 216  Reward: -65 Explore: 0.22
# Episode: 217  Reward: -44 Explore: 0.21
# Episode: 218  Reward: 107 Explore: 0.20
# Episode: 219  Reward: 42 Explore: 0.19
# Episode: 220  Reward: 41 Explore: 0.19
# Episode: 221  Reward: 31 Explore: 0.18
# Episode: 222  Reward: 55 Explore: 0.17
# Episode: 223  Reward: 86 Explore: 0.17
# Episode: 224  Reward: 56 Explore: 0.16
# Episode: 225  Reward: 7 Explore: 0.15
# Episode: 226  Reward: 16 Explore: 0.15
# Episode: 227  Reward: -12 Explore: 0.14
# Episode: 228  Reward: 4 Explore: 0.14
# Episode: 229  Reward: -32 Explore: 0.13
# Episode: 230  Reward: 49 Explore: 0.13
# Episode: 231  Reward: 6 Explore: 0.12
# Episode: 232  Reward: 10 Explore: 0.12
# Episode: 233  Reward: 8 Explore: 0.11
# Episode: 234  Reward: -20 Explore: 0.11
# Episode: 235  Reward: -96 Explore: 0.11
# Episode: 236  Reward: -33 Explore: 0.10
# Episode: 237  Reward: 4 Explore: 0.10
# Episode: 238  Reward: 66 Explore: 0.09
# Episode: 239  Reward: -22 Explore: 0.09
# Episode: 240  Reward: 88 Explore: 0.09
# Episode: 241  Reward: 69 Explore: 0.08
# Episode: 242  Reward: 26 Explore: 0.08
# Episode: 243  Reward: 84 Explore: 0.08
# Episode: 244  Reward: 20 Explore: 0.08
# Episode: 245  Reward: -60 Explore: 0.07
# Episode: 246  Reward: 75 Explore: 0.07
# Episode: 247  Reward: -19 Explore: 0.07
# Episode: 248  Reward: 47 Explore: 0.07
# Episode: 249  Reward: -129 Explore: 0.06
# Episode: 250  Reward: -21 Explore: 0.06
# Episode: 251  Reward: 31 Explore: 0.06
# Episode: 252  Reward: 93 Explore: 0.06
# Episode: 253  Reward: 95 Explore: 0.05
# Episode: 254  Reward: 81 Explore: 0.05
# Episode: 255  Reward: 8 Explore: 0.05
# Episode: 256  Reward: 95 Explore: 0.05
# Episode: 257  Reward: -54 Explore: 0.05
# Episode: 258  Reward: 90 Explore: 0.05
# Episode: 259  Reward: 58 Explore: 0.05
# Episode: 260  Reward: 121 Explore: 0.05
# Episode: 261  Reward: 38 Explore: 0.05
# Episode: 262  Reward: 36 Explore: 0.05
# Episode: 263  Reward: 5 Explore: 0.05
# Episode: 264  Reward: -82 Explore: 0.05
# Episode: 265  Reward: -27 Explore: 0.05
# Episode: 266  Reward: 26 Explore: 0.05
# Episode: 267  Reward: 65 Explore: 0.05
# Episode: 268  Reward: 83 Explore: 0.05
# Episode: 269  Reward: 41 Explore: 0.05
# Episode: 270  Reward: -19 Explore: 0.05
# Episode: 271  Reward: 60 Explore: 0.05
# Episode: 272  Reward: -22 Explore: 0.05
# Episode: 273  Reward: -21 Explore: 0.05
# Episode: 274  Reward: 90 Explore: 0.05
# Episode: 275  Reward: 60 Explore: 0.05
# Episode: 276  Reward: 29 Explore: 0.05
# Episode: 277  Reward: 97 Explore: 0.05
# Episode: 278  Reward: -17 Explore: 0.05
# Episode: 279  Reward: 5 Explore: 0.05
# Episode: 280  Reward: -82 Explore: 0.05
# Episode: 281  Reward: 67 Explore: 0.05
# SUCCESS
# Episode: 282  Reward: 837 Explore: 0.05
# Episode: 283  Reward: 15 Explore: 0.05
# Episode: 284  Reward: 38 Explore: 0.05
# Episode: 285  Reward: 31 Explore: 0.05
# Episode: 286  Reward: 56 Explore: 0.05
# Episode: 287  Reward: 27 Explore: 0.05
# Episode: 288  Reward: 20 Explore: 0.05
# Episode: 289  Reward: 76 Explore: 0.05
# Episode: 290  Reward: 12 Explore: 0.05
# Episode: 291  Reward: -39 Explore: 0.05
# Episode: 292  Reward: -49 Explore: 0.05
# Episode: 293  Reward: 17 Explore: 0.05
# Episode: 294  Reward: -35 Explore: 0.05
# Episode: 295  Reward: 86 Explore: 0.05
# Episode: 296  Reward: 93 Explore: 0.05
# Episode: 297  Reward: 51 Explore: 0.05
# Episode: 298  Reward: 89 Explore: 0.05
# Episode: 299  Reward: 10 Explore: 0.05
# Episode: 300  Reward: 94 Explore: 0.05
# Episode: 301  Reward: -42 Explore: 0.05
# Episode: 302  Reward: 267 Explore: 0.05
# Episode: 303  Reward: 105 Explore: 0.05
# Episode: 304  Reward: 29 Explore: 0.05
# Episode: 305  Reward: 74 Explore: 0.05
# Episode: 306  Reward: 58 Explore: 0.05
# Episode: 307  Reward: -59 Explore: 0.05
# Episode: 308  Reward: -7 Explore: 0.05
# Episode: 309  Reward: 21 Explore: 0.05
# Episode: 310  Reward: 37 Explore: 0.05
# Episode: 311  Reward: 59 Explore: 0.05
# Episode: 312  Reward: 99 Explore: 0.05
# Episode: 313  Reward: 94 Explore: 0.05
# Episode: 314  Reward: 59 Explore: 0.05
# Episode: 315  Reward: 92 Explore: 0.05
# Episode: 316  Reward: 101 Explore: 0.05
# Episode: 317  Reward: 80 Explore: 0.05
# Episode: 318  Reward: 125 Explore: 0.05
# Episode: 319  Reward: 15 Explore: 0.05
# Episode: 320  Reward: 69 Explore: 0.05
# Episode: 321  Reward: 83 Explore: 0.05
# Episode: 322  Reward: 84 Explore: 0.05
# Episode: 323  Reward: 109 Explore: 0.05
# Episode: 324  Reward: 67 Explore: 0.05
# Episode: 325  Reward: 106 Explore: 0.05
# Episode: 326  Reward: 49 Explore: 0.05
# Episode: 327  Reward: 105 Explore: 0.05
# Episode: 328  Reward: 91 Explore: 0.05
# Episode: 329  Reward: 79 Explore: 0.05
# Episode: 330  Reward: 65 Explore: 0.05
# Episode: 331  Reward: 26 Explore: 0.05
# Episode: 332  Reward: 91 Explore: 0.05
# Episode: 333  Reward: 124 Explore: 0.05
# Episode: 334  Reward: 68 Explore: 0.05
# Episode: 335  Reward: 71 Explore: 0.05
# Episode: 336  Reward: 108 Explore: 0.05
# Episode: 337  Reward: 41 Explore: 0.05
# Episode: 338  Reward: -26 Explore: 0.05
# Episode: 339  Reward: 0 Explore: 0.05
# Episode: 340  Reward: 97 Explore: 0.05
# Episode: 341  Reward: 64 Explore: 0.05
# Episode: 342  Reward: 98 Explore: 0.05
# Episode: 343  Reward: 36 Explore: 0.05
# Episode: 344  Reward: 50 Explore: 0.05
# Episode: 345  Reward: 94 Explore: 0.05
# Episode: 346  Reward: 68 Explore: 0.05
# Episode: 347  Reward: 105 Explore: 0.05
# Episode: 348  Reward: 139 Explore: 0.05
# Episode: 349  Reward: 23 Explore: 0.05
# Episode: 350  Reward: 104 Explore: 0.05
# Episode: 351  Reward: 56 Explore: 0.05
# Episode: 352  Reward: 59 Explore: 0.05
# Episode: 353  Reward: 65 Explore: 0.05
# Episode: 354  Reward: 88 Explore: 0.05
# Episode: 355  Reward: 25 Explore: 0.05
# Episode: 356  Reward: 106 Explore: 0.05
# Episode: 357  Reward: 91 Explore: 0.05
# Episode: 358  Reward: 48 Explore: 0.05
# Episode: 359  Reward: 134 Explore: 0.05
# Episode: 360  Reward: 35 Explore: 0.05
# Episode: 361  Reward: 37 Explore: 0.05
# Episode: 362  Reward: 76 Explore: 0.05
# Episode: 363  Reward: 107 Explore: 0.05
# Episode: 364  Reward: 91 Explore: 0.05
# Episode: 365  Reward: 84 Explore: 0.05
# Episode: 366  Reward: 85 Explore: 0.05
# Episode: 367  Reward: 99 Explore: 0.05
# Episode: 368  Reward: 79 Explore: 0.05
# Episode: 369  Reward: 124 Explore: 0.05
# Episode: 370  Reward: 116 Explore: 0.05
# Episode: 371  Reward: 97 Explore: 0.05
# Episode: 372  Reward: 161 Explore: 0.05
# Episode: 373  Reward: 96 Explore: 0.05
# Episode: 374  Reward: 53 Explore: 0.05
# Episode: 375  Reward: 46 Explore: 0.05
# Episode: 376  Reward: 122 Explore: 0.05
# Episode: 377  Reward: 54 Explore: 0.05
# Episode: 378  Reward: 32 Explore: 0.05
# Episode: 379  Reward: 90 Explore: 0.05
# Episode: 380  Reward: 63 Explore: 0.05
# Episode: 381  Reward: 101 Explore: 0.05
# Episode: 382  Reward: 44 Explore: 0.05
# Episode: 383  Reward: 58 Explore: 0.05
# Episode: 384  Reward: 0 Explore: 0.05
# Episode: 385  Reward: 90 Explore: 0.05
# Episode: 386  Reward: 72 Explore: 0.05
# Episode: 387  Reward: -36 Explore: 0.05
# Episode: 388  Reward: 120 Explore: 0.05
# Episode: 389  Reward: 94 Explore: 0.05
# Episode: 390  Reward: 64 Explore: 0.05
# Episode: 391  Reward: 72 Explore: 0.05
# Episode: 392  Reward: 77 Explore: 0.05
# Episode: 393  Reward: 106 Explore: 0.05
# Episode: 394  Reward: 133 Explore: 0.05
# Episode: 395  Reward: 329 Explore: 0.05
# Episode: 396  Reward: 52 Explore: 0.05
# Episode: 397  Reward: 74 Explore: 0.05
# Episode: 398  Reward: 52 Explore: 0.05
# Episode: 399  Reward: 90 Explore: 0.05
# Episode: 400  Reward: 63 Explore: 0.05
# Episode: 401  Reward: 94 Explore: 0.05
# Episode: 402  Reward: 87 Explore: 0.05
# Episode: 403  Reward: 83 Explore: 0.05
# Episode: 404  Reward: 63 Explore: 0.05
# Episode: 405  Reward: 55 Explore: 0.05
# Episode: 406  Reward: 146 Explore: 0.05
# Episode: 407  Reward: 110 Explore: 0.05
# Episode: 408  Reward: 129 Explore: 0.05
# Episode: 409  Reward: 108 Explore: 0.05
# Episode: 410  Reward: 147 Explore: 0.05
# Episode: 411  Reward: 47 Explore: 0.05
# Episode: 412  Reward: 103 Explore: 0.05
# Episode: 413  Reward: 122 Explore: 0.05
# Episode: 414  Reward: 83 Explore: 0.05
# Episode: 415  Reward: 102 Explore: 0.05
# Episode: 416  Reward: 104 Explore: 0.05
# Episode: 417  Reward: 126 Explore: 0.05
# Episode: 418  Reward: 87 Explore: 0.05
# Episode: 419  Reward: 142 Explore: 0.05
# Episode: 420  Reward: 161 Explore: 0.05
# Episode: 421  Reward: 145 Explore: 0.05
# Episode: 422  Reward: 62 Explore: 0.05
# Episode: 423  Reward: 123 Explore: 0.05
# Episode: 424  Reward: 111 Explore: 0.05
# Episode: 425  Reward: 93 Explore: 0.05
# Episode: 426  Reward: 135 Explore: 0.05
# Episode: 427  Reward: 117 Explore: 0.05
# Episode: 428  Reward: 118 Explore: 0.05
# Episode: 429  Reward: 123 Explore: 0.05
# Episode: 430  Reward: 80 Explore: 0.05
# Episode: 431  Reward: 119 Explore: 0.05
# Episode: 432  Reward: 117 Explore: 0.05
# Episode: 433  Reward: 101 Explore: 0.05
# Episode: 434  Reward: 59 Explore: 0.05
# Episode: 435  Reward: 105 Explore: 0.05
# Episode: 436  Reward: 110 Explore: 0.05
# Episode: 437  Reward: 130 Explore: 0.05
# Episode: 438  Reward: 84 Explore: 0.05
# Episode: 439  Reward: 109 Explore: 0.05
# Episode: 440  Reward: 146 Explore: 0.05
# Episode: 441  Reward: 80 Explore: 0.05
# Episode: 442  Reward: 87 Explore: 0.05
# Episode: 443  Reward: 84 Explore: 0.05
# Episode: 444  Reward: 88 Explore: 0.05
# Episode: 445  Reward: 45 Explore: 0.05
# Episode: 446  Reward: 102 Explore: 0.05
# Episode: 447  Reward: 133 Explore: 0.05
# Episode: 448  Reward: 56 Explore: 0.05
# Episode: 449  Reward: 115 Explore: 0.05
# Episode: 450  Reward: 144 Explore: 0.05
# Episode: 451  Reward: 141 Explore: 0.05
# Episode: 452  Reward: 164 Explore: 0.05
# Episode: 453  Reward: 140 Explore: 0.05
# Episode: 454  Reward: 96 Explore: 0.05
# Episode: 455  Reward: 72 Explore: 0.05
# Episode: 456  Reward: 109 Explore: 0.05
# Episode: 457  Reward: 84 Explore: 0.05
# Episode: 458  Reward: 132 Explore: 0.05
# Episode: 459  Reward: 117 Explore: 0.05
# Episode: 460  Reward: 107 Explore: 0.05
# Episode: 461  Reward: 138 Explore: 0.05
# Episode: 462  Reward: 114 Explore: 0.05
# Episode: 463  Reward: 136 Explore: 0.05
# Episode: 464  Reward: 130 Explore: 0.05
# Episode: 465  Reward: 63 Explore: 0.05
# Episode: 466  Reward: 155 Explore: 0.05
# Episode: 467  Reward: 92 Explore: 0.05
# Episode: 468  Reward: 142 Explore: 0.05
# Episode: 469  Reward: 140 Explore: 0.05
# Episode: 470  Reward: 150 Explore: 0.05
# Episode: 471  Reward: 112 Explore: 0.05
# Episode: 472  Reward: 96 Explore: 0.05
# Episode: 473  Reward: -19 Explore: 0.05
# Episode: 474  Reward: 82 Explore: 0.05
# Episode: 475  Reward: 29 Explore: 0.05
# Episode: 476  Reward: -16 Explore: 0.05
# Episode: 477  Reward: 30 Explore: 0.05
# Episode: 478  Reward: 98 Explore: 0.05
# Episode: 479  Reward: 113 Explore: 0.05
# Episode: 480  Reward: 140 Explore: 0.05
# Episode: 481  Reward: 81 Explore: 0.05
# Episode: 482  Reward: 85 Explore: 0.05
# Episode: 483  Reward: 107 Explore: 0.05
# Episode: 484  Reward: 124 Explore: 0.05
# Episode: 485  Reward: 82 Explore: 0.05
# Episode: 486  Reward: 43 Explore: 0.05
# Episode: 487  Reward: 86 Explore: 0.05
# Episode: 488  Reward: 119 Explore: 0.05
# Episode: 489  Reward: 68 Explore: 0.05
# Episode: 490  Reward: 0 Explore: 0.05
# Episode: 491  Reward: 91 Explore: 0.05
# Episode: 492  Reward: 117 Explore: 0.05
# Episode: 493  Reward: 154 Explore: 0.05
# Episode: 494  Reward: 92 Explore: 0.05
# Episode: 495  Reward: 65 Explore: 0.05
# Episode: 496  Reward: 83 Explore: 0.05
# Episode: 497  Reward: 94 Explore: 0.05
# Episode: 498  Reward: 94 Explore: 0.05
# Episode: 499  Reward: 131 Explore: 0.05
# Episode: 500  Reward: 112 Explore: 0.05
# Episode: 501  Reward: 95 Explore: 0.05
# Episode: 502  Reward: 118 Explore: 0.05
# Episode: 503  Reward: 126 Explore: 0.05
# Episode: 504  Reward: 115 Explore: 0.05
# Episode: 505  Reward: 165 Explore: 0.05
# Episode: 506  Reward: 86 Explore: 0.05
# Episode: 507  Reward: 67 Explore: 0.05
# Episode: 508  Reward: 151 Explore: 0.05
# Episode: 509  Reward: 159 Explore: 0.05
# Episode: 510  Reward: 112 Explore: 0.05
# Episode: 511  Reward: 99 Explore: 0.05
# Episode: 512  Reward: 43 Explore: 0.05
# Episode: 513  Reward: -9 Explore: 0.05
# Episode: 514  Reward: 149 Explore: 0.05
# Episode: 515  Reward: 94 Explore: 0.05
# Episode: 516  Reward: 102 Explore: 0.05
# Episode: 517  Reward: 100 Explore: 0.05
# Episode: 518  Reward: 167 Explore: 0.05
# Episode: 519  Reward: 62 Explore: 0.05
# Episode: 520  Reward: 103 Explore: 0.05
# Episode: 521  Reward: 62 Explore: 0.05
# Episode: 522  Reward: 140 Explore: 0.05
# Episode: 523  Reward: 107 Explore: 0.05
# Episode: 524  Reward: 88 Explore: 0.05
# Episode: 525  Reward: 86 Explore: 0.05
# Episode: 526  Reward: 129 Explore: 0.05
# Episode: 527  Reward: 110 Explore: 0.05
# Episode: 528  Reward: 73 Explore: 0.05
# Episode: 529  Reward: 109 Explore: 0.05
# Episode: 530  Reward: 36 Explore: 0.05
# Episode: 531  Reward: 83 Explore: 0.05
# Episode: 532  Reward: 126 Explore: 0.05
# Episode: 533  Reward: 128 Explore: 0.05
# Episode: 534  Reward: 124 Explore: 0.05
# Episode: 535  Reward: 117 Explore: 0.05
# Episode: 536  Reward: 175 Explore: 0.05
# Episode: 537  Reward: 102 Explore: 0.05
# Episode: 538  Reward: 147 Explore: 0.05
# Episode: 539  Reward: 100 Explore: 0.05
# Episode: 540  Reward: 79 Explore: 0.05
# Episode: 541  Reward: 113 Explore: 0.05
# Episode: 542  Reward: 184 Explore: 0.05
# Episode: 543  Reward: 119 Explore: 0.05
# Episode: 544  Reward: 80 Explore: 0.05
# Episode: 545  Reward: 70 Explore: 0.05
# Episode: 546  Reward: 129 Explore: 0.05
# Episode: 547  Reward: 76 Explore: 0.05
# Episode: 548  Reward: 30 Explore: 0.05
# Episode: 549  Reward: 122 Explore: 0.05
# Episode: 550  Reward: 99 Explore: 0.05
# Episode: 551  Reward: 79 Explore: 0.05
# Episode: 552  Reward: 103 Explore: 0.05
# Episode: 553  Reward: 135 Explore: 0.05
# Episode: 554  Reward: 25 Explore: 0.05
# Episode: 555  Reward: 128 Explore: 0.05
# Episode: 556  Reward: 106 Explore: 0.05
# Episode: 557  Reward: 132 Explore: 0.05
# Episode: 558  Reward: 84 Explore: 0.05
# Episode: 559  Reward: 83 Explore: 0.05
# Episode: 560  Reward: 85 Explore: 0.05
# Episode: 561  Reward: 115 Explore: 0.05
# Episode: 562  Reward: 113 Explore: 0.05
# Episode: 563  Reward: 109 Explore: 0.05
# Episode: 564  Reward: 136 Explore: 0.05
# Episode: 565  Reward: 57 Explore: 0.05
# Episode: 566  Reward: 92 Explore: 0.05
# Episode: 567  Reward: 69 Explore: 0.05
# Episode: 568  Reward: 109 Explore: 0.05
# Episode: 569  Reward: 68 Explore: 0.05
# Episode: 570  Reward: 68 Explore: 0.05
# Episode: 571  Reward: 104 Explore: 0.05
# Episode: 572  Reward: 75 Explore: 0.05
# Episode: 573  Reward: 131 Explore: 0.05
# Episode: 574  Reward: 63 Explore: 0.05
# Episode: 575  Reward: 105 Explore: 0.05
# Episode: 576  Reward: 136 Explore: 0.05
# Episode: 577  Reward: 132 Explore: 0.05
# Episode: 578  Reward: 83 Explore: 0.05
# Episode: 579  Reward: 126 Explore: 0.05
# Episode: 580  Reward: 108 Explore: 0.05
# Episode: 581  Reward: 95 Explore: 0.05
# Episode: 582  Reward: 28 Explore: 0.05
# Episode: 583  Reward: 128 Explore: 0.05
# Episode: 584  Reward: 115 Explore: 0.05
# Episode: 585  Reward: 125 Explore: 0.05
# Episode: 586  Reward: 125 Explore: 0.05
# Episode: 587  Reward: 98 Explore: 0.05
# Episode: 588  Reward: 258 Explore: 0.05
# Episode: 589  Reward: 85 Explore: 0.05
# Episode: 590  Reward: 96 Explore: 0.05
# Episode: 591  Reward: 25 Explore: 0.05
# Episode: 592  Reward: 86 Explore: 0.05
# Episode: 593  Reward: 64 Explore: 0.05
# SUCCESS
# Episode: 594  Reward: 808 Explore: 0.05
# SUCCESS
# Episode: 595  Reward: 1142 Explore: 0.05
# Episode: 596  Reward: 72 Explore: 0.05
# Episode: 597  Reward: 64 Explore: 0.05
# Episode: 598  Reward: 56 Explore: 0.05
# Episode: 599  Reward: 109 Explore: 0.05
# Episode: 600  Reward: -49 Explore: 0.05
# SUCCESS
# Episode: 601  Reward: 509 Explore: 0.05
# Episode: 602  Reward: -73 Explore: 0.05
# Episode: 603  Reward: 86 Explore: 0.05
# Episode: 604  Reward: 67 Explore: 0.05
# Episode: 605  Reward: 132 Explore: 0.05
# Episode: 606  Reward: 51 Explore: 0.05
# Episode: 607  Reward: 17 Explore: 0.05
# Episode: 608  Reward: -67 Explore: 0.05
# Episode: 609  Reward: -33 Explore: 0.05
# Episode: 610  Reward: -91 Explore: 0.05
# Episode: 611  Reward: 74 Explore: 0.05
# Episode: 612  Reward: -27 Explore: 0.05
# Episode: 613  Reward: 0 Explore: 0.05
# Episode: 614  Reward: -72 Explore: 0.05
# Episode: 615  Reward: 0 Explore: 0.05
# Episode: 616  Reward: 10 Explore: 0.05
# Episode: 617  Reward: 41 Explore: 0.05
# Episode: 618  Reward: 183 Explore: 0.05
# Episode: 619  Reward: 91 Explore: 0.05
# Episode: 620  Reward: 26 Explore: 0.05
# Episode: 621  Reward: -35 Explore: 0.05
# Episode: 622  Reward: -213 Explore: 0.05
# Episode: 623  Reward: 140 Explore: 0.05
# Episode: 624  Reward: 4 Explore: 0.05
# Episode: 625  Reward: -357 Explore: 0.05
# Episode: 626  Reward: 0 Explore: 0.05
# Episode: 627  Reward: 57 Explore: 0.05
# Episode: 628  Reward: 15 Explore: 0.05
# Episode: 629  Reward: 50 Explore: 0.05
# Episode: 630  Reward: 32 Explore: 0.05
# Episode: 631  Reward: 86 Explore: 0.05
# Episode: 632  Reward: -22 Explore: 0.05
# Episode: 633  Reward: 69 Explore: 0.05
# Episode: 634  Reward: 125 Explore: 0.05
# Episode: 635  Reward: -24 Explore: 0.05
# Episode: 636  Reward: 17 Explore: 0.05
# Episode: 637  Reward: 94 Explore: 0.05
# Episode: 638  Reward: 91 Explore: 0.05
# Episode: 639  Reward: 19 Explore: 0.05
# Episode: 640  Reward: 90 Explore: 0.05
# Episode: 641  Reward: 77 Explore: 0.05
# Episode: 642  Reward: 21 Explore: 0.05
# Episode: 643  Reward: 78 Explore: 0.05
# Episode: 644  Reward: 82 Explore: 0.05
# Episode: 645  Reward: -35 Explore: 0.05
# Episode: 646  Reward: 114 Explore: 0.05
# Episode: 647  Reward: 109 Explore: 0.05
# SUCCESS
# Episode: 648  Reward: 676 Explore: 0.05
# Episode: 649  Reward: 80 Explore: 0.05
# Episode: 650  Reward: 57 Explore: 0.05
# Episode: 651  Reward: 5 Explore: 0.05
# Episode: 652  Reward: 50 Explore: 0.05
# Episode: 653  Reward: 96 Explore: 0.05
# Episode: 654  Reward: 1 Explore: 0.05
# Episode: 655  Reward: -28 Explore: 0.05
# Episode: 656  Reward: 137 Explore: 0.05
# Episode: 657  Reward: 79 Explore: 0.05
# Episode: 658  Reward: 87 Explore: 0.05
# Episode: 659  Reward: 72 Explore: 0.05
# Episode: 660  Reward: 55 Explore: 0.05
# Episode: 661  Reward: 30 Explore: 0.05
# Episode: 662  Reward: 55 Explore: 0.05
# Episode: 663  Reward: 95 Explore: 0.05
# Episode: 664  Reward: 66 Explore: 0.05
# Episode: 665  Reward: 72 Explore: 0.05
# Episode: 666  Reward: 45 Explore: 0.05
# Episode: 667  Reward: 65 Explore: 0.05
# Episode: 668  Reward: 75 Explore: 0.05
# Episode: 669  Reward: 69 Explore: 0.05
# Episode: 670  Reward: 49 Explore: 0.05
# Episode: 671  Reward: 33 Explore: 0.05
# Episode: 672  Reward: -143 Explore: 0.05
# Episode: 673  Reward: -42 Explore: 0.05
# SUCCESS
# Episode: 674  Reward: 729 Explore: 0.05
# Episode: 675  Reward: 73 Explore: 0.05
# Episode: 676  Reward: 130 Explore: 0.05
# Episode: 677  Reward: 100 Explore: 0.05
# Episode: 678  Reward: 144 Explore: 0.05
# Episode: 679  Reward: 90 Explore: 0.05
# Episode: 680  Reward: 69 Explore: 0.05
# Episode: 681  Reward: 29 Explore: 0.05
# Episode: 682  Reward: 130 Explore: 0.05
# Episode: 683  Reward: 115 Explore: 0.05
# Episode: 684  Reward: 68 Explore: 0.05
# Episode: 685  Reward: 112 Explore: 0.05
# Episode: 686  Reward: 62 Explore: 0.05
# Episode: 687  Reward: 60 Explore: 0.05
# Episode: 688  Reward: 7 Explore: 0.05
# Episode: 689  Reward: 63 Explore: 0.05
# Episode: 690  Reward: 63 Explore: 0.05
# Episode: 691  Reward: 146 Explore: 0.05
# Episode: 692  Reward: 111 Explore: 0.05
# Episode: 693  Reward: 100 Explore: 0.05
# Episode: 694  Reward: 108 Explore: 0.05
# Episode: 695  Reward: 43 Explore: 0.05
# Episode: 696  Reward: 138 Explore: 0.05
# Episode: 697  Reward: 55 Explore: 0.05
# Episode: 698  Reward: 63 Explore: 0.05
# Episode: 699  Reward: 45 Explore: 0.05
# Episode: 700  Reward: 86 Explore: 0.05
# Episode: 701  Reward: 7 Explore: 0.05
# Episode: 702  Reward: -140 Explore: 0.05
# Episode: 703  Reward: 86 Explore: 0.05
# Episode: 704  Reward: 40 Explore: 0.05
# Episode: 705  Reward: 27 Explore: 0.05
# Episode: 706  Reward: 68 Explore: 0.05
# Episode: 707  Reward: 94 Explore: 0.05
# Episode: 708  Reward: 81 Explore: 0.05
# Episode: 709  Reward: 96 Explore: 0.05
# Episode: 710  Reward: 155 Explore: 0.05
# Episode: 711  Reward: 92 Explore: 0.05
# Episode: 712  Reward: 97 Explore: 0.05
# Episode: 713  Reward: 84 Explore: 0.05
# Episode: 714  Reward: 23 Explore: 0.05
# Episode: 715  Reward: 23 Explore: 0.05
# Episode: 716  Reward: 47 Explore: 0.05
# Episode: 717  Reward: 45 Explore: 0.05
# Episode: 718  Reward: -21 Explore: 0.05
# SUCCESS
# Episode: 719  Reward: 966 Explore: 0.05
# Episode: 720  Reward: 41 Explore: 0.05
# Episode: 721  Reward: 23 Explore: 0.05
# Episode: 722  Reward: 183 Explore: 0.05
# Episode: 723  Reward: 7 Explore: 0.05
# Episode: 724  Reward: -26 Explore: 0.05
# Episode: 725  Reward: -9 Explore: 0.05
# Episode: 726  Reward: 78 Explore: 0.05
# Episode: 727  Reward: 28 Explore: 0.05
# Episode: 728  Reward: 151 Explore: 0.05
# Episode: 729  Reward: 31 Explore: 0.05
# Episode: 730  Reward: 63 Explore: 0.05
# SUCCESS
# Episode: 731  Reward: 1019 Explore: 0.05
# Episode: 732  Reward: 98 Explore: 0.05
# Episode: 733  Reward: 47 Explore: 0.05
# Episode: 734  Reward: -40 Explore: 0.05
# Episode: 735  Reward: 27 Explore: 0.05
# Episode: 736  Reward: -80 Explore: 0.05
# Episode: 737  Reward: 9 Explore: 0.05
# Episode: 738  Reward: 547 Explore: 0.05
# Episode: 739  Reward: 86 Explore: 0.05
# Episode: 740  Reward: 29 Explore: 0.05
# Episode: 741  Reward: 169 Explore: 0.05
# Episode: 742  Reward: -120 Explore: 0.05
# Episode: 743  Reward: 57 Explore: 0.05
# Episode: 744  Reward: 114 Explore: 0.05
# Episode: 745  Reward: 39 Explore: 0.05
# Episode: 746  Reward: 47 Explore: 0.05
# Episode: 747  Reward: 31 Explore: 0.05
# Episode: 748  Reward: 47 Explore: 0.05
# Episode: 749  Reward: 53 Explore: 0.05
# Episode: 750  Reward: 47 Explore: 0.05
# Episode: 751  Reward: 92 Explore: 0.05
# Episode: 752  Reward: 97 Explore: 0.05
# Episode: 753  Reward: 21 Explore: 0.05
# Episode: 754  Reward: 33 Explore: 0.05
# Episode: 755  Reward: 115 Explore: 0.05
# Episode: 756  Reward: 47 Explore: 0.05
# Episode: 757  Reward: 95 Explore: 0.05
# Episode: 758  Reward: 66 Explore: 0.05
# Episode: 759  Reward: 97 Explore: 0.05
# Episode: 760  Reward: 18 Explore: 0.05
# Episode: 761  Reward: 70 Explore: 0.05
# Episode: 762  Reward: 65 Explore: 0.05
# Episode: 763  Reward: 31 Explore: 0.05
# Episode: 764  Reward: 46 Explore: 0.05
# Episode: 765  Reward: 83 Explore: 0.05
# Episode: 766  Reward: 53 Explore: 0.05
# Episode: 767  Reward: 32 Explore: 0.05
# Episode: 768  Reward: 38 Explore: 0.05
# Episode: 769  Reward: 4 Explore: 0.05
# Episode: 770  Reward: 65 Explore: 0.05
# Episode: 771  Reward: 85 Explore: 0.05
# Episode: 772  Reward: 30 Explore: 0.05
# Episode: 773  Reward: 20 Explore: 0.05
# Episode: 774  Reward: 115 Explore: 0.05
# Episode: 775  Reward: 32 Explore: 0.05
# Episode: 776  Reward: 112 Explore: 0.05
# Episode: 777  Reward: 41 Explore: 0.05
# Episode: 778  Reward: -53 Explore: 0.05
# Episode: 779  Reward: 67 Explore: 0.05
# Episode: 780  Reward: -65 Explore: 0.05
# Episode: 781  Reward: -10 Explore: 0.05
# Episode: 782  Reward: 90 Explore: 0.05
# Episode: 783  Reward: 41 Explore: 0.05
# Episode: 784  Reward: 59 Explore: 0.05
# Episode: 785  Reward: 92 Explore: 0.05
# Episode: 786  Reward: 93 Explore: 0.05
# Episode: 787  Reward: 88 Explore: 0.05
# Episode: 788  Reward: 111 Explore: 0.05
# Episode: 789  Reward: 138 Explore: 0.05
# Episode: 790  Reward: 98 Explore: 0.05
# Episode: 791  Reward: 117 Explore: 0.05
# Episode: 792  Reward: 78 Explore: 0.05
# Episode: 793  Reward: 118 Explore: 0.05
# Episode: 794  Reward: 77 Explore: 0.05
# Episode: 795  Reward: 121 Explore: 0.05
# Episode: 796  Reward: 90 Explore: 0.05
# Episode: 797  Reward: 79 Explore: 0.05
# Episode: 798  Reward: 76 Explore: 0.05
# Episode: 799  Reward: 57 Explore: 0.05
# Episode: 800  Reward: 91 Explore: 0.05
# Episode: 801  Reward: 66 Explore: 0.05
# Episode: 802  Reward: 27 Explore: 0.05
# Episode: 803  Reward: 58 Explore: 0.05
# Episode: 804  Reward: -53 Explore: 0.05
# Episode: 805  Reward: 120 Explore: 0.05
# Episode: 806  Reward: 101 Explore: 0.05
# Episode: 807  Reward: -10 Explore: 0.05
# SUCCESS
# Episode: 808  Reward: 817 Explore: 0.05
# Episode: 809  Reward: 67 Explore: 0.05
# Episode: 810  Reward: 93 Explore: 0.05
# Episode: 811  Reward: 88 Explore: 0.05
# Episode: 812  Reward: 26 Explore: 0.05
# Episode: 813  Reward: -16 Explore: 0.05
# Episode: 814  Reward: -86 Explore: 0.05
# SUCCESS
# Episode: 815  Reward: 765 Explore: 0.05
# Episode: 816  Reward: 91 Explore: 0.05
# Episode: 817  Reward: 58 Explore: 0.05
# Episode: 818  Reward: 61 Explore: 0.05
# Episode: 819  Reward: -6 Explore: 0.05
# SUCCESS
# Episode: 820  Reward: 602 Explore: 0.05
# Episode: 821  Reward: 92 Explore: 0.05
# Episode: 822  Reward: 85 Explore: 0.05
# Episode: 823  Reward: 54 Explore: 0.05
# Episode: 824  Reward: 27 Explore: 0.05
# Episode: 825  Reward: 116 Explore: 0.05
# Episode: 826  Reward: 52 Explore: 0.05
# Episode: 827  Reward: -7 Explore: 0.05
# Episode: 828  Reward: 80 Explore: 0.05
# Episode: 829  Reward: 100 Explore: 0.05
# Episode: 830  Reward: 43 Explore: 0.05
# Episode: 831  Reward: 66 Explore: 0.05
# Episode: 832  Reward: 99 Explore: 0.05
# Episode: 833  Reward: 40 Explore: 0.05
# Episode: 834  Reward: 51 Explore: 0.05
# Episode: 835  Reward: 26 Explore: 0.05
# Episode: 836  Reward: 93 Explore: 0.05
# Episode: 837  Reward: 166 Explore: 0.05
# Episode: 838  Reward: 238 Explore: 0.05
# Episode: 839  Reward: 11 Explore: 0.05
# Episode: 840  Reward: 104 Explore: 0.05
# Episode: 841  Reward: 59 Explore: 0.05
# Episode: 842  Reward: 72 Explore: 0.05
# Episode: 843  Reward: 63 Explore: 0.05
# Episode: 844  Reward: 67 Explore: 0.05
# Episode: 845  Reward: 50 Explore: 0.05
# Episode: 846  Reward: 230 Explore: 0.05
# Episode: 847  Reward: 42 Explore: 0.05
# Episode: 848  Reward: 38 Explore: 0.05
# Episode: 849  Reward: 11 Explore: 0.05
# Episode: 850  Reward: 71 Explore: 0.05
# SUCCESS
# Episode: 851  Reward: 801 Explore: 0.05
# Episode: 852  Reward: 33 Explore: 0.05
# Episode: 853  Reward: 24 Explore: 0.05
# Episode: 854  Reward: 118 Explore: 0.05
# Episode: 855  Reward: 54 Explore: 0.05
# Episode: 856  Reward: 86 Explore: 0.05
# Episode: 857  Reward: 76 Explore: 0.05
# Episode: 858  Reward: 97 Explore: 0.05
# Episode: 859  Reward: 67 Explore: 0.05
# Episode: 860  Reward: 43 Explore: 0.05
# Episode: 861  Reward: 91 Explore: 0.05
# Episode: 862  Reward: 50 Explore: 0.05
# Episode: 863  Reward: 94 Explore: 0.05
# Episode: 864  Reward: 96 Explore: 0.05
# Episode: 865  Reward: 70 Explore: 0.05
# Episode: 866  Reward: 31 Explore: 0.05
# Episode: 867  Reward: 56 Explore: 0.05
# Episode: 868  Reward: 82 Explore: 0.05
# Episode: 869  Reward: 89 Explore: 0.05
# Episode: 870  Reward: 24 Explore: 0.05
# Episode: 871  Reward: 44 Explore: 0.05
# Episode: 872  Reward: 62 Explore: 0.05
# Episode: 873  Reward: 39 Explore: 0.05
# Episode: 874  Reward: 1 Explore: 0.05
# Episode: 875  Reward: 50 Explore: 0.05
# Episode: 876  Reward: 32 Explore: 0.05
# Episode: 877  Reward: 64 Explore: 0.05
# Episode: 878  Reward: 12 Explore: 0.05
# Episode: 879  Reward: 6 Explore: 0.05
# Episode: 880  Reward: 68 Explore: 0.05
# Episode: 881  Reward: 46 Explore: 0.05
# Episode: 882  Reward: 63 Explore: 0.05
# Episode: 883  Reward: -16 Explore: 0.05
# Episode: 884  Reward: 24 Explore: 0.05
# Episode: 885  Reward: 18 Explore: 0.05
# Episode: 886  Reward: 62 Explore: 0.05
# Episode: 887  Reward: 55 Explore: 0.05
# Episode: 888  Reward: 67 Explore: 0.05
# Episode: 889  Reward: 1 Explore: 0.05
# Episode: 890  Reward: -9 Explore: 0.05
# Episode: 891  Reward: 0 Explore: 0.05
# Episode: 892  Reward: 44 Explore: 0.05
# Episode: 893  Reward: 96 Explore: 0.05
# Episode: 894  Reward: 66 Explore: 0.05
# Episode: 895  Reward: 68 Explore: 0.05
# Episode: 896  Reward: 31 Explore: 0.05
# Episode: 897  Reward: 124 Explore: 0.05
# Episode: 898  Reward: 55 Explore: 0.05
# Episode: 899  Reward: 49 Explore: 0.05
# Episode: 900  Reward: 54 Explore: 0.05
# Episode: 901  Reward: 34 Explore: 0.05
# Episode: 902  Reward: 16 Explore: 0.05
# Episode: 903  Reward: 46 Explore: 0.05
# Episode: 904  Reward: -5 Explore: 0.05
# Episode: 905  Reward: 7 Explore: 0.05
# Episode: 906  Reward: 64 Explore: 0.05
# Episode: 907  Reward: 47 Explore: 0.05
# Episode: 908  Reward: 79 Explore: 0.05
# Episode: 909  Reward: -1 Explore: 0.05
# Episode: 910  Reward: 82 Explore: 0.05
# Episode: 911  Reward: 88 Explore: 0.05
# Episode: 912  Reward: 51 Explore: 0.05
# Episode: 913  Reward: 30 Explore: 0.05
# Episode: 914  Reward: 40 Explore: 0.05
# Episode: 915  Reward: 52 Explore: 0.05
# Episode: 916  Reward: 12 Explore: 0.05
# Episode: 917  Reward: 41 Explore: 0.05
# Episode: 918  Reward: 57 Explore: 0.05
# Episode: 919  Reward: 26 Explore: 0.05
# Episode: 920  Reward: 63 Explore: 0.05
# Episode: 921  Reward: 110 Explore: 0.05
# Episode: 922  Reward: 100 Explore: 0.05
# Episode: 923  Reward: 83 Explore: 0.05
# Episode: 924  Reward: 94 Explore: 0.05
# Episode: 925  Reward: 87 Explore: 0.05
# Episode: 926  Reward: 34 Explore: 0.05
# Episode: 927  Reward: 92 Explore: 0.05
# Episode: 928  Reward: 84 Explore: 0.05
# Episode: 929  Reward: 91 Explore: 0.05
# Episode: 930  Reward: 50 Explore: 0.05
# Episode: 931  Reward: 110 Explore: 0.05
# Episode: 932  Reward: 66 Explore: 0.05
# Episode: 933  Reward: 66 Explore: 0.05
# Episode: 934  Reward: 125 Explore: 0.05
# Episode: 935  Reward: 124 Explore: 0.05
# Episode: 936  Reward: 59 Explore: 0.05
# Episode: 937  Reward: 47 Explore: 0.05
# Episode: 938  Reward: 76 Explore: 0.05
# Episode: 939  Reward: 31 Explore: 0.05
# Episode: 940  Reward: 122 Explore: 0.05
# Episode: 941  Reward: 27 Explore: 0.05
# Episode: 942  Reward: 112 Explore: 0.05
# Episode: 943  Reward: 72 Explore: 0.05
# Episode: 944  Reward: 25 Explore: 0.05
# Episode: 945  Reward: 76 Explore: 0.05
# Episode: 946  Reward: 98 Explore: 0.05
# Episode: 947  Reward: 111 Explore: 0.05
# Episode: 948  Reward: -18 Explore: 0.05
# Episode: 949  Reward: 143 Explore: 0.05
# Episode: 950  Reward: 100 Explore: 0.05
# Episode: 951  Reward: 18 Explore: 0.05
# Episode: 952  Reward: 121 Explore: 0.05
# Episode: 953  Reward: 108 Explore: 0.05
# Episode: 954  Reward: 9 Explore: 0.05
# Episode: 955  Reward: 51 Explore: 0.05
# Episode: 956  Reward: 122 Explore: 0.05
# Episode: 957  Reward: 69 Explore: 0.05
# Episode: 958  Reward: 61 Explore: 0.05
# Episode: 959  Reward: 98 Explore: 0.05
# Episode: 960  Reward: 118 Explore: 0.05
# Episode: 961  Reward: 113 Explore: 0.05
# Episode: 962  Reward: 96 Explore: 0.05
# Episode: 963  Reward: 69 Explore: 0.05
# Episode: 964  Reward: 102 Explore: 0.05
# Episode: 965  Reward: 59 Explore: 0.05
# Episode: 966  Reward: 100 Explore: 0.05
# Episode: 967  Reward: 64 Explore: 0.05
# Episode: 968  Reward: 80 Explore: 0.05
# Episode: 969  Reward: 103 Explore: 0.05
# Episode: 970  Reward: 103 Explore: 0.05
# Episode: 971  Reward: 80 Explore: 0.05
# Episode: 972  Reward: 14 Explore: 0.05
# Episode: 973  Reward: 69 Explore: 0.05
# Episode: 974  Reward: 74 Explore: 0.05
# Episode: 975  Reward: 81 Explore: 0.05
# Episode: 976  Reward: 91 Explore: 0.05
# Episode: 977  Reward: 72 Explore: 0.05
# Episode: 978  Reward: 38 Explore: 0.05
# Episode: 979  Reward: 46 Explore: 0.05
# Episode: 980  Reward: 83 Explore: 0.05
# Episode: 981  Reward: 102 Explore: 0.05
# Episode: 982  Reward: 98 Explore: 0.05
# Episode: 983  Reward: 84 Explore: 0.05
# Episode: 984  Reward: 131 Explore: 0.05
# Episode: 985  Reward: 58 Explore: 0.05
# Episode: 986  Reward: 19 Explore: 0.05
# Episode: 987  Reward: 323 Explore: 0.05
# Episode: 988  Reward: 24 Explore: 0.05
# Episode: 989  Reward: 57 Explore: 0.05
# Episode: 990  Reward: 18 Explore: 0.05
# Episode: 991  Reward: 88 Explore: 0.05
# Episode: 992  Reward: 29 Explore: 0.05
# Episode: 993  Reward: 86 Explore: 0.05
# Episode: 994  Reward: 156 Explore: 0.05
# Episode: 995  Reward: 118 Explore: 0.05
# Episode: 996  Reward: 76 Explore: 0.05
# Episode: 997  Reward: 7 Explore: 0.05
# Episode: 998  Reward: 104 Explore: 0.05
# Episode: 999  Reward: 141 Explore: 0.05
# Episode: 1000  Reward: -4 Explore: 0.05
# Episode: 1001  Reward: 127 Explore: 0.05
# Episode: 1002  Reward: 65 Explore: 0.05
# Episode: 1003  Reward: 130 Explore: 0.05
# Episode: 1004  Reward: 66 Explore: 0.05
# Episode: 1005  Reward: 44 Explore: 0.05
# Episode: 1006  Reward: 12 Explore: 0.05
# Episode: 1007  Reward: 99 Explore: 0.05
# Episode: 1008  Reward: 41 Explore: 0.05
# Episode: 1009  Reward: 19 Explore: 0.05
# Episode: 1010  Reward: 30 Explore: 0.05
# Episode: 1011  Reward: 89 Explore: 0.05
# Episode: 1012  Reward: 79 Explore: 0.05
# Episode: 1013  Reward: 89 Explore: 0.05
# Episode: 1014  Reward: 50 Explore: 0.05
# Episode: 1015  Reward: 58 Explore: 0.05
# Episode: 1016  Reward: 63 Explore: 0.05
# Episode: 1017  Reward: 63 Explore: 0.05
# Episode: 1018  Reward: 79 Explore: 0.05
# Episode: 1019  Reward: 116 Explore: 0.05
# Episode: 1020  Reward: 129 Explore: 0.05
# Episode: 1021  Reward: 106 Explore: 0.05
# Episode: 1022  Reward: 60 Explore: 0.05
# Episode: 1023  Reward: 30 Explore: 0.05
# Episode: 1024  Reward: 44 Explore: 0.05
# Episode: 1025  Reward: 61 Explore: 0.05
# Episode: 1026  Reward: 62 Explore: 0.05
# Episode: 1027  Reward: 97 Explore: 0.05
# Episode: 1028  Reward: 10 Explore: 0.05
# Episode: 1029  Reward: 66 Explore: 0.05
# Episode: 1030  Reward: 72 Explore: 0.05
# Episode: 1031  Reward: 107 Explore: 0.05
# Episode: 1032  Reward: 92 Explore: 0.05
# Episode: 1033  Reward: 85 Explore: 0.05
# Episode: 1034  Reward: 65 Explore: 0.05
# Episode: 1035  Reward: 75 Explore: 0.05
# Episode: 1036  Reward: 121 Explore: 0.05
# Episode: 1037  Reward: 60 Explore: 0.05
# Episode: 1038  Reward: 115 Explore: 0.05
# Episode: 1039  Reward: 17 Explore: 0.05
# Episode: 1040  Reward: 118 Explore: 0.05
# Episode: 1041  Reward: 71 Explore: 0.05
# Episode: 1042  Reward: 31 Explore: 0.05
# Episode: 1043  Reward: 78 Explore: 0.05
# Episode: 1044  Reward: 84 Explore: 0.05
# Episode: 1045  Reward: 120 Explore: 0.05
# Episode: 1046  Reward: 89 Explore: 0.05
# Episode: 1047  Reward: 31 Explore: 0.05
# Episode: 1048  Reward: 87 Explore: 0.05
# Episode: 1049  Reward: 152 Explore: 0.05
# Episode: 1050  Reward: -28 Explore: 0.05
# /tmp/ipykernel_8586/3601640071.py:234: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10, 10), dpi=70)
# Episode: 1051  Reward: 98 Explore: 0.05
# Episode: 1052  Reward: 81 Explore: 0.05
# Episode: 1053  Reward: 109 Explore: 0.05
# Episode: 1054  Reward: 100 Explore: 0.05
# Episode: 1055  Reward: 37 Explore: 0.05
# Episode: 1056  Reward: 94 Explore: 0.05
# Episode: 1057  Reward: 122 Explore: 0.05
# Episode: 1058  Reward: 83 Explore: 0.05
# Episode: 1059  Reward: 185 Explore: 0.05
# Episode: 1060  Reward: 66 Explore: 0.05
# Episode: 1061  Reward: 53 Explore: 0.05
# Episode: 1062  Reward: 104 Explore: 0.05
# Episode: 1063  Reward: -26 Explore: 0.05
# Episode: 1064  Reward: 85 Explore: 0.05
# Episode: 1065  Reward: -57 Explore: 0.05
# Episode: 1066  Reward: 115 Explore: 0.05
# Episode: 1067  Reward: 71 Explore: 0.05
# Episode: 1068  Reward: 64 Explore: 0.05
# Episode: 1069  Reward: 89 Explore: 0.05
# Episode: 1070  Reward: 84 Explore: 0.05
# Episode: 1071  Reward: 85 Explore: 0.05
# Episode: 1072  Reward: 50 Explore: 0.05
# Episode: 1073  Reward: 40 Explore: 0.05
# Episode: 1074  Reward: 93 Explore: 0.05
# Episode: 1075  Reward: 20 Explore: 0.05
# Episode: 1076  Reward: -22 Explore: 0.05
# Episode: 1077  Reward: 96 Explore: 0.05
# Episode: 1078  Reward: 48 Explore: 0.05
# Episode: 1079  Reward: 21 Explore: 0.05
# Episode: 1080  Reward: 98 Explore: 0.05
# Episode: 1081  Reward: 35 Explore: 0.05
# Episode: 1082  Reward: 58 Explore: 0.05
# Episode: 1083  Reward: 2 Explore: 0.05
# Episode: 1084  Reward: -11 Explore: 0.05
# Episode: 1085  Reward: 301 Explore: 0.05
# Episode: 1086  Reward: 39 Explore: 0.05
# Episode: 1087  Reward: 4 Explore: 0.05
# Episode: 1088  Reward: 82 Explore: 0.05
# Episode: 1089  Reward: -50 Explore: 0.05
# Episode: 1090  Reward: 66 Explore: 0.05
# Episode: 1091  Reward: 86 Explore: 0.05
# Episode: 1092  Reward: -2 Explore: 0.05
# Episode: 1093  Reward: -11 Explore: 0.05
# Episode: 1094  Reward: 33 Explore: 0.05
# Episode: 1095  Reward: 71 Explore: 0.05
# Episode: 1096  Reward: 45 Explore: 0.05
# Episode: 1097  Reward: 63 Explore: 0.05
# Episode: 1098  Reward: 21 Explore: 0.05
# Episode: 1099  Reward: 71 Explore: 0.05
# Episode: 1100  Reward: 41 Explore: 0.05
# Episode: 1101  Reward: -7 Explore: 0.05
# Episode: 1102  Reward: 132 Explore: 0.05
# Episode: 1103  Reward: 54 Explore: 0.05
# Episode: 1104  Reward: 38 Explore: 0.05
# Episode: 1105  Reward: 114 Explore: 0.05
# Episode: 1106  Reward: 66 Explore: 0.05
# Episode: 1107  Reward: 86 Explore: 0.05
# Episode: 1108  Reward: 113 Explore: 0.05
# Episode: 1109  Reward: 97 Explore: 0.05
# SUCCESS
# Episode: 1110  Reward: 639 Explore: 0.05
# Episode: 1111  Reward: 17 Explore: 0.05
# Episode: 1112  Reward: 20 Explore: 0.05
# Episode: 1113  Reward: 60 Explore: 0.05
# Episode: 1114  Reward: 18 Explore: 0.05
# Episode: 1115  Reward: 123 Explore: 0.05
# Episode: 1116  Reward: 93 Explore: 0.05
# Episode: 1117  Reward: 77 Explore: 0.05
# Episode: 1118  Reward: 80 Explore: 0.05
# Episode: 1119  Reward: 100 Explore: 0.05
# Episode: 1120  Reward: 84 Explore: 0.05
# Episode: 1121  Reward: 65 Explore: 0.05
# Episode: 1122  Reward: 58 Explore: 0.05
# Episode: 1123  Reward: 39 Explore: 0.05
# Episode: 1124  Reward: 79 Explore: 0.05
# Episode: 1125  Reward: 32 Explore: 0.05
# Episode: 1126  Reward: 105 Explore: 0.05
# Episode: 1127  Reward: 78 Explore: 0.05
# Episode: 1128  Reward: 16 Explore: 0.05
# Episode: 1129  Reward: 78 Explore: 0.05
# Episode: 1130  Reward: 50 Explore: 0.05
# Episode: 1131  Reward: 67 Explore: 0.05
# Episode: 1132  Reward: 98 Explore: 0.05
# Episode: 1133  Reward: 28 Explore: 0.05
# Episode: 1134  Reward: 79 Explore: 0.05
# Episode: 1135  Reward: 111 Explore: 0.05
# Episode: 1136  Reward: 83 Explore: 0.05
# Episode: 1137  Reward: 70 Explore: 0.05
# Episode: 1138  Reward: 54 Explore: 0.05
# Episode: 1139  Reward: 18 Explore: 0.05
# Episode: 1140  Reward: 132 Explore: 0.05
# Episode: 1141  Reward: 85 Explore: 0.05
# Episode: 1142  Reward: 106 Explore: 0.05
# Episode: 1143  Reward: 90 Explore: 0.05
# Episode: 1144  Reward: 112 Explore: 0.05
# Episode: 1145  Reward: 84 Explore: 0.05
# Episode: 1146  Reward: 75 Explore: 0.05
# Episode: 1147  Reward: 94 Explore: 0.05
# Episode: 1148  Reward: 79 Explore: 0.05
# Episode: 1149  Reward: 80 Explore: 0.05
# Episode: 1150  Reward: 81 Explore: 0.05
# Episode: 1151  Reward: 72 Explore: 0.05
# Episode: 1152  Reward: 125 Explore: 0.05
# Episode: 1153  Reward: 50 Explore: 0.05
# Episode: 1154  Reward: 68 Explore: 0.05
# Episode: 1155  Reward: 81 Explore: 0.05
# Episode: 1156  Reward: 83 Explore: 0.05
# Episode: 1157  Reward: 36 Explore: 0.05
# Episode: 1158  Reward: 36 Explore: 0.05
# Episode: 1159  Reward: 72 Explore: 0.05
# Episode: 1160  Reward: 101 Explore: 0.05
# Episode: 1161  Reward: 54 Explore: 0.05
# Episode: 1162  Reward: 51 Explore: 0.05
# Episode: 1163  Reward: 58 Explore: 0.05
# Episode: 1164  Reward: 113 Explore: 0.05
# Episode: 1165  Reward: 109 Explore: 0.05
# Episode: 1166  Reward: 79 Explore: 0.05
# Episode: 1167  Reward: 110 Explore: 0.05
# Episode: 1168  Reward: 92 Explore: 0.05
# Episode: 1169  Reward: 19 Explore: 0.05
# Episode: 1170  Reward: 63 Explore: 0.05
# Episode: 1171  Reward: 64 Explore: 0.05
# Episode: 1172  Reward: 11 Explore: 0.05
# Episode: 1173  Reward: 66 Explore: 0.05
# Episode: 1174  Reward: 75 Explore: 0.05
# Episode: 1175  Reward: 147 Explore: 0.05
# Episode: 1176  Reward: 35 Explore: 0.05
# Episode: 1177  Reward: 95 Explore: 0.05
# Episode: 1178  Reward: 97 Explore: 0.05
# Episode: 1179  Reward: -20 Explore: 0.05
# Episode: 1180  Reward: 10 Explore: 0.05
# Episode: 1181  Reward: 72 Explore: 0.05
# Episode: 1182  Reward: 102 Explore: 0.05
# Episode: 1183  Reward: 74 Explore: 0.05
# Episode: 1184  Reward: -45 Explore: 0.05
# Episode: 1185  Reward: 89 Explore: 0.05
# Episode: 1186  Reward: 115 Explore: 0.05
# Episode: 1187  Reward: 55 Explore: 0.05
# ...
# Episode: 2607  Reward: 85 Explore: 0.05
# Episode: 2608  Reward: -89 Explore: 0.05
# Episode: 2609  Reward: 125 Explore: 0.05
# Episode: 2610  Reward: 112 Explore: 0.05
# Episode: 2611  Reward: 26 Explore: 0.05
# Episode: 2612  Reward: 54 Explore: 0.05
# Episode: 2613  Reward: 112 Explore: 0.05
# Episode: 2614  Reward: 110 Explore: 0.05
# Episode: 2615  Reward: -10 Explore: 0.05
# Episode: 2616  Reward: 53 Explore: 0.05
# Episode: 2617  Reward: 27 Explore: 0.05
# Episode: 2618  Reward: -6 Explore: 0.05
# Episode: 2619  Reward: 80 Explore: 0.05
# Episode: 2620  Reward: -10 Explore: 0.05
# Episode: 2621  Reward: -26 Explore: 0.05
# Episode: 2622  Reward: -267 Explore: 0.05
# Episode: 2623  Reward: -30 Explore: 0.05
# Episode: 2624  Reward: 74 Explore: 0.05
# Episode: 2625  Reward: 130 Explore: 0.05
# Episode: 2626  Reward: -229 Explore: 0.05
# Episode: 2627  Reward: 89 Explore: 0.05
# Episode: 2628  Reward: -44 Explore: 0.05
# Episode: 2629  Reward: 56 Explore: 0.05
# Episode: 2630  Reward: 62 Explore: 0.05
# Episode: 2631  Reward: 149 Explore: 0.05
# Episode: 2632  Reward: 75 Explore: 0.05
# Episode: 2633  Reward: 78 Explore: 0.05
# Episode: 2634  Reward: 97 Explore: 0.05
# Episode: 2635  Reward: 178 Explore: 0.05
# Episode: 2636  Reward: 111 Explore: 0.05
# Episode: 2637  Reward: 111 Explore: 0.05
# Episode: 2638  Reward: 120 Explore: 0.05
# Episode: 2639  Reward: 95 Explore: 0.05
# Episode: 2640  Reward: 117 Explore: 0.05
# Episode: 2641  Reward: 113 Explore: 0.05
# Episode: 2642  Reward: 83 Explore: 0.05
# Episode: 2643  Reward: 115 Explore: 0.05
# Episode: 2644  Reward: 101 Explore: 0.05
# Episode: 2645  Reward: 99 Explore: 0.05
# Episode: 2646  Reward: 126 Explore: 0.05
# Episode: 2647  Reward: 80 Explore: 0.05
# Episode: 2648  Reward: 93 Explore: 0.05
# Episode: 2649  Reward: 78 Explore: 0.05
# Episode: 2650  Reward: 134 Explore: 0.05
# Episode: 2651  Reward: 129 Explore: 0.05
# Episode: 2652  Reward: 92 Explore: 0.05
# Episode: 2653  Reward: -9 Explore: 0.05
# Episode: 2654  Reward: 94 Explore: 0.05
# Episode: 2655  Reward: 1 Explore: 0.05
# Episode: 2656  Reward: 63 Explore: 0.05
# Episode: 2657  Reward: 201 Explore: 0.05
# Episode: 2658  Reward: 119 Explore: 0.05
# Episode: 2659  Reward: 164 Explore: 0.05
# Episode: 2660  Reward: 134 Explore: 0.05
# Episode: 2661  Reward: 117 Explore: 0.05
# Episode: 2662  Reward: 116 Explore: 0.05
# Episode: 2663  Reward: 89 Explore: 0.05
# Episode: 2664  Reward: 114 Explore: 0.05
# Episode: 2665  Reward: 115 Explore: 0.05
# Episode: 2666  Reward: 87 Explore: 0.05
# Episode: 2667  Reward: 66 Explore: 0.05
# Episode: 2668  Reward: 90 Explore: 0.05
# Episode: 2669  Reward: 105 Explore: 0.05
# Episode: 2670  Reward: 120 Explore: 0.05
# Episode: 2671  Reward: 96 Explore: 0.05
# SUCCESS
# Episode: 2672  Reward: 531 Explore: 0.05
# Episode: 2673  Reward: 135 Explore: 0.05
# Episode: 2674  Reward: 88 Explore: 0.05
# Episode: 2675  Reward: 141 Explore: 0.05
# Episode: 2676  Reward: 86 Explore: 0.05
# Episode: 2677  Reward: 62 Explore: 0.05
# Episode: 2678  Reward: 96 Explore: 0.05
# Episode: 2679  Reward: 116 Explore: 0.05
# Episode: 2680  Reward: 56 Explore: 0.05
# Episode: 2681  Reward: 20 Explore: 0.05
# Episode: 2682  Reward: 32 Explore: 0.05
# Episode: 2683  Reward: -20 Explore: 0.05
# Episode: 2684  Reward: 65 Explore: 0.05
# Episode: 2685  Reward: 14 Explore: 0.05
# Episode: 2686  Reward: 64 Explore: 0.05
# Episode: 2687  Reward: 76 Explore: 0.05
# Episode: 2688  Reward: 97 Explore: 0.05
# Episode: 2689  Reward: 72 Explore: 0.05
# Episode: 2690  Reward: 57 Explore: 0.05
# Episode: 2691  Reward: 83 Explore: 0.05
# Episode: 2692  Reward: 110 Explore: 0.05
# Episode: 2693  Reward: 110 Explore: 0.05
# Episode: 2694  Reward: 94 Explore: 0.05
# Episode: 2695  Reward: 49 Explore: 0.05
# Episode: 2696  Reward: 4 Explore: 0.05
# Episode: 2697  Reward: 136 Explore: 0.05
# Episode: 2698  Reward: 182 Explore: 0.05
# Episode: 2699  Reward: 66 Explore: 0.05
# Episode: 2700  Reward: 101 Explore: 0.05
# Episode: 2701  Reward: -30 Explore: 0.05
# Episode: 2702  Reward: 33 Explore: 0.05
# Episode: 2703  Reward: 95 Explore: 0.05
# Episode: 2704  Reward: 11 Explore: 0.05
# Episode: 2705  Reward: 78 Explore: 0.05
# Episode: 2706  Reward: 75 Explore: 0.05
# Episode: 2707  Reward: 103 Explore: 0.05
# Episode: 2708  Reward: 84 Explore: 0.05
# Episode: 2709  Reward: 85 Explore: 0.05
# Episode: 2710  Reward: 101 Explore: 0.05
# Episode: 2711  Reward: 136 Explore: 0.05
# Episode: 2712  Reward: 146 Explore: 0.05
# Episode: 2713  Reward: 84 Explore: 0.05
# Episode: 2714  Reward: 77 Explore: 0.05
# Episode: 2715  Reward: 109 Explore: 0.05
# Episode: 2716  Reward: 64 Explore: 0.05
# Episode: 2717  Reward: 95 Explore: 0.05
# Episode: 2718  Reward: 134 Explore: 0.05
# Episode: 2719  Reward: 86 Explore: 0.05
# Episode: 2720  Reward: 61 Explore: 0.05
# Episode: 2721  Reward: 69 Explore: 0.05
# Episode: 2722  Reward: 112 Explore: 0.05
# Episode: 2723  Reward: 51 Explore: 0.05
# Episode: 2724  Reward: 81 Explore: 0.05
# Episode: 2725  Reward: 38 Explore: 0.05
# Episode: 2726  Reward: 66 Explore: 0.05
# Episode: 2727  Reward: 48 Explore: 0.05
# Episode: 2728  Reward: 56 Explore: 0.05
# Episode: 2729  Reward: 78 Explore: 0.05
# Episode: 2730  Reward: 37 Explore: 0.05
# Episode: 2731  Reward: 39 Explore: 0.05
# Episode: 2732  Reward: 78 Explore: 0.05
# Episode: 2733  Reward: 77 Explore: 0.05
# Episode: 2734  Reward: 122 Explore: 0.05
# Episode: 2735  Reward: 26 Explore: 0.05
# Episode: 2736  Reward: 40 Explore: 0.05
# Episode: 2737  Reward: 106 Explore: 0.05
# Episode: 2738  Reward: 62 Explore: 0.05
# Episode: 2739  Reward: 60 Explore: 0.05
# Episode: 2740  Reward: 95 Explore: 0.05
# Episode: 2741  Reward: 26 Explore: 0.05
# Episode: 2742  Reward: 10 Explore: 0.05
# Episode: 2743  Reward: 23 Explore: 0.05
# Episode: 2744  Reward: 80 Explore: 0.05
# Episode: 2745  Reward: 151 Explore: 0.05
# Episode: 2746  Reward: 120 Explore: 0.05
# Episode: 2747  Reward: 69 Explore: 0.05
# Episode: 2748  Reward: 22 Explore: 0.05
# Episode: 2749  Reward: 95 Explore: 0.05
# Episode: 2750  Reward: 65 Explore: 0.05
# Episode: 2751  Reward: 86 Explore: 0.05
# Episode: 2752  Reward: -5 Explore: 0.05
# Episode: 2753  Reward: 73 Explore: 0.05
# Episode: 2754  Reward: -11 Explore: 0.05
# Episode: 2755  Reward: 90 Explore: 0.05
# Episode: 2756  Reward: 121 Explore: 0.05
# Episode: 2757  Reward: 121 Explore: 0.05
# Episode: 2758  Reward: 51 Explore: 0.05
# Episode: 2759  Reward: 114 Explore: 0.05
# Episode: 2760  Reward: 51 Explore: 0.05
# Episode: 2761  Reward: 35 Explore: 0.05
# Episode: 2762  Reward: 52 Explore: 0.05
# Episode: 2763  Reward: -136 Explore: 0.05
# Episode: 2764  Reward: 22 Explore: 0.05
# Episode: 2765  Reward: 82 Explore: 0.05
# Episode: 2766  Reward: -15 Explore: 0.05
# Episode: 2767  Reward: 332 Explore: 0.05
# Episode: 2768  Reward: 78 Explore: 0.05
# Episode: 2769  Reward: 445 Explore: 0.05
# Episode: 2770  Reward: 23 Explore: 0.05
# Episode: 2771  Reward: 47 Explore: 0.05
# SUCCESS
# Episode: 2772  Reward: 1062 Explore: 0.05
# Episode: 2773  Reward: -5 Explore: 0.05
# Episode: 2774  Reward: -52 Explore: 0.05
# Episode: 2775  Reward: 188 Explore: 0.05
# SUCCESS
# Episode: 2776  Reward: 1150 Explore: 0.05
# Episode: 2777  Reward: 16 Explore: 0.05
# Episode: 2778  Reward: 50 Explore: 0.05
# Episode: 2779  Reward: 58 Explore: 0.05
# Episode: 2780  Reward: 81 Explore: 0.05
# Episode: 2781  Reward: 452 Explore: 0.05
# Episode: 2782  Reward: 74 Explore: 0.05
# Episode: 2783  Reward: -55 Explore: 0.05
# Episode: 2784  Reward: 146 Explore: 0.05
# Episode: 2785  Reward: -75 Explore: 0.05
# Episode: 2786  Reward: 11 Explore: 0.05
# Episode: 2787  Reward: 95 Explore: 0.05
# Episode: 2788  Reward: 428 Explore: 0.05
# Episode: 2789  Reward: 9 Explore: 0.05
# Episode: 2790  Reward: 105 Explore: 0.05
# Episode: 2791  Reward: 59 Explore: 0.05
# SUCCESS
# Episode: 2792  Reward: 732 Explore: 0.05
# Episode: 2793  Reward: 118 Explore: 0.05
# Episode: 2794  Reward: 75 Explore: 0.05
# Episode: 2795  Reward: 89 Explore: 0.05
# Episode: 2796  Reward: 111 Explore: 0.05
# Episode: 2797  Reward: 104 Explore: 0.05
# Episode: 2798  Reward: 62 Explore: 0.05
# Episode: 2799  Reward: -139 Explore: 0.05
# Episode: 2800  Reward: 51 Explore: 0.05
# Episode: 2801  Reward: 127 Explore: 0.05
# Episode: 2802  Reward: 83 Explore: 0.05
# Episode: 2803  Reward: 21 Explore: 0.05
# Episode: 2804  Reward: 47 Explore: 0.05
# Episode: 2805  Reward: 80 Explore: 0.05
# Episode: 2806  Reward: 86 Explore: 0.05
# Episode: 2807  Reward: 81 Explore: 0.05
# Episode: 2808  Reward: 113 Explore: 0.05
# Episode: 2809  Reward: 81 Explore: 0.05
# Episode: 2810  Reward: 60 Explore: 0.05
# Episode: 2811  Reward: 86 Explore: 0.05
# Episode: 2812  Reward: 32 Explore: 0.05
# Episode: 2813  Reward: 82 Explore: 0.05
# Episode: 2814  Reward: 107 Explore: 0.05
# Episode: 2815  Reward: 100 Explore: 0.05
# Episode: 2816  Reward: 140 Explore: 0.05
# Episode: 2817  Reward: 84 Explore: 0.05
# Episode: 2818  Reward: -9 Explore: 0.05
# Episode: 2819  Reward: 11 Explore: 0.05
# Episode: 2820  Reward: 107 Explore: 0.05
# Episode: 2821  Reward: 7 Explore: 0.05
# Episode: 2822  Reward: 86 Explore: 0.05
# Episode: 2823  Reward: 117 Explore: 0.05
# Episode: 2824  Reward: 297 Explore: 0.05
# Episode: 2825  Reward: 29 Explore: 0.05
# Episode: 2826  Reward: 122 Explore: 0.05
# Episode: 2827  Reward: 123 Explore: 0.05
# Episode: 2828  Reward: 73 Explore: 0.05
# Episode: 2829  Reward: 17 Explore: 0.05
# Episode: 2830  Reward: 108 Explore: 0.05
# Episode: 2831  Reward: 89 Explore: 0.05
# Episode: 2832  Reward: 98 Explore: 0.05
# Episode: 2833  Reward: 39 Explore: 0.05
# Episode: 2834  Reward: 33 Explore: 0.05
# Episode: 2835  Reward: 56 Explore: 0.05
# Episode: 2836  Reward: -6 Explore: 0.05
# Episode: 2837  Reward: 42 Explore: 0.05
# Episode: 2838  Reward: 68 Explore: 0.05
# Episode: 2839  Reward: 55 Explore: 0.05
# Episode: 2840  Reward: 32 Explore: 0.05
# Episode: 2841  Reward: 75 Explore: 0.05
# Episode: 2842  Reward: 37 Explore: 0.05
# Episode: 2843  Reward: 58 Explore: 0.05
# Episode: 2844  Reward: 185 Explore: 0.05
# Episode: 2845  Reward: 106 Explore: 0.05
# Episode: 2846  Reward: 79 Explore: 0.05
# Episode: 2847  Reward: 82 Explore: 0.05
# Episode: 2848  Reward: 82 Explore: 0.05
# Episode: 2849  Reward: 30 Explore: 0.05
# Episode: 2850  Reward: 322 Explore: 0.05
# Episode: 2851  Reward: 71 Explore: 0.05
# Episode: 2852  Reward: 21 Explore: 0.05
# Episode: 2853  Reward: 70 Explore: 0.05
# Episode: 2854  Reward: 88 Explore: 0.05
# Episode: 2855  Reward: -246 Explore: 0.05
# Episode: 2856  Reward: 81 Explore: 0.05
# Episode: 2857  Reward: 93 Explore: 0.05
# Episode: 2858  Reward: 71 Explore: 0.05
# Episode: 2859  Reward: 93 Explore: 0.05
# Episode: 2860  Reward: 94 Explore: 0.05
# Episode: 2861  Reward: 107 Explore: 0.05
# Episode: 2862  Reward: 74 Explore: 0.05
# Episode: 2863  Reward: 98 Explore: 0.05
# Episode: 2864  Reward: 110 Explore: 0.05
# Episode: 2865  Reward: 138 Explore: 0.05
# Episode: 2866  Reward: -177 Explore: 0.05
# Episode: 2867  Reward: 97 Explore: 0.05
# Episode: 2868  Reward: 82 Explore: 0.05
# Episode: 2869  Reward: 101 Explore: 0.05
# SUCCESS
# Episode: 2870  Reward: 776 Explore: 0.05
# Episode: 2871  Reward: 106 Explore: 0.05
# Episode: 2872  Reward: 55 Explore: 0.05
# Episode: 2873  Reward: 66 Explore: 0.05
# Episode: 2874  Reward: 28 Explore: 0.05
# Episode: 2875  Reward: 23 Explore: 0.05
# Episode: 2876  Reward: 92 Explore: 0.05
# Episode: 2877  Reward: 68 Explore: 0.05
# Episode: 2878  Reward: 96 Explore: 0.05
# Episode: 2879  Reward: 96 Explore: 0.05
# Episode: 2880  Reward: 238 Explore: 0.05
# Episode: 2881  Reward: 86 Explore: 0.05
# Episode: 2882  Reward: 66 Explore: 0.05
# Episode: 2883  Reward: 47 Explore: 0.05
# Episode: 2884  Reward: 266 Explore: 0.05
# Episode: 2885  Reward: 157 Explore: 0.05
# Episode: 2886  Reward: 65 Explore: 0.05
# Episode: 2887  Reward: 39 Explore: 0.05
# Episode: 2888  Reward: 27 Explore: 0.05
# Episode: 2889  Reward: 87 Explore: 0.05
# Episode: 2890  Reward: 45 Explore: 0.05
# Episode: 2891  Reward: 69 Explore: 0.05
# Episode: 2892  Reward: 2 Explore: 0.05
# Episode: 2893  Reward: -212 Explore: 0.05
# Episode: 2894  Reward: 100 Explore: 0.05
# Episode: 2895  Reward: 81 Explore: 0.05
# Episode: 2896  Reward: 94 Explore: 0.05
# Episode: 2897  Reward: 95 Explore: 0.05
# Episode: 2898  Reward: -139 Explore: 0.05
# Episode: 2899  Reward: -122 Explore: 0.05
# Episode: 2900  Reward: 11 Explore: 0.05
# Episode: 2901  Reward: 27 Explore: 0.05
# Episode: 2902  Reward: 2 Explore: 0.05
# Episode: 2903  Reward: 103 Explore: 0.05
# Episode: 2904  Reward: -127 Explore: 0.05
# Episode: 2905  Reward: 106 Explore: 0.05
# Episode: 2906  Reward: -34 Explore: 0.05
# Episode: 2907  Reward: 219 Explore: 0.05
# Episode: 2908  Reward: 90 Explore: 0.05
# Episode: 2909  Reward: 72 Explore: 0.05
# Episode: 2910  Reward: 27 Explore: 0.05
# Episode: 2911  Reward: 51 Explore: 0.05
# Episode: 2912  Reward: 116 Explore: 0.05
# Episode: 2913  Reward: -7 Explore: 0.05
# Episode: 2914  Reward: 96 Explore: 0.05
# Episode: 2915  Reward: -7 Explore: 0.05
# Episode: 2916  Reward: 98 Explore: 0.05
# Episode: 2917  Reward: 42 Explore: 0.05
# Episode: 2918  Reward: 123 Explore: 0.05
# Episode: 2919  Reward: -40 Explore: 0.05
# Episode: 2920  Reward: 111 Explore: 0.05
# Episode: 2921  Reward: 32 Explore: 0.05
# Episode: 2922  Reward: 94 Explore: 0.05
# Episode: 2923  Reward: 246 Explore: 0.05
# Episode: 2924  Reward: 92 Explore: 0.05
# Episode: 2925  Reward: 109 Explore: 0.05
# Episode: 2926  Reward: 118 Explore: 0.05
# Episode: 2927  Reward: 86 Explore: 0.05
# Episode: 2928  Reward: 169 Explore: 0.05
# Episode: 2929  Reward: 81 Explore: 0.05
# Episode: 2930  Reward: 240 Explore: 0.05
# Episode: 2931  Reward: 63 Explore: 0.05
# Episode: 2932  Reward: 108 Explore: 0.05
# Episode: 2933  Reward: 142 Explore: 0.05
# Episode: 2934  Reward: 85 Explore: 0.05
# Episode: 2935  Reward: 79 Explore: 0.05
# Episode: 2936  Reward: 30 Explore: 0.05
# Episode: 2937  Reward: 57 Explore: 0.05
# Episode: 2938  Reward: 83 Explore: 0.05
# Episode: 2939  Reward: 96 Explore: 0.05
# Episode: 2940  Reward: 96 Explore: 0.05
# Episode: 2941  Reward: 90 Explore: 0.05
# Episode: 2942  Reward: 74 Explore: 0.05
# Episode: 2943  Reward: -52 Explore: 0.05
# Episode: 2944  Reward: 168 Explore: 0.05
# Episode: 2945  Reward: 74 Explore: 0.05
# Episode: 2946  Reward: 63 Explore: 0.05
# Episode: 2947  Reward: 105 Explore: 0.05
# Episode: 2948  Reward: 69 Explore: 0.05
# Episode: 2949  Reward: 100 Explore: 0.05
# Episode: 2950  Reward: 47 Explore: 0.05
# Episode: 2951  Reward: 71 Explore: 0.05
# Episode: 2952  Reward: 61 Explore: 0.05
# Episode: 2953  Reward: 98 Explore: 0.05
# Episode: 2954  Reward: -5 Explore: 0.05
# Episode: 2955  Reward: 75 Explore: 0.05
# Episode: 2956  Reward: -59 Explore: 0.05
# Episode: 2957  Reward: 55 Explore: 0.05
# Episode: 2958  Reward: 55 Explore: 0.05
# Episode: 2959  Reward: 212 Explore: 0.05
# Episode: 2960  Reward: 44 Explore: 0.05
# Episode: 2961  Reward: -13 Explore: 0.05
# Episode: 2962  Reward: 68 Explore: 0.05
# Episode: 2963  Reward: 62 Explore: 0.05
# Episode: 2964  Reward: 105 Explore: 0.05
# Episode: 2965  Reward: 93 Explore: 0.05
# Episode: 2966  Reward: 38 Explore: 0.05
# Episode: 2967  Reward: 83 Explore: 0.05
# Episode: 2968  Reward: 2 Explore: 0.05
# Episode: 2969  Reward: 58 Explore: 0.05
# Episode: 2970  Reward: 87 Explore: 0.05
# Episode: 2971  Reward: 77 Explore: 0.05
# Episode: 2972  Reward: 121 Explore: 0.05
# Episode: 2973  Reward: -30 Explore: 0.05
# Episode: 2974  Reward: 93 Explore: 0.05
# Episode: 2975  Reward: 100 Explore: 0.05
# Episode: 2976  Reward: 232 Explore: 0.05
# Episode: 2977  Reward: 50 Explore: 0.05
# Episode: 2978  Reward: 93 Explore: 0.05
# Episode: 2979  Reward: 101 Explore: 0.05
# Episode: 2980  Reward: 75 Explore: 0.05
# Episode: 2981  Reward: 89 Explore: 0.05
# Episode: 2982  Reward: 84 Explore: 0.05
# Episode: 2983  Reward: 112 Explore: 0.05
# Episode: 2984  Reward: 99 Explore: 0.05
# Episode: 2985  Reward: 19 Explore: 0.05
# Episode: 2986  Reward: 73 Explore: 0.05
# Episode: 2987  Reward: 61 Explore: 0.05
# Episode: 2988  Reward: -2 Explore: 0.05
# Episode: 2989  Reward: 59 Explore: 0.05
# Episode: 2990  Reward: 83 Explore: 0.05
# Episode: 2991  Reward: 4 Explore: 0.05
# Episode: 2992  Reward: 53 Explore: 0.05
# Episode: 2993  Reward: 102 Explore: 0.05
# Episode: 2994  Reward: 38 Explore: 0.05
# Episode: 2995  Reward: 35 Explore: 0.05
# Episode: 2996  Reward: 67 Explore: 0.05
# Episode: 2997  Reward: 53 Explore: 0.05
# Episode: 2998  Reward: 92 Explore: 0.05
# Episode: 2999  Reward: 32 Explore: 0.05
# Episode: 3000  Reward: 90 Explore: 0.05
# Running time:  6146.750079631805

# %%
ddpg.save('carbinet_SELF_level_selected_3000EPS')

# %%
data = pd.read_csv('./DPG model/level12789_check_point_final/3050epi/Rewards.csv')
y = np.array(data).squeeze()
x = range(y.shape[0])

size = 50

z = np.zeros(len(y))
m = np.zeros(len(y))

#for i in range(len(y)):
#    if y[i] >= 10:
#        y[i] = 0
        
for i in range(len(y)):
    
    if i > (size/2 -1) and i < (len(y) - size/2):  
        for j in range(size):
            z[i] += y[i + j - int(size/2)]  #平均reward
            
            if(y[i + j - int(size/2)] == 0):
                m[i] += 1                  #success rate
            
                                   
            
        z[i] = z[i] / size
        m[i] = m[i]
        

    
    
plt.figure(figsize=(10, 10), dpi=70)

plt.plot(x, y)
plt.plot(x, z)
plt.plot(x, m)

plt.legend(['y','z','m'])
plt.show()

print('maximum success rate: ', max(m)/50)
print('maximum mean rewards: ', max(z))
# Out:
# maximum success rate:  0.0
# maximum mean rewards:  800.5924504191495

# %%
data = pd.read_csv('./DPG model/level_selected_checkpoint/3000epi/Rewards.csv')
y = np.array(data).squeeze()
x = range(y.shape[0])
size = 50
z = np.zeros(len(y))
for i in range(len(y)):
    if y[i] >= 300:
        y[i] = 0  
for i in range(len(y)):
    if i > (size/2 -1) and i < (len(y) - size/2):  
        for j in range(size):
            z[i] += y[i + j - int(size/2)]  #平均reward        
    z[i] = z[i]/size
plt.figure(figsize=(10, 10), dpi=70)
plt.plot(x, y)
plt.plot(x, z)
plt.legend(['y','z'])
plt.show()
print('maximum mean rewards: ', np.argmax(z))
# Out:
# maximum mean rewards:  444

# %%
data = pd.read_csv('./DPG model/level_selected_checkpoint/3000epi/Success_record.csv')
y = np.array(data).squeeze()
x = range(y.shape[0])
m = np.zeros(y.shape[0])

for i in range(50,3000):
    for j in range(50):
        if y[i-50+j] == 1:
            m[i] += 1
    m[i] = m[i] / 50   
    
plt.figure(figsize=(10, 10), dpi=70)
plt.plot(x, m)
plt.show()
print(max(m))#最大值
print(np.argmax(m))#最大值所在位置
# Out:
# 0.08
# 852
